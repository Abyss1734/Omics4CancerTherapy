# %%
import requests
from chembl_webresource_client.new_client import new_client
import pandas as pd
import numpy as np
from typing import List, Dict, Union, Optional
from functools import lru_cache
import time
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import os
from pathlib import Path

# Настройка сессии с повторными попытками
session = requests.Session()
retries = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[500, 502, 503, 504]
)
session.mount('https://', HTTPAdapter(max_retries=retries))

# Установка таймаута по умолчанию для ChEMBL клиента
new_client.timeout = 30

def uniprot_to_chembl(uniprot_id: str) -> Optional[str]:
    """Получает ChEMBL ID из UniProt ID."""
    target = new_client.target
    try:
        res = target.filter(target_components__accession=uniprot_id)
        res_df = pd.DataFrame(res)
        
        if res_df.empty:
            return None
        return res_df['target_chembl_id'].iloc[0]
    except Exception as e:
        print(f"Ошибка при получении ChEMBL ID для UniProt {uniprot_id}: {e}")
        return None

def search_gene_in_uniprot_filtered(gene_name: str, organism: str = "Homo sapiens") -> Union[str, List[Dict]]:
    """Ищет информацию о гене в UniProt."""
    url = "https://rest.uniprot.org/uniprotkb/search"
    query = f'gene_exact:"{gene_name}" AND reviewed:true AND taxonomy_name:"{organism}"'
    
    params = {
        "query": query,
        "format": "json",
        "fields": "accession,gene_names,protein_name",
        "size": 10
    }
    
    try:
        response = session.get(url, params=params, timeout=30)
        response.raise_for_status()
        
        results = response.json().get("results", [])
        if not results:
            return f"No results found for gene '{gene_name}'"
        
        gene_info = [
            {
                "UniProt_ID": result["primaryAccession"],
                "Gene_Names": result["genes"][0]["geneName"]["value"] if result.get("genes") else "N/A",
                "Protein_Name": result["proteinDescription"]["recommendedName"]["fullName"]["value"],
            }
            for result in results
        ]
        
        for gene in gene_info:
            uniprot_id = gene["UniProt_ID"]
            chembl_id = uniprot_to_chembl(uniprot_id)
            gene["ChEMBL_ID"] = chembl_id if chembl_id else f"No ChEMBL ID found for {uniprot_id}"
            time.sleep(0.1)  # Задержка между запросами
        
        return gene_info
    except Exception as e:
        print(f"Ошибка при поиске гена {gene_name}: {e}")
        return f"Error searching gene {gene_name}: {str(e)}"

@lru_cache(maxsize=1000)
def get_parent_info(chembl_id: str) -> dict:
    """Получает информацию о родительском соединении для данного ChEMBL ID."""
    molecule = new_client.molecule
    molecule_form = new_client.molecule_form
    
    try:
        # Проверяем, есть ли родительское соединение
        parent_data = list(molecule_form.filter(molecule_chembl_id=chembl_id).only('parent_chembl_id'))
        
        if parent_data and 'parent_chembl_id' in parent_data[0]:
            parent_id = parent_data[0]['parent_chembl_id']
        else:
            # Если нет родителя, считаем текущий ID родительским
            parent_id = chembl_id
        
        # Получаем информацию о родительском соединении
        mol_data = list(molecule.filter(molecule_chembl_id=parent_id).only('pref_name', 'molecule_chembl_id'))
        pref_name = mol_data[0].get('pref_name', 'Unknown') if mol_data else 'Unknown'
        
        return {
            'parent_chembl_id': parent_id,
            'parent_pref_name': pref_name,
            'is_parent': parent_id == chembl_id
        }
    except Exception as e:
        print(f"Error getting parent info for {chembl_id}: {e}")
        return {
            'parent_chembl_id': chembl_id,
            'parent_pref_name': 'Unknown',
            'is_parent': True
        }

def filter_parent_drugs(drugs_list: List[Dict]) -> List[Dict]:
    """Фильтрует список препаратов, оставляя по одному представителю из каждого семейства.
       Сохраняет 'Yes' в Drug Mechanism при замене дочернего с 'Yes' на родительский."""
    parent_groups = {}
    
    # 1. Группируем все препараты по семействам
    for drug in drugs_list:
        try:
            if not drug.get('Drug ChEMBL ID'):
                continue
                
            parent_info = get_parent_info(drug['Drug ChEMBL ID'])
            parent_id = parent_info['parent_chembl_id']
            
            if parent_id not in parent_groups:
                parent_groups[parent_id] = {
                    'parent_info': parent_info,
                    'drugs': [],
                    'has_mechanism': False
                }
            
            parent_groups[parent_id]['drugs'].append(drug)
            if drug.get('Drug Mechanism ChEMBL') == 'Yes':
                parent_groups[parent_id]['has_mechanism'] = True
                
        except Exception as e:
            print(f"Ошибка при группировке препаратов: {e}")
            continue
    
    filtered_drugs = []
    
    # 2. Обрабатываем каждое семейство
    for parent_id, group in parent_groups.items():
        drugs_in_group = group['drugs']
        has_mechanism = group['has_mechanism']
        
        # Если в группе только один препарат - оставляем как есть
        if len(drugs_in_group) == 1:
            filtered_drugs.append(drugs_in_group[0])
            continue
        
        # Находим родительский препарат в группе
        parent_drug = next(
            (d for d in drugs_in_group if d['Drug ChEMBL ID'] == parent_id),
            None
        )
        
        # Если есть родительский препарат
        if parent_drug:
            # Если в семействе есть препараты с механизмом, сохраняем 'Yes' для родителя
            if has_mechanism:
                parent_drug['Drug Mechanism ChEMBL'] = 'Yes'
            filtered_drugs.append(parent_drug)
        else:
            # Если нет родительского - выбираем препарат с максимальным pChEMBL
            best_drug = max(
                drugs_in_group,
                key=lambda x: float(x['pChEMBL value']) if x.get('pChEMBL value', 'N/A') != 'N/A' else -1
            )
            filtered_drugs.append(best_drug)
    
    return filtered_drugs

def get_action_type(chembl_id: str) -> str:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        action_types = set()
        for mechanism in mechanisms:
            action_type = mechanism.get("action_type")
            if action_type:
                action_types.add(action_type)
        
        return "; ".join(action_types) if action_types else "N/A"
    except Exception as e:
        print(f"Ошибка при получении типа действия для {chembl_id}: {e}")
        return "N/A"

def get_mechanism_details(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        details = []
        for mechanism in mechanisms:
            mechanism_of_action = mechanism.get("mechanism_of_action", "N/A")
            
            details.append({
                "Mechanism of Action ChEMBL": mechanism_of_action,  # Изменено здесь
            })
        
        return details if details else [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь
    except Exception as e:
        print(f"Ошибка при получении механизма действия для {chembl_id}: {e}")
        return [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь

def get_max_phase(chembl_id: str) -> str:
    try:
        client = new_client
        molecule = client.molecule.get(chembl_id)
        max_phase = molecule.get("max_phase", None)
        
        if max_phase is None:
            return ""
        
        if max_phase == "0.0":
            return "Preclinical"
        elif max_phase == "1.0":
            return "Phase 1"
        elif max_phase == "2.0":
            return "Phase 2"
        elif max_phase == "3.0":
            return "Phase 3"
        elif max_phase == "4.0":
            return "Approved"
        else:
            return f"Unknown phase ({max_phase})"
    except Exception as e:
        print(f"Ошибка при получении фазы для {chembl_id}: {e}")
        return "N/A"

def get_pchembl_value(molecule_chembl_id: str, target_chembl_id: str) -> str:
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            pchembl_value__isnull=False
        ).only("pchembl_value")
        return activities[0]["pchembl_value"] if activities else "N/A"
    except Exception as e:
        print(f"Error fetching pChEMBL value for {molecule_chembl_id}: {e}")
        return "N/A"

def get_activity_data(molecule_chembl_id: str, target_chembl_id: str) -> Dict:
    """Возвращает объединенные данные активности: значение + единицы измерения"""
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).only("standard_value", "standard_type", "standard_units")
        
        if not activities:
            return {
                "Activity value ChEMBL": "N/A",
                "Activity type ChEMBL": "N/A"
            }
        
        activity = activities[0]
        value = activity.get('standard_value')
        units = activity.get('standard_units')
        act_type = activity.get('standard_type')
        
        if act_type == "Activity":
            act_type = "N/A"
        
        if value and units and value != "N/A" and units != "N/A":
            activity_value = f"= {value} {units}"
        else:
            activity_value = "N/A"
        
        return {
            "Activity value ChEMBL": activity_value,
            "Activity type ChEMBL": act_type
        }
    except Exception as e:
        print(f"Ошибка при получении данных активности для {molecule_chembl_id}: {e}")
        return {
            "Activity value ChEMBL": "N/A",
            "Activity type ChEMBL": "N/A"
        }

def get_drugs_for_target(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        
        mechanism_drugs = []
        mechanisms = client.mechanism.filter(target_chembl_id=chembl_id)
        for mech in mechanisms:
            try:
                drug_id = mech['molecule_chembl_id']
                drug = client.molecule.get(drug_id)
                
                activity_data = get_activity_data(drug_id, chembl_id)
                mechanism_details = get_mechanism_details(drug_id)
                
                if not mechanism_details:
                    print(f"Нет данных о механизме для {drug_id}")
                    continue
                    
                mechanism_drugs.append({
                    "Drug ChEMBL ID": drug_id,
                    "Drug name": drug.get('pref_name', 'N/A'),
                    "Drug Mechanism ChEMBL": "Yes",
                    "Activity value ChEMBL": activity_data["Activity value ChEMBL"],
                    "Activity type ChEMBL": activity_data["Activity type ChEMBL"],
                    "pChEMBL value": get_pchembl_value(drug_id, chembl_id),
                    "Max phase ChEMBL": get_max_phase(drug_id),
                    "Action type ChEMBL": get_action_type(drug_id),
                    "Mechanism of Action ChEMBL": mechanism_details[0]["Mechanism of Action ChEMBL"]
                })
                time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке механизма {mech.get('molecule_chembl_id')}: {str(e)}")
                continue
        
        mechanism_ids = {drug["Drug ChEMBL ID"] for drug in mechanism_drugs}
        activity_drugs = []
        
        activities = client.activity.filter(
            target_chembl_id=chembl_id,
            pchembl_value__isnull=False,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).order_by('-pchembl_value')[:100]
        
        for activity in activities:
            try:
                if activity['molecule_chembl_id'] not in mechanism_ids:
                    value = activity.get('standard_value', 'N/A')
                    units = activity.get('standard_units', 'N/A')
                    act_type = activity.get('standard_type', 'N/A')
                    
                    if act_type == "Activity":
                        act_type = "N/A"
                    
                    activity_value = f"= {value} {units}" if value != "N/A" and units != "N/A" else "N/A"
                    
                    activity_drugs.append({
                        "Drug ChEMBL ID": activity['molecule_chembl_id'],
                        "Drug name": activity['molecule_pref_name'],
                        "Drug Mechanism ChEMBL": "No",
                        "Activity value ChEMBL": activity_value,  # Исправлено
                        "Activity type ChEMBL": act_type,          # Исправлено
                        "pChEMBL value": activity['pchembl_value'],
                        "Max phase ChEMBL": get_max_phase(activity['molecule_chembl_id']),  # Исправлено
                        "Action type ChEMBL": get_action_type(activity['molecule_chembl_id']),  # Исправлено
                        "Mechanism of Action ChEMBL": "N/A"
                    })
                    time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке активности {activity}: {e}")
                continue
        
        all_drugs = mechanism_drugs + activity_drugs
        return filter_parent_drugs(all_drugs)
    except Exception as e:
        print(f"Ошибка при получении препаратов для цели {chembl_id}: {e}")
        return []

def get_gene_drug_info(gene_names: List[str]) -> List[Dict]:
    result = []
    
    for gene_name in gene_names:
        try:
            print(f"Обрабатывается ген: {gene_name}")
            gene_info_list = search_gene_in_uniprot_filtered(gene_name)
            
            if isinstance(gene_info_list, str):
                result.append({"Gene": gene_name, "Error": gene_info_list})
                continue
            
            unique_drugs_for_gene = {}

            for gene_info in gene_info_list:
                try:
                    if isinstance(gene_info['ChEMBL_ID'], str) and gene_info['ChEMBL_ID'].startswith("No ChEMBL"):
                        continue
                        
                    drugs = get_drugs_for_target(gene_info['ChEMBL_ID'])  # Только 1 аргумент!
                    
                    for drug in drugs:
                        chembl_id = drug["Drug ChEMBL ID"]
                        if chembl_id not in unique_drugs_for_gene or unique_drugs_for_gene[chembl_id]["pChEMBL value"] < drug["pChEMBL value"]:
                            unique_drugs_for_gene[chembl_id] = drug
                except Exception as e:
                    print(f"Ошибка при обработке информации о гене {gene_name}: {e}")
                    continue
            
            if not gene_info_list or 'UniProt_ID' not in gene_info_list[0]:
                continue
                
            for drug in unique_drugs_for_gene.values():
                result.append({
                    "Gene": gene_name,
                    "UniProt ID": gene_info_list[0]['UniProt_ID'],
                    "Protein name": gene_info_list[0]['Protein_Name'],
                    "Protein ChEMBL ID": gene_info_list[0]['ChEMBL_ID'],
                    **drug
                })
                
        except Exception as e:
            print(f"Ошибка при обработке гена {gene_name}: {e}")
            result.append({"Gene": gene_name, "Error": str(e)})
            continue

    return result

if __name__ == "__main__":
    # Замените этот путь на ваш реальный путь к файлу
    input_file = r"C:\Users\rusla\OneDrive\Рабочий стол\Диплом\Гены\thresholds\gene_selection\ALL\ALL_depscore_-0.2_zscore_-0.5.csv"
    
    # Чтение генов из файла
    try:
        genes_df = pd.read_csv(input_file)
        gene_names = genes_df['Gene'].tolist()
        print(f"Загружено {len(gene_names)} генов из файла")
    except Exception as e:
        print(f"Ошибка при чтении файла {input_file}: {e}")
        raise
    
    # Получаем имя выходного файла (без пути)
    output_filename = os.path.basename(input_file)
    
    start_time = time.time()
    print("\nНачинаем обработку с динамической фильтрацией pChEMBL")
    
    try:
        gene_drug_info = get_gene_drug_info(gene_names)
        
        # Определяем полный список всех возможных колонок
        all_columns = [
            "Gene", "UniProt ID", "Protein name", "Protein ChEMBL ID",
            "Drug ChEMBL ID", "Drug name", "Drug Mechanism ChEMBL",
            "Activity type ChEMBL", "Activity value ChEMBL",
            "pChEMBL value", "Max phase ChEMBL", "Action type ChEMBL", 
            "Mechanism of Action ChEMBL"
        ]
        
        # Создаем DataFrame из результатов
        df = pd.DataFrame(gene_drug_info)
        
        # Добавляем отсутствующие колонки и заполняем их NA
        for col in all_columns:
            if col not in df.columns:
                df[col] = pd.NA
        
        # Упорядочиваем колонки согласно нашему списку
        df = df[all_columns]
        
        # Фильтруем ошибочные записи (где нет Drug ChEMBL ID)
        df = df[df['Drug ChEMBL ID'].notna()]
        
        # Сохраняем в текущую директорию с тем же именем файла
        df.to_csv(output_filename, index=False, encoding='utf-8')
        
        elapsed_time = time.time() - start_time
        
        # Собираем статистику
        num_drugs = len(df)
        num_mechanisms = len(df[df['Drug Mechanism ChEMBL'] == 'Yes'])
        
        print(f"Файл {output_filename} сохранён. Время выполнения: {elapsed_time:.2f} секунд")
        print(f"Статистика: {num_drugs} препаратов, из них {num_mechanisms} с известным механизмом")
        
    except Exception as e:
        print(f"Критическая ошибка при обработке: {e}")
# Out:
# Загружено 907 генов из файла
#
# Начинаем обработку с динамической фильтрацией pChEMBL
# Обрабатывается ген: ABHD11
# Обрабатывается ген: ACAP3
# Обрабатывается ген: ACIN1
# Обрабатывается ген: ACLY
# Обрабатывается ген: ACO2
# Обрабатывается ген: ACSL4
# Обрабатывается ген: ACTL6A
# Обрабатывается ген: ACTR10
# Обрабатывается ген: ADGRB2
# Обрабатывается ген: ADSL
# Обрабатывается ген: ADSS2
# Обрабатывается ген: AES
# Обрабатывается ген: AGPS
# Обрабатывается ген: AHCY
# Обрабатывается ген: AHDC1
# Обрабатывается ген: AJM1
# Обрабатывается ген: AK2
# Обрабатывается ген: AKAP17A
# Обрабатывается ген: ALAD
# Обрабатывается ген: ALAS1
# Обрабатывается ген: ALYREF
# Обрабатывается ген: ANAPC7
# Обрабатывается ген: ANKH
# Обрабатывается ген: ANKRD36
# Обрабатывается ген: ANKRD62P1-PARP4P3
# Обрабатывается ген: ANKUB1
# Обрабатывается ген: AP1M1
# Обрабатывается ген: AP2M1
# Обрабатывается ген: AP2S1
# Обрабатывается ген: APC
# Обрабатывается ген: APOBEC3F
# Обрабатывается ген: AQR
# Обрабатывается ген: ARHGAP19-SLIT1
# Обрабатывается ген: ARHGAP45
# Обрабатывается ген: ARID1A
# Обрабатывается ген: ARL6IP4
# Обрабатывается ген: ARMH3
# Обрабатывается ген: ATF7
# Обрабатывается ген: ATIC
# Обрабатывается ген: ATP1B3
# Обрабатывается ген: ATP2C1
# Обрабатывается ген: ATP5F1E
# Обрабатывается ген: ATP5MG
# Обрабатывается ген: ATP6AP1
# Обрабатывается ген: ATP6AP2
# Обрабатывается ген: ATP6V0A2
# Обрабатывается ген: ATP6V0C
# Обрабатывается ген: ATP6V1E1
# Обрабатывается ген: ATRX
# Обрабатывается ген: ATXN2
# Обрабатывается ген: ATXN2L
# Обрабатывается ген: BAGE
# Обрабатывается ген: BAGE5
# Обрабатывается ген: BANF1
# Обрабатывается ген: BBC3
# Обрабатывается ген: BCL2
# Обрабатывается ген: BCS1L
# Обрабатывается ген: BIRC8
# Обрабатывается ген: BRD4
# Обрабатывается ген: BRI3
# Обрабатывается ген: BRIP1
# Обрабатывается ген: BTNL2
# Обрабатывается ген: C10orf95
# Обрабатывается ген: C14orf2
# Обрабатывается ген: C15orf38-AP3S2
# Обрабатывается ген: C16orf52
# Обрабатывается ген: C16orf62
# Обрабатывается ген: C17orf77
# Обрабатывается ген: C17orf82
# Обрабатывается ген: C1QTNF5&MFRP
# Обрабатывается ген: C1orf109
# Обрабатывается ген: C1orf228
# Обрабатывается ген: C1orf27
# Обрабатывается ген: C4orf32
# Обрабатывается ген: C8orf44-SGK3
# Обрабатывается ген: CAB39
# Обрабатывается ген: CAD
# Обрабатывается ген: CAPNS1
# Обрабатывается ген: CARM1
# Обрабатывается ген: CARS2
# Обрабатывается ген: CBFB
# Обрабатывается ген: CBWD1
# Обрабатывается ген: CCDC115
# Обрабатывается ген: CCDC154
# Обрабатывается ген: CCDC155
# Обрабатывается ген: CCDC168
# Обрабатывается ген: CCDC47
# Обрабатывается ген: CCDC93
# Обрабатывается ген: CCM2
# Обрабатывается ген: CCNC
# Обрабатывается ген: CCND3
# Обрабатывается ген: CCNYL2
# Обрабатывается ген: CD19
# Обрабатывается ген: CD3EAP
# Обрабатывается ген: CDAN1
# Обрабатывается ген: CDC25A
# Обрабатывается ген: CDIN1
# Обрабатывается ген: CDK6
# Обрабатывается ген: CDS2
# Обрабатывается ген: CEND1
# Обрабатывается ген: CEP350
# Обрабатывается ген: CEP43
# Обрабатывается ген: CEP55
# Обрабатывается ген: CFC1&CFC1B
# Обрабатывается ген: CFL1
# Обрабатывается ген: CHCHD3
# Обрабатывается ген: CHD7
# Обрабатывается ген: CHD8
# Обрабатывается ген: CIAO1
# Обрабатывается ген: CKMT1B
# Обрабатывается ген: CLDN19
# Обрабатывается ген: CLTC
# Обрабатывается ген: CMIP
# Обрабатывается ген: COA5
# Обрабатывается ген: COA6
# Обрабатывается ген: COA7
# Обрабатывается ген: COMT
# Обрабатывается ген: COQ2
# Обрабатывается ген: COQ3
# Обрабатывается ген: COQ4
# Обрабатывается ген: COQ5
# Обрабатывается ген: COQ7
# Обрабатывается ген: COX14
# Обрабатывается ген: COX16
# Обрабатывается ген: COX17
# Обрабатывается ген: COX5B
# Обрабатывается ген: COX6A1
# Обрабатывается ген: COX6B1
# Обрабатывается ген: COX6C
# Обрабатывается ген: COX7B
# Обрабатывается ген: CPOX
# Обрабатывается ген: CRACDL
# Обрабатывается ген: CRACR2B
# Обрабатывается ген: CROCC
# Обрабатывается ген: CSH1
# Обрабатывается ген: CSK
# Обрабатывается ген: CSPG4
# Обрабатывается ген: CTBP1
# Обрабатывается ген: CTBP2
# Обрабатывается ген: CTGF
# Обрабатывается ген: CTPS1
# Обрабатывается ген: CTRB1&CTRB2
# Обрабатывается ген: CXCL1
# Обрабатывается ген: CXorf40B
# Обрабатывается ген: CYC1
# Обрабатывается ген: DAP3
# Обрабатывается ген: DARS2
# Обрабатывается ген: DCAF15
# Обрабатывается ген: DCAF7
# Обрабатывается ген: DCPS
# Обрабатывается ген: DDX39A
# Обрабатывается ген: DDX3Y
# Обрабатывается ген: DEC1
# Обрабатывается ген: DENND4A
# Обрабатывается ген: DHFR
# Обрабатывается ген: DHODH
# Обрабатывается ген: DHX29
# Обрабатывается ген: DKC1
# Обрабатывается ген: DLD
# Обрабатывается ген: DLST
# Обрабатывается ген: DMRTB1
# Обрабатывается ген: DNAJB11
# Обрабатывается ген: DNAJC9
# Обрабатывается ген: DNLZ
# Обрабатывается ген: DNM2
# Обрабатывается ген: DNMT1
# Обрабатывается ген: DOLK
# Обрабатывается ген: DOPEY2
# Обрабатывается ген: DOT1L
# Обрабатывается ген: DPF2
# Обрабатывается ген: DPH1
# Обрабатывается ген: DPH3
# Обрабатывается ген: DPH6
# Обрабатывается ген: DPH7
# Обрабатывается ген: DPY30
# Обрабатывается ген: DROSHA
# Обрабатывается ген: DTYMK
# Обрабатывается ген: DUOX2
# Обрабатывается ген: DUSP22
# Обрабатывается ген: DYNC1LI1
# Обрабатывается ген: EBF1
# Обрабатывается ген: EEF1D
# Обрабатывается ген: EEF1G
# Обрабатывается ген: EEF2
# Обрабатывается ген: EEFSEC
# Обрабатывается ген: EFHD2
# Обрабатывается ген: EIF3B
# Обрабатывается ген: EIF3K
# Обрабатывается ген: EIF4E2
# Обрабатывается ген: EIF4G1
# Обрабатывается ген: EIF5A
# Обрабатывается ген: ELOB
# Error getting parent info for CHEMBL4227226: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Обрабатывается ген: ELOF1
# Обрабатывается ген: EMC1
# Обрабатывается ген: EMC2
# Обрабатывается ген: EMC3
# Обрабатывается ген: EMC4
# Обрабатывается ген: EMC6
# Обрабатывается ген: EMC7
# Обрабатывается ген: EMC8
# Обрабатывается ген: EML6
# Обрабатывается ген: EP300
# Обрабатывается ген: EP400
# Обрабатывается ген: EPHA10
# Обрабатывается ген: EPSTI1
# Обрабатывается ген: ERCC1
# Обрабатывается ген: ERG
# Обрабатывается ген: ESPNP
# Обрабатывается ген: ESYT1
# Обрабатывается ген: EXTL1
# Обрабатывается ген: EZH2
# Обрабатывается ген: FAAP100
# Обрабатывается ген: FAM104B
# Обрабатывается ген: FAM157A
# Обрабатывается ген: FAM19A4
# Обрабатывается ген: FAM19A5
# Обрабатывается ген: FAM214B
# Обрабатывается ген: FAM26E
# Обрабатывается ген: FAM45BP
# Обрабатывается ген: FAM50A
# Обрабатывается ген: FAM74A6
# Обрабатывается ген: FAM83C
# Обрабатывается ген: FANCA
# Обрабатывается ген: FANCD2
# Обрабатывается ген: FANCI
# Обрабатывается ген: FANCL
# Обрабатывается ген: FAR1
# Обрабатывается ген: FARS2
# Обрабатывается ген: FASTKD5
# Обрабатывается ген: FCGR1B
# Обрабатывается ген: FCHO1
# Обрабатывается ген: FDPS
# Обрабатывается ген: FDX1
# Обрабатывается ген: FDXR
# Обрабатывается ген: FECH
# Обрабатывается ген: FEN1
# Обрабатывается ген: FER1L6-AS1
# Обрабатывается ген: FH
# Обрабатывается ген: FKBP1A
# Обрабатывается ген: FLCN
# Обрабатывается ген: FLJ40194
# Обрабатывается ген: FLJ42393
# Обрабатывается ген: FLOT2
# Обрабатывается ген: FLT3
# Обрабатывается ген: FNDC10
# Обрабатывается ген: FOXI3
# Обрабатывается ген: FOXO1
# Обрабатывается ген: FPGS
# Обрабатывается ген: FTCD
# Обрабатывается ген: FUK
# Обрабатывается ген: FUT4
# Обрабатывается ген: G6PD
# Обрабатывается ген: GABARAP
# Обрабатывается ген: GABPA
# Обрабатывается ген: GABPB1
# Обрабатывается ген: GALE
# Обрабатывается ген: GAPDH
# Обрабатывается ген: GAREM2
# Обрабатывается ген: GART
# Обрабатывается ген: GATA3
# Обрабатывается ген: GATB
# Обрабатывается ген: GCLC
# Обрабатывается ген: GCSH
# Обрабатывается ген: GFM1
# Обрабатывается ген: GFPT1
# Обрабатывается ген: GFUS
# Обрабатывается ген: GIGYF2
# Обрабатывается ген: GIP
# Обрабатывается ген: GJC3
# Обрабатывается ген: GLRX5
# Обрабатывается ген: GMPPB
# Обрабатывается ген: GNB3
# Обрабатывается ген: GNE
# Обрабатывается ген: GOLGA8S
# Обрабатывается ген: GOT2
# Обрабатывается ген: GPR137
# Обрабатывается ген: GPX4
# Обрабатывается ген: GS1-124K5.11
# Обрабатывается ген: GTF2H2
# Обрабатывается ген: GTF2H3
# Обрабатывается ген: GTF2H5
# Обрабатывается ген: GTF2IRD2B
# Обрабатывается ген: GTPBP3
# Обрабатывается ген: GTPBP8
# Обрабатывается ген: GUCY1B2
# Обрабатывается ген: GUCY2EP
# Обрабатывается ген: H2AC16
# Обрабатывается ген: H2AC6
# Обрабатывается ген: H2AJ
# Обрабатывается ген: H2AZ1
# Обрабатывается ген: H2BC10
# Обрабатывается ген: H2BC11
# Обрабатывается ген: H2BC13
# Обрабатывается ген: H2BC14
# Обрабатывается ген: H2BC3
# Обрабатывается ген: H2BC4
# Обрабатывается ген: H2BC5
# Обрабатывается ген: H2BC6
# Обрабатывается ген: H2BC8
# Обрабатывается ген: H3-3A
# Обрабатывается ген: H3C2
# Обрабатывается ген: H3C3
# Обрабатывается ген: H3C4
# Обрабатывается ген: H3C7
# Обрабатывается ген: HBS1L
# Обрабатывается ген: HCCS
# Обрабатывается ген: HCFC1
# Обрабатывается ген: HDAC1
# Обрабатывается ген: HEATR5B
# Обрабатывается ген: HEATR6
# Обрабатывается ген: HES3
# Обрабатывается ген: HFE2
# Обрабатывается ген: HGS
# Обрабатывается ген: HID1
# Обрабатывается ген: HIF1AN
# Обрабатывается ген: HIST1H2AC
# Обрабатывается ген: HIST1H2BH
# Обрабатывается ген: HIST1H2BO
# Обрабатывается ген: HIST1H4C
# Обрабатывается ген: HIST2H4B&HIST2H4A
# Обрабатывается ген: HJURP
# Обрабатывается ген: HLA-DRB4
# Обрабатывается ген: HMBS
# Обрабатывается ген: HMGB1
# Обрабатывается ген: HMX3
# Обрабатывается ген: HNRNPA1
# Обрабатывается ген: HOXC13
# Обрабатывается ген: HRK
# Обрабатывается ген: HSD17B10
# Обрабатывается ген: HSFY2&HSFY1
# Обрабатывается ген: HSH2D
# Обрабатывается ген: HSP90AA1
# Обрабатывается ген: HSPA5
# Обрабатывается ген: HSPA7
# Обрабатывается ген: HSPA8
# Обрабатывается ген: HSPB7
# Обрабатывается ген: IBA57
# Обрабатывается ген: ID3
# Обрабатывается ген: IFITM2
# Обрабатывается ген: IFNL2&IFNL3
# Обрабатывается ген: IFNLR1
# Обрабатывается ген: IGFALS
# Обрабатывается ген: IGLL1
# Обрабатывается ген: IGSF3
# Обрабатывается ген: IKZF1
# Обрабатывается ген: IMPDH2
# Обрабатывается ген: INO80
# Обрабатывается ген: IPPK
# Обрабатывается ген: IRF4
# Обрабатывается ген: ISCA1
# Обрабатывается ген: ISG20
# Обрабатывается ген: IWS1
# Обрабатывается ген: JADE3
# Обрабатывается ген: KAT2A
# Обрабатывается ген: KCNJ12
# Обрабатывается ген: KCTD5
# Обрабатывается ген: KDM2B
# Обрабатывается ген: KDM5C
# Обрабатывается ген: KEAP1
# Обрабатывается ген: KIR2DL5B&KIR2DL5A
# Обрабатывается ген: KIR3DS1
# Обрабатывается ген: KLHDC8A
# Обрабатывается ген: KLRA1P
# Обрабатывается ген: KMT5A
# Обрабатывается ген: KRT6A
# Обрабатывается ген: KRTAP10-11
# Обрабатывается ген: KRTAP10-9
# Обрабатывается ген: KRTAP5-1
# Обрабатывается ген: KRTAP5-10
# Обрабатывается ген: KRTAP5-3
# Обрабатывается ген: L3MBTL1
# Обрабатывается ген: LAGE3
# Обрабатывается ген: LARS2
# Обрабатывается ген: LCE1F
# Обрабатывается ген: LCE2C
# Обрабатывается ген: LCMT2
# Обрабатывается ген: LCN10
# Обрабатывается ген: LDB1
# Обрабатывается ген: LEF1
# Обрабатывается ген: LEMD3
# Обрабатывается ген: LGI1
# Обрабатывается ген: LHX4
# Обрабатывается ген: LIAS
# Обрабатывается ген: LIG1
# Обрабатывается ген: LINC00518
# Обрабатывается ген: LINC00523
# Обрабатывается ген: LINC01140
# Обрабатывается ген: LIPT1
# Обрабатывается ген: LIPT2
# Обрабатывается ген: LOC101929540
# Обрабатывается ген: LOC101929775
# Обрабатывается ген: LOC102724770&DGCR6
# Обрабатывается ген: LOC102724985&PDXDC1
# Обрабатывается ген: LOC105369243&SULT1A4&SULT1A3
# Обрабатывается ген: LOC107984021
# Обрабатывается ген: LOC107984065
# Обрабатывается ген: LOC107986988
# Обрабатывается ген: LOC107987188
# Обрабатывается ген: LOC341056
# Обрабатывается ген: LOC400710
# Обрабатывается ген: LOC440434
# Обрабатывается ген: LOC606724
# Обрабатывается ген: LOC641367
# Обрабатывается ген: LOC644762
# Обрабатывается ген: LOC644936
# Обрабатывается ген: LOC645752
# Обрабатывается ген: LRP5
# Обрабатывается ген: LRP8
# Обрабатывается ген: LRRC57
# Обрабатывается ген: LTV1
# Обрабатывается ген: LYNX1
# Обрабатывается ген: MAD1L1
# Обрабатывается ген: MAGEA3
# Обрабатывается ген: MAGOH
# Обрабатывается ген: MAML1
# Обрабатывается ген: MAN1C1
# Обрабатывается ген: MANF
# Обрабатывается ген: MAPK14
# Обрабатывается ген: MAPK6
# Обрабатывается ген: MAST2
# Обрабатывается ген: MAU2
# Обрабатывается ген: MBNL1
# Обрабатывается ген: MCAT
# Обрабатывается ген: MDH2
# Обрабатывается ген: MEAF6
# Обрабатывается ген: MECR
# Обрабатывается ген: MED10
# Обрабатывается ген: MED12
# Обрабатывается ген: MED13L
# Обрабатывается ген: MED15
# Обрабатывается ген: MED16
# Обрабатывается ген: MED19
# Обрабатывается ген: MED23
# Обрабатывается ген: MED24
# Обрабатывается ген: MEF2C
# Обрабатывается ген: MEN1
# Обрабатывается ген: METTL1
# Обрабатывается ген: METTL16
# Обрабатывается ген: MFSD3
# Обрабатывается ген: MGAT1
# Обрабатывается ген: MIB2
# Обрабатывается ген: MICOS10
# Обрабатывается ген: MINDY2
# Обрабатывается ген: MINOS1-NBL1&NBL1
# Обрабатывается ген: MIOS
# Обрабатывается ген: MIR429
# Обрабатывается ген: MLST8
# Обрабатывается ген: MMEL1
# Обрабатывается ген: MMGT1
# Обрабатывается ген: MMP23B
# Обрабатывается ген: MMS22L
# Обрабатывается ген: MON1A
# Обрабатывается ген: MORF4L1
# Обрабатывается ген: MOS
# Обрабатывается ген: MPV17
# Обрабатывается ген: MRE11
# Обрабатывается ген: MRGBP
# Обрабатывается ген: MRPL11
# Обрабатывается ген: MRPL12
# Обрабатывается ген: MRPL18
# Обрабатывается ген: MRPL20
# Обрабатывается ген: MRPL21
# Обрабатывается ген: MRPL22
# Обрабатывается ген: MRPL24
# Обрабатывается ген: MRPL34
# Обрабатывается ген: MRPL41
# Обрабатывается ген: MRPL43
# Обрабатывается ген: MRPL47
# Обрабатывается ген: MRPL48
# Обрабатывается ген: MRPL52
# Обрабатывается ген: MRPL55
# Обрабатывается ген: MRPS14
# Обрабатывается ген: MRPS16
# Обрабатывается ген: MRPS17
# Обрабатывается ген: MRPS2
# Обрабатывается ген: MRPS22
# Обрабатывается ген: MRPS23
# Обрабатывается ген: MRPS24
# Обрабатывается ген: MRPS25
# Обрабатывается ген: MRPS26
# Обрабатывается ген: MRPS30
# Обрабатывается ген: MRPS33
# Обрабатывается ген: MRPS36
# Обрабатывается ген: MSI2
# Обрабатывается ген: MSL3P1
# Обрабатывается ген: MT1A
# Обрабатывается ген: MT1B
# Обрабатывается ген: MT2A
# Обрабатывается ген: MTBP
# Обрабатывается ген: MTF1
# Обрабатывается ген: MTG1
# Обрабатывается ген: MTG2
# Обрабатывается ген: MTHFD1
# Обрабатывается ген: MTO1
# Обрабатывается ген: MUM1L1
# Обрабатывается ген: MVD
# Обрабатывается ген: MXRA7
# Обрабатывается ген: MYB
# Обрабатывается ген: MYBL2
# Обрабатывается ген: MYC
# Обрабатывается ген: MYO15A
# Обрабатывается ген: MZF1
# Обрабатывается ген: N6AMT1
# Обрабатывается ген: NAA10
# Обрабатывается ген: NAMPT
# Обрабатывается ген: NAPRT
# Обрабатывается ген: NARS2
# Обрабатывается ген: NCKAP1L
# Обрабатывается ген: NCLN
# Обрабатывается ген: NDUFA4
# Обрабатывается ген: NELFB
# Обрабатывается ген: NELFE
# Обрабатывается ген: NGRN
# Обрабатывается ген: NIPBL
# Обрабатывается ген: NMNAT1
# Обрабатывается ген: NOL3
# Обрабатывается ген: NOL6
# Обрабатывается ген: NOTUM
# Обрабатывается ген: NR2E3
# Обрабатывается ген: NRBP1
# Обрабатывается ген: NSA2
# Обрабатывается ген: NSL1
# Обрабатывается ген: NUDT18
# Обрабатывается ген: NUFIP2
# Обрабатывается ген: NUP37
# Обрабатывается ген: OGDH
# Обрабатывается ген: OR10G9
# Обрабатывается ген: OR10H2
# Обрабатывается ген: OR12D2
# Обрабатывается ген: OR1I1
# Обрабатывается ген: OR2A14
# Обрабатывается ген: OR2F1
# Обрабатывается ген: OR2M7
# Обрабатывается ген: OR2T8
# Обрабатывается ген: OR8B12
# Обрабатывается ген: OR8D2
# Обрабатывается ген: OSBPL2
# Обрабатывается ген: OTUD7A
# Обрабатывается ген: OXSM
# Обрабатывается ген: P3H4
# Обрабатывается ген: PABPN1
# Обрабатывается ген: PAICS
# Обрабатывается ген: PARS2
# Обрабатывается ген: PAX5
# Обрабатывается ген: PAXIP1
# Обрабатывается ген: PCYT2
# Обрабатывается ген: PDAP1
# Обрабатывается ген: PDCD6
# Обрабатывается ген: PDPK1
# Обрабатывается ген: PDRG1
# Обрабатывается ген: PDSS1
# Обрабатывается ген: PDSS2
# Обрабатывается ген: PDXK
# Обрабатывается ген: PEDS1
# Обрабатывается ген: PELO
# Обрабатывается ген: PER2
# Обрабатывается ген: PERP
# Обрабатывается ген: PET100
# Обрабатывается ген: PET117
# Обрабатывается ген: PEX7
# Обрабатывается ген: PFAS
# Обрабатывается ген: PGAP3
# Обрабатывается ген: PGAP6
# Обрабатывается ген: PI4KB
# Обрабатывается ген: PIK3CD
# Обрабатывается ген: PIM2
# Обрабатывается ген: PIM3
# Обрабатывается ген: PIMREG
# Обрабатывается ген: PISD
# Обрабатывается ген: PKD1L2
# Обрабатывается ген: PLAGL2
# Обрабатывается ген: PLEKHN1
# Обрабатывается ген: PLK4
# Обрабатывается ген: PLRG1
# Обрабатывается ген: PMM2
# Обрабатывается ген: PMS2P2
# Обрабатывается ген: PMVK
# Обрабатывается ген: PNPT1
# Обрабатывается ген: POLR1B
# Обрабатывается ген: POLR2L
# Обрабатывается ген: POLR3K
# Обрабатывается ген: POT1
# Обрабатывается ген: POU2AF1
# Обрабатывается ген: PPA2
# Обрабатывается ген: PPAN-P2RY11
# Обрабатывается ген: PPAT
# Обрабатывается ген: PPCDC
# Обрабатывается ген: PPCS
# Обрабатывается ген: PPIL1
# Обрабатывается ген: PPOX
# Обрабатывается ген: PPP2CA
# Обрабатывается ген: PPP2R3C
# Обрабатывается ген: PPP4C
# Обрабатывается ген: PPY
# Обрабатывается ген: PQBP1
# Обрабатывается ген: PQLC1
# Обрабатывается ген: PRAMEF18
# Обрабатывается ген: PRAMEF20
# Обрабатывается ген: PRB2
# Обрабатывается ген: PRC1
# Обрабатывается ген: PRCC
# Обрабатывается ген: PRDX3
# Обрабатывается ген: PRDX6
# Обрабатывается ген: PRELID1
# Обрабатывается ген: PRIM1
# Обрабатывается ген: PRKAR1A
# Обрабатывается ген: PRMT5
# Обрабатывается ген: PRPF6
# Обрабатывается ген: PRR22
# Обрабатывается ген: PRR30
# Обрабатывается ген: PSENEN
# Обрабатывается ген: PSMD2
# Обрабатывается ген: PSTK
# Обрабатывается ген: PTCD1
# Обрабатывается ген: PTCH2
# Обрабатывается ген: PTMA
# Обрабатывается ген: PTP4A2
# Обрабатывается ген: PTPN23
# Обрабатывается ген: PTPRQ
# Обрабатывается ген: PUS3
# Обрабатывается ген: PYM1
# Обрабатывается ген: RAB3A
# Обрабатывается ген: RAB5IF
# Обрабатывается ген: RAB6C-AS1
# Обрабатывается ген: RABIF
# Обрабатывается ген: RACK1
# Обрабатывается ген: RAD21
# Обрабатывается ген: RAD54L2
# Обрабатывается ген: RARS
# Обрабатывается ген: RASAL1
# Обрабатывается ген: RBFA
# Обрабатывается ген: RBSN
# Обрабатывается ген: RER1
# Обрабатывается ген: RERE
# Обрабатывается ген: RFC4
# Обрабатывается ген: RFC5
# Обрабатывается ген: RFK
# Обрабатывается ген: RFWD2
# Обрабатывается ген: RFWD3
# Обрабатывается ген: RGPD3
# Обрабатывается ген: RHBDF1
# Обрабатывается ген: RHOA
# Обрабатывается ген: RHOXF2B&RHOXF2
# Обрабатывается ген: RICTOR
# Обрабатывается ген: RILP
# Обрабатывается ген: RNASEH2A
# Обрабатывается ген: RNASEH2C
# Обрабатывается ген: RND1
# Обрабатывается ген: RNF11
# Обрабатывается ген: RNF219
# Обрабатывается ген: RPE
# Обрабатывается ген: RPF2
# Обрабатывается ген: RPIA
# Обрабатывается ген: RPL10A
# Обрабатывается ген: RPL13AP20
# Обрабатывается ген: RPL18
# Обрабатывается ген: RPL26
# Обрабатывается ген: RPL27A
# Обрабатывается ген: RPL30
# Обрабатывается ген: RPL37A
# Обрабатывается ген: RPL38
# Обрабатывается ген: RPL4
# Обрабатывается ген: RPL5
# Обрабатывается ген: RPL7
# Обрабатывается ген: RPL7A
# Обрабатывается ген: RPL8
# Обрабатывается ген: RPLP1
# Обрабатывается ген: RPLP2
# Обрабатывается ген: RPP25L
# Обрабатывается ген: RPS10-NUDT3
# Обрабатывается ген: RPS16
# Обрабатывается ген: RPS18
# Обрабатывается ген: RPS21
# Обрабатывается ген: RPS24
# Обрабатывается ген: RPS26
# Обрабатывается ген: RPS27A
# Обрабатывается ген: RPSAP9
# Обрабатывается ген: RPUSD3
# Обрабатывается ген: RSL24D1
# Обрабатывается ген: RTEL1
# Обрабатывается ген: RUFY4
# Обрабатывается ген: RUNX1
# Обрабатывается ген: RUVBL1
# Обрабатывается ген: RYK
# Обрабатывается ген: SARS2
# Обрабатывается ген: SATB1
# Обрабатывается ген: SCARF1
# Обрабатывается ген: SCN8A
# Обрабатывается ген: SCO1
# Обрабатывается ген: SCO2
# Обрабатывается ген: SDHA
# Обрабатывается ген: SDHAF2
# Обрабатывается ген: SDHB
# Обрабатывается ген: SDHC
# Обрабатывается ген: SDHD
# Обрабатывается ген: SDR9C7
# Обрабатывается ген: SEC24A
# Обрабатывается ген: SECISBP2
# Обрабатывается ген: SEH1L
# Обрабатывается ген: SEL1L
# Обрабатывается ген: SEMA3F
# Обрабатывается ген: SEPHS2
# Обрабатывается ген: SEPSECS
# Обрабатывается ген: SEPT7
# Обрабатывается ген: SETD1B
# Обрабатывается ген: SF3B4
# Обрабатывается ген: SFT2D3
# Обрабатывается ген: SGF29
# Обрабатывается ген: SH3GL1
# Обрабатывается ген: SIRT7
# Обрабатывается ген: SKIC2
# Обрабатывается ген: SLC16A1
# Обрабатывается ген: SLC20A1
# Обрабатывается ген: SLC25A1
# Обрабатывается ген: SLC25A19
# Обрабатывается ген: SLC25A26
# Обрабатывается ген: SLC25A51
# Обрабатывается ген: SLC4A7
# Обрабатывается ген: SLC5A3
# Обрабатывается ген: SLC8B1
# Обрабатывается ген: SLX4
# Обрабатывается ген: SMARCA4
# Обрабатывается ген: SMARCA5
# Обрабатывается ген: SMARCB1
# Обрабатывается ген: SMARCC1
# Обрабатывается ген: SMARCD1
# Обрабатывается ген: SMARCD2
# Обрабатывается ген: SMARCE1
# Обрабатывается ген: SMPD5
# Обрабатывается ген: SMR3B
# Обрабатывается ген: SNAPC5
# Обрабатывается ген: SNRPB
# Обрабатывается ген: SNRPE
# Обрабатывается ген: SOD2
# Обрабатывается ген: SORD2P
# Обрабатывается ген: SPATA33
# Обрабатывается ген: SPRYD4
# Обрабатывается ген: SRM
# Обрабатывается ген: SRSF6
# Обрабатывается ген: SSBP1
# Обрабатывается ген: SSH1
# Обрабатывается ген: SSH2
# Обрабатывается ген: SSRP1
# Обрабатывается ген: STAG2
# Обрабатывается ген: STEAP3
# Обрабатывается ген: STK11
# Обрабатывается ген: STMN1
# Обрабатывается ген: STRIP1
# Обрабатывается ген: SUCLA2
# Обрабатывается ген: SUCLG1
# Обрабатывается ген: SUOX
# Обрабатывается ген: SUPT20H
# Обрабатывается ген: SUPT4H1
# Обрабатывается ген: SUPT7L
# Обрабатывается ген: SYK
# Обрабатывается ген: SYVN1
# Обрабатывается ген: TADA1
# Обрабатывается ген: TADA2B
# Обрабатывается ген: TAF10
# Обрабатывается ген: TAF11
# Обрабатывается ген: TAF13
# Обрабатывается ген: TAF1A
# Обрабатывается ген: TAF2
# Обрабатывается ген: TAF5L
# Обрабатывается ген: TAF6L
# Обрабатывается ген: TAFAZZIN
# Обрабатывается ген: TAMM41
# Обрабатывается ген: TARDBP
# Обрабатывается ген: TBC1D3J
# Обрабатывается ген: TBCD
# Обрабатывается ген: TBL1Y
# Обрабатывается ген: TCF12
# Обрабатывается ген: TCF3
# Обрабатывается ген: TCTN2
# Обрабатывается ген: TEDC1
# Обрабатывается ген: TEFM
# Обрабатывается ген: TEN1
# Обрабатывается ген: TEX44
# Обрабатывается ген: TFB2M
# Обрабатывается ген: TFRC
# Обрабатывается ген: TGFBRAP1
# Обрабатывается ген: THAP11
# Обрабатывается ген: THAP3
# Обрабатывается ген: THG1L
# Обрабатывается ген: THOC3
# Обрабатывается ген: THOC5
# Обрабатывается ген: TIE1
# Обрабатывается ген: TIMM13
# Обрабатывается ген: TKFC
# Обрабатывается ген: TKT
# Обрабатывается ген: TM4SF19-TCTEX1D2
# Обрабатывается ген: TMEM189
# Обрабатывается ген: TMEM30A
# Обрабатывается ген: TMEM41B
# Обрабатывается ген: TMEM57
# Обрабатывается ген: TMPRSS11BNL
# Обрабатывается ген: TMX1
# Обрабатывается ген: TMX2
# Обрабатывается ген: TNKS1BP1
# Обрабатывается ген: TNNT2
# Обрабатывается ген: TNS2
# Обрабатывается ген: TOMM20
# Обрабатывается ген: TOMM22
# Обрабатывается ген: TP53I3
# Обрабатывается ген: TPI1
# Обрабатывается ген: TPK1
# Обрабатывается ген: TPPP
# Обрабатывается ген: TPT1
# Обрабатывается ген: TPTE
# Обрабатывается ген: TRAF2
# Обрабатывается ген: TRAIP
# Обрабатывается ген: TRIM28
# Обрабатывается ген: TRIM49D2
# Обрабатывается ген: TRIM66
# Обрабатывается ген: TRIP6
# Обрабатывается ген: TRMT112
# Обрабатывается ген: TRNAU1AP
# Обрабатывается ген: TRPM7
# Обрабатывается ген: TRRAP
# Обрабатывается ген: TRUB2
# Обрабатывается ген: TSC2
# Обрабатывается ген: TTC14
# Обрабатывается ген: TTC22
# Обрабатывается ген: TTC27
# Обрабатывается ген: TTC39A
# Обрабатывается ген: TUBA1B
# Обрабатывается ген: TUBB
# Обрабатывается ген: TUBB8
# Обрабатывается ген: TUSC5
# Обрабатывается ген: TXN
# Обрабатывается ген: TYMS
# Обрабатывается ген: TYW1B
# Обрабатывается ген: UBA3
# Обрабатывается ген: UBALD2
# Обрабатывается ген: UBE2G2
# Обрабатывается ген: UBE2T
# Обрабатывается ген: UCN
# Обрабатывается ген: UGT2B10
# Обрабатывается ген: UMPS
# Обрабатывается ген: UNC13D
# Обрабатывается ген: UNK
# Обрабатывается ген: UPK3BL2
# Обрабатывается ген: UQCC1
# Обрабатывается ген: UQCC2
# Обрабатывается ген: UQCR10
# Обрабатывается ген: UQCRB
# Обрабатывается ген: UQCRC1
# Обрабатывается ген: UQCRC2
# Обрабатывается ген: URM1
# Обрабатывается ген: UROD
# Обрабатывается ген: UROS
# Обрабатывается ген: USH1G
# Обрабатывается ген: USP17L3
# Обрабатывается ген: USP34
# Обрабатывается ген: VARS2
# Обрабатывается ген: VMA21
# Обрабатывается ген: VPS18
# Обрабатывается ген: VPS33A
# Обрабатывается ген: VPS35
# Обрабатывается ген: VPS37C
# Обрабатывается ген: VPS45
# Обрабатывается ген: VPS72
# Обрабатывается ген: VPS8
# Обрабатывается ген: WASHC3
# Обрабатывается ген: WASHC4
# Обрабатывается ген: WASHC5
# Обрабатывается ген: WDR20
# Обрабатывается ген: WDR24
# Обрабатывается ген: WDR4
# Обрабатывается ген: WDR49
# Обрабатывается ген: WDR5
# Обрабатывается ген: WDR59
# Обрабатывается ген: WDR61
# Обрабатывается ген: WDR77
# Обрабатывается ген: WDR82
# Обрабатывается ген: WDYHV1
# Обрабатывается ген: WISP3
# Обрабатывается ген: WNK1
# Обрабатывается ген: WNT1
# Обрабатывается ген: WSB1
# Обрабатывается ген: XRN1
# Обрабатывается ген: YARS2
# Обрабатывается ген: YBX1
# Обрабатывается ген: YRDC
# Обрабатывается ген: YWHAE
# Обрабатывается ген: YY1P2
# Обрабатывается ген: ZBED1
# Обрабатывается ген: ZBTB8OS
# Обрабатывается ген: ZC3H18
# Обрабатывается ген: ZC3H4
# Обрабатывается ген: ZCRB1
# Обрабатывается ген: ZEB2
# Обрабатывается ген: ZFC3H1
# Обрабатывается ген: ZFP57
# Обрабатывается ген: ZMYND8
# Обрабатывается ген: ZNF143
# Обрабатывается ген: ZNF217
# Обрабатывается ген: ZNF281
# Обрабатывается ген: ZNF479
# Обрабатывается ген: ZNF492
# Обрабатывается ген: ZNF559-ZNF177&ZNF177
# Обрабатывается ген: ZNF592
# Обрабатывается ген: ZNF608
# Обрабатывается ген: ZNF629
# Обрабатывается ген: ZNF644
# Обрабатывается ген: ZNF98
# Обрабатывается ген: ZNHIT6
# Файл ALL_depscore_-0.2_zscore_-0.5.csv сохранён. Время выполнения: 9830.95 секунд
# Статистика: 7575 препаратов, из них 466 с известным механизмом

# %%
import requests
from chembl_webresource_client.new_client import new_client
import pandas as pd
import numpy as np
from typing import List, Dict, Union, Optional
from functools import lru_cache
import time
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import os
from pathlib import Path

# Настройка сессии с повторными попытками
session = requests.Session()
retries = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[500, 502, 503, 504]
)
session.mount('https://', HTTPAdapter(max_retries=retries))

# Установка таймаута по умолчанию для ChEMBL клиента
new_client.timeout = 30

def uniprot_to_chembl(uniprot_id: str) -> Optional[str]:
    """Получает ChEMBL ID из UniProt ID."""
    target = new_client.target
    try:
        res = target.filter(target_components__accession=uniprot_id)
        res_df = pd.DataFrame(res)
        
        if res_df.empty:
            return None
        return res_df['target_chembl_id'].iloc[0]
    except Exception as e:
        print(f"Ошибка при получении ChEMBL ID для UniProt {uniprot_id}: {e}")
        return None

def search_gene_in_uniprot_filtered(gene_name: str, organism: str = "Homo sapiens") -> Union[str, List[Dict]]:
    """Ищет информацию о гене в UniProt."""
    url = "https://rest.uniprot.org/uniprotkb/search"
    query = f'gene_exact:"{gene_name}" AND reviewed:true AND taxonomy_name:"{organism}"'
    
    params = {
        "query": query,
        "format": "json",
        "fields": "accession,gene_names,protein_name",
        "size": 10
    }
    
    try:
        response = session.get(url, params=params, timeout=30)
        response.raise_for_status()
        
        results = response.json().get("results", [])
        if not results:
            return f"No results found for gene '{gene_name}'"
        
        gene_info = [
            {
                "UniProt_ID": result["primaryAccession"],
                "Gene_Names": result["genes"][0]["geneName"]["value"] if result.get("genes") else "N/A",
                "Protein_Name": result["proteinDescription"]["recommendedName"]["fullName"]["value"],
            }
            for result in results
        ]
        
        for gene in gene_info:
            uniprot_id = gene["UniProt_ID"]
            chembl_id = uniprot_to_chembl(uniprot_id)
            gene["ChEMBL_ID"] = chembl_id if chembl_id else f"No ChEMBL ID found for {uniprot_id}"
            time.sleep(0.1)  # Задержка между запросами
        
        return gene_info
    except Exception as e:
        print(f"Ошибка при поиске гена {gene_name}: {e}")
        return f"Error searching gene {gene_name}: {str(e)}"

@lru_cache(maxsize=1000)
def get_parent_info(chembl_id: str) -> dict:
    """Получает информацию о родительском соединении для данного ChEMBL ID."""
    molecule = new_client.molecule
    molecule_form = new_client.molecule_form
    
    try:
        # Проверяем, есть ли родительское соединение
        parent_data = list(molecule_form.filter(molecule_chembl_id=chembl_id).only('parent_chembl_id'))
        
        if parent_data and 'parent_chembl_id' in parent_data[0]:
            parent_id = parent_data[0]['parent_chembl_id']
        else:
            # Если нет родителя, считаем текущий ID родительским
            parent_id = chembl_id
        
        # Получаем информацию о родительском соединении
        mol_data = list(molecule.filter(molecule_chembl_id=parent_id).only('pref_name', 'molecule_chembl_id'))
        pref_name = mol_data[0].get('pref_name', 'Unknown') if mol_data else 'Unknown'
        
        return {
            'parent_chembl_id': parent_id,
            'parent_pref_name': pref_name,
            'is_parent': parent_id == chembl_id
        }
    except Exception as e:
        print(f"Error getting parent info for {chembl_id}: {e}")
        return {
            'parent_chembl_id': chembl_id,
            'parent_pref_name': 'Unknown',
            'is_parent': True
        }

def filter_parent_drugs(drugs_list: List[Dict]) -> List[Dict]:
    """Фильтрует список препаратов, оставляя по одному представителю из каждого семейства.
       Сохраняет 'Yes' в Drug Mechanism при замене дочернего с 'Yes' на родительский."""
    parent_groups = {}
    
    # 1. Группируем все препараты по семействам
    for drug in drugs_list:
        try:
            if not drug.get('Drug ChEMBL ID'):
                continue
                
            parent_info = get_parent_info(drug['Drug ChEMBL ID'])
            parent_id = parent_info['parent_chembl_id']
            
            if parent_id not in parent_groups:
                parent_groups[parent_id] = {
                    'parent_info': parent_info,
                    'drugs': [],
                    'has_mechanism': False
                }
            
            parent_groups[parent_id]['drugs'].append(drug)
            if drug.get('Drug Mechanism ChEMBL') == 'Yes':
                parent_groups[parent_id]['has_mechanism'] = True
                
        except Exception as e:
            print(f"Ошибка при группировке препаратов: {e}")
            continue
    
    filtered_drugs = []
    
    # 2. Обрабатываем каждое семейство
    for parent_id, group in parent_groups.items():
        drugs_in_group = group['drugs']
        has_mechanism = group['has_mechanism']
        
        # Если в группе только один препарат - оставляем как есть
        if len(drugs_in_group) == 1:
            filtered_drugs.append(drugs_in_group[0])
            continue
        
        # Находим родительский препарат в группе
        parent_drug = next(
            (d for d in drugs_in_group if d['Drug ChEMBL ID'] == parent_id),
            None
        )
        
        # Если есть родительский препарат
        if parent_drug:
            # Если в семействе есть препараты с механизмом, сохраняем 'Yes' для родителя
            if has_mechanism:
                parent_drug['Drug Mechanism ChEMBL'] = 'Yes'
            filtered_drugs.append(parent_drug)
        else:
            # Если нет родительского - выбираем препарат с максимальным pChEMBL
            best_drug = max(
                drugs_in_group,
                key=lambda x: float(x['pChEMBL value']) if x.get('pChEMBL value', 'N/A') != 'N/A' else -1
            )
            filtered_drugs.append(best_drug)
    
    return filtered_drugs

def get_action_type(chembl_id: str) -> str:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        action_types = set()
        for mechanism in mechanisms:
            action_type = mechanism.get("action_type")
            if action_type:
                action_types.add(action_type)
        
        return "; ".join(action_types) if action_types else "N/A"
    except Exception as e:
        print(f"Ошибка при получении типа действия для {chembl_id}: {e}")
        return "N/A"

def get_mechanism_details(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        details = []
        for mechanism in mechanisms:
            mechanism_of_action = mechanism.get("mechanism_of_action", "N/A")
            
            details.append({
                "Mechanism of Action ChEMBL": mechanism_of_action,  # Изменено здесь
            })
        
        return details if details else [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь
    except Exception as e:
        print(f"Ошибка при получении механизма действия для {chembl_id}: {e}")
        return [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь

def get_max_phase(chembl_id: str) -> str:
    try:
        client = new_client
        molecule = client.molecule.get(chembl_id)
        max_phase = molecule.get("max_phase", None)
        
        if max_phase is None:
            return ""
        
        if max_phase == "0.0":
            return "Preclinical"
        elif max_phase == "1.0":
            return "Phase 1"
        elif max_phase == "2.0":
            return "Phase 2"
        elif max_phase == "3.0":
            return "Phase 3"
        elif max_phase == "4.0":
            return "Approved"
        else:
            return f"Unknown phase ({max_phase})"
    except Exception as e:
        print(f"Ошибка при получении фазы для {chembl_id}: {e}")
        return "N/A"

def get_pchembl_value(molecule_chembl_id: str, target_chembl_id: str) -> str:
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            pchembl_value__isnull=False
        ).only("pchembl_value")
        return activities[0]["pchembl_value"] if activities else "N/A"
    except Exception as e:
        print(f"Error fetching pChEMBL value for {molecule_chembl_id}: {e}")
        return "N/A"

def get_activity_data(molecule_chembl_id: str, target_chembl_id: str) -> Dict:
    """Возвращает объединенные данные активности: значение + единицы измерения"""
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).only("standard_value", "standard_type", "standard_units")
        
        if not activities:
            return {
                "Activity value ChEMBL": "N/A",
                "Activity type ChEMBL": "N/A"
            }
        
        activity = activities[0]
        value = activity.get('standard_value')
        units = activity.get('standard_units')
        act_type = activity.get('standard_type')
        
        if act_type == "Activity":
            act_type = "N/A"
        
        if value and units and value != "N/A" and units != "N/A":
            activity_value = f"= {value} {units}"
        else:
            activity_value = "N/A"
        
        return {
            "Activity value ChEMBL": activity_value,
            "Activity type ChEMBL": act_type
        }
    except Exception as e:
        print(f"Ошибка при получении данных активности для {molecule_chembl_id}: {e}")
        return {
            "Activity value ChEMBL": "N/A",
            "Activity type ChEMBL": "N/A"
        }

def get_drugs_for_target(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        
        mechanism_drugs = []
        mechanisms = client.mechanism.filter(target_chembl_id=chembl_id)
        for mech in mechanisms:
            try:
                drug_id = mech['molecule_chembl_id']
                drug = client.molecule.get(drug_id)
                
                activity_data = get_activity_data(drug_id, chembl_id)
                mechanism_details = get_mechanism_details(drug_id)
                
                if not mechanism_details:
                    print(f"Нет данных о механизме для {drug_id}")
                    continue
                    
                mechanism_drugs.append({
                    "Drug ChEMBL ID": drug_id,
                    "Drug name": drug.get('pref_name', 'N/A'),
                    "Drug Mechanism ChEMBL": "Yes",
                    "Activity value ChEMBL": activity_data["Activity value ChEMBL"],
                    "Activity type ChEMBL": activity_data["Activity type ChEMBL"],
                    "pChEMBL value": get_pchembl_value(drug_id, chembl_id),
                    "Max phase ChEMBL": get_max_phase(drug_id),
                    "Action type ChEMBL": get_action_type(drug_id),
                    "Mechanism of Action ChEMBL": mechanism_details[0]["Mechanism of Action ChEMBL"]
                })
                time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке механизма {mech.get('molecule_chembl_id')}: {str(e)}")
                continue
        
        mechanism_ids = {drug["Drug ChEMBL ID"] for drug in mechanism_drugs}
        activity_drugs = []
        
        activities = client.activity.filter(
            target_chembl_id=chembl_id,
            pchembl_value__isnull=False,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).order_by('-pchembl_value')[:100]
        
        for activity in activities:
            try:
                if activity['molecule_chembl_id'] not in mechanism_ids:
                    value = activity.get('standard_value', 'N/A')
                    units = activity.get('standard_units', 'N/A')
                    act_type = activity.get('standard_type', 'N/A')
                    
                    if act_type == "Activity":
                        act_type = "N/A"
                    
                    activity_value = f"= {value} {units}" if value != "N/A" and units != "N/A" else "N/A"
                    
                    activity_drugs.append({
                        "Drug ChEMBL ID": activity['molecule_chembl_id'],
                        "Drug name": activity['molecule_pref_name'],
                        "Drug Mechanism ChEMBL": "No",
                        "Activity value ChEMBL": activity_value,  # Исправлено
                        "Activity type ChEMBL": act_type,          # Исправлено
                        "pChEMBL value": activity['pchembl_value'],
                        "Max phase ChEMBL": get_max_phase(activity['molecule_chembl_id']),  # Исправлено
                        "Action type ChEMBL": get_action_type(activity['molecule_chembl_id']),  # Исправлено
                        "Mechanism of Action ChEMBL": "N/A"
                    })
                    time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке активности {activity}: {e}")
                continue
        
        all_drugs = mechanism_drugs + activity_drugs
        return filter_parent_drugs(all_drugs)
    except Exception as e:
        print(f"Ошибка при получении препаратов для цели {chembl_id}: {e}")
        return []

def get_gene_drug_info(gene_names: List[str]) -> List[Dict]:
    result = []
    
    for gene_name in gene_names:
        try:
            print(f"Обрабатывается ген: {gene_name}")
            gene_info_list = search_gene_in_uniprot_filtered(gene_name)
            
            if isinstance(gene_info_list, str):
                result.append({"Gene": gene_name, "Error": gene_info_list})
                continue
            
            unique_drugs_for_gene = {}

            for gene_info in gene_info_list:
                try:
                    if isinstance(gene_info['ChEMBL_ID'], str) and gene_info['ChEMBL_ID'].startswith("No ChEMBL"):
                        continue
                        
                    drugs = get_drugs_for_target(gene_info['ChEMBL_ID'])  # Только 1 аргумент!
                    
                    for drug in drugs:
                        chembl_id = drug["Drug ChEMBL ID"]
                        if chembl_id not in unique_drugs_for_gene or unique_drugs_for_gene[chembl_id]["pChEMBL value"] < drug["pChEMBL value"]:
                            unique_drugs_for_gene[chembl_id] = drug
                except Exception as e:
                    print(f"Ошибка при обработке информации о гене {gene_name}: {e}")
                    continue
            
            if not gene_info_list or 'UniProt_ID' not in gene_info_list[0]:
                continue
                
            for drug in unique_drugs_for_gene.values():
                result.append({
                    "Gene": gene_name,
                    "UniProt ID": gene_info_list[0]['UniProt_ID'],
                    "Protein name": gene_info_list[0]['Protein_Name'],
                    "Protein ChEMBL ID": gene_info_list[0]['ChEMBL_ID'],
                    **drug
                })
                
        except Exception as e:
            print(f"Ошибка при обработке гена {gene_name}: {e}")
            result.append({"Gene": gene_name, "Error": str(e)})
            continue

    return result

if __name__ == "__main__":
    # Замените этот путь на ваш реальный путь к файлу
    input_file = r"C:\Users\rusla\OneDrive\Рабочий стол\Диплом\Гены\thresholds\gene_selection\ALL\ALL_depscore_-0.2_zscore_-1.5.csv"
    
    # Чтение генов из файла
    try:
        genes_df = pd.read_csv(input_file)
        gene_names = genes_df['Gene'].tolist()
        print(f"Загружено {len(gene_names)} генов из файла")
    except Exception as e:
        print(f"Ошибка при чтении файла {input_file}: {e}")
        raise
    
    # Получаем имя выходного файла (без пути)
    output_filename = os.path.basename(input_file)
    
    start_time = time.time()
    print("\nНачинаем обработку с динамической фильтрацией pChEMBL")
    
    try:
        gene_drug_info = get_gene_drug_info(gene_names)
        
        # Определяем полный список всех возможных колонок
        all_columns = [
            "Gene", "UniProt ID", "Protein name", "Protein ChEMBL ID",
            "Drug ChEMBL ID", "Drug name", "Drug Mechanism ChEMBL",
            "Activity type ChEMBL", "Activity value ChEMBL",
            "pChEMBL value", "Max phase ChEMBL", "Action type ChEMBL", 
            "Mechanism of Action ChEMBL"
        ]
        
        # Создаем DataFrame из результатов
        df = pd.DataFrame(gene_drug_info)
        
        # Добавляем отсутствующие колонки и заполняем их NA
        for col in all_columns:
            if col not in df.columns:
                df[col] = pd.NA
        
        # Упорядочиваем колонки согласно нашему списку
        df = df[all_columns]
        
        # Фильтруем ошибочные записи (где нет Drug ChEMBL ID)
        df = df[df['Drug ChEMBL ID'].notna()]
        
        # Сохраняем в текущую директорию с тем же именем файла
        df.to_csv(output_filename, index=False, encoding='utf-8')
        
        elapsed_time = time.time() - start_time
        
        # Собираем статистику
        num_drugs = len(df)
        num_mechanisms = len(df[df['Drug Mechanism ChEMBL'] == 'Yes'])
        
        print(f"Файл {output_filename} сохранён. Время выполнения: {elapsed_time:.2f} секунд")
        print(f"Статистика: {num_drugs} препаратов, из них {num_mechanisms} с известным механизмом")
        
    except Exception as e:
        print(f"Критическая ошибка при обработке: {e}")
# Out:
# Загружено 46 генов из файла
#
# Начинаем обработку с динамической фильтрацией pChEMBL
# Обрабатывается ген: ARHGAP45
# Обрабатывается ген: ATP1B3
# Обрабатывается ген: ATP6V0A2
# Обрабатывается ген: BCL2
# Обрабатывается ген: C10orf95
# Обрабатывается ген: C16orf52
# Обрабатывается ген: CARS2
# Обрабатывается ген: CBFB
# Обрабатывается ген: CCND3
# Обрабатывается ген: COQ4
# Обрабатывается ген: DHODH
# Обрабатывается ген: EBF1
# Обрабатывается ген: ERG
# Обрабатывается ген: FAM19A4
# Обрабатывается ген: FAM214B
# Обрабатывается ген: FAR1
# Обрабатывается ген: FLJ42393
# Обрабатывается ген: GCLC
# Обрабатывается ген: IKZF1
# Обрабатывается ген: LCE1F
# Обрабатывается ген: LEF1
# Обрабатывается ген: LOC107984065
# Обрабатывается ген: LOC107987188
# Обрабатывается ген: LOC440434
# Обрабатывается ген: MAGEA3
# Обрабатывается ген: MBNL1
# Обрабатывается ген: MEF2C
# Обрабатывается ген: MIR429
# Обрабатывается ген: MON1A
# Обрабатывается ген: MSL3P1
# Обрабатывается ген: MYB
# Обрабатывается ген: NMNAT1
# Обрабатывается ген: PAICS
# Обрабатывается ген: PAX5
# Обрабатывается ген: PIK3CD
# Обрабатывается ген: PPCDC
# Обрабатывается ген: PPCS
# Обрабатывается ген: RUNX1
# Обрабатывается ген: SLC25A19
# Обрабатывается ген: SMARCC1
# Обрабатывается ген: STMN1
# Обрабатывается ген: TCF3
# Обрабатывается ген: TRIM66
# Обрабатывается ген: UMPS
# Обрабатывается ген: WDR61
# Обрабатывается ген: WDYHV1
# Файл ALL_depscore_-0.2_zscore_-1.5.csv сохранён. Время выполнения: 98.23 секунд
# Статистика: 651 препаратов, из них 44 с известным механизмом

# %%
import requests
from chembl_webresource_client.new_client import new_client
import pandas as pd
import numpy as np
from typing import List, Dict, Union, Optional
from functools import lru_cache
import time
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import os
from pathlib import Path

# Настройка сессии с повторными попытками
session = requests.Session()
retries = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[500, 502, 503, 504]
)
session.mount('https://', HTTPAdapter(max_retries=retries))

# Установка таймаута по умолчанию для ChEMBL клиента
new_client.timeout = 30

def uniprot_to_chembl(uniprot_id: str) -> Optional[str]:
    """Получает ChEMBL ID из UniProt ID."""
    target = new_client.target
    try:
        res = target.filter(target_components__accession=uniprot_id)
        res_df = pd.DataFrame(res)
        
        if res_df.empty:
            return None
        return res_df['target_chembl_id'].iloc[0]
    except Exception as e:
        print(f"Ошибка при получении ChEMBL ID для UniProt {uniprot_id}: {e}")
        return None

def search_gene_in_uniprot_filtered(gene_name: str, organism: str = "Homo sapiens") -> Union[str, List[Dict]]:
    """Ищет информацию о гене в UniProt."""
    url = "https://rest.uniprot.org/uniprotkb/search"
    query = f'gene_exact:"{gene_name}" AND reviewed:true AND taxonomy_name:"{organism}"'
    
    params = {
        "query": query,
        "format": "json",
        "fields": "accession,gene_names,protein_name",
        "size": 10
    }
    
    try:
        response = session.get(url, params=params, timeout=30)
        response.raise_for_status()
        
        results = response.json().get("results", [])
        if not results:
            return f"No results found for gene '{gene_name}'"
        
        gene_info = [
            {
                "UniProt_ID": result["primaryAccession"],
                "Gene_Names": result["genes"][0]["geneName"]["value"] if result.get("genes") else "N/A",
                "Protein_Name": result["proteinDescription"]["recommendedName"]["fullName"]["value"],
            }
            for result in results
        ]
        
        for gene in gene_info:
            uniprot_id = gene["UniProt_ID"]
            chembl_id = uniprot_to_chembl(uniprot_id)
            gene["ChEMBL_ID"] = chembl_id if chembl_id else f"No ChEMBL ID found for {uniprot_id}"
            time.sleep(0.1)  # Задержка между запросами
        
        return gene_info
    except Exception as e:
        print(f"Ошибка при поиске гена {gene_name}: {e}")
        return f"Error searching gene {gene_name}: {str(e)}"

@lru_cache(maxsize=1000)
def get_parent_info(chembl_id: str) -> dict:
    """Получает информацию о родительском соединении для данного ChEMBL ID."""
    molecule = new_client.molecule
    molecule_form = new_client.molecule_form
    
    try:
        # Проверяем, есть ли родительское соединение
        parent_data = list(molecule_form.filter(molecule_chembl_id=chembl_id).only('parent_chembl_id'))
        
        if parent_data and 'parent_chembl_id' in parent_data[0]:
            parent_id = parent_data[0]['parent_chembl_id']
        else:
            # Если нет родителя, считаем текущий ID родительским
            parent_id = chembl_id
        
        # Получаем информацию о родительском соединении
        mol_data = list(molecule.filter(molecule_chembl_id=parent_id).only('pref_name', 'molecule_chembl_id'))
        pref_name = mol_data[0].get('pref_name', 'Unknown') if mol_data else 'Unknown'
        
        return {
            'parent_chembl_id': parent_id,
            'parent_pref_name': pref_name,
            'is_parent': parent_id == chembl_id
        }
    except Exception as e:
        print(f"Error getting parent info for {chembl_id}: {e}")
        return {
            'parent_chembl_id': chembl_id,
            'parent_pref_name': 'Unknown',
            'is_parent': True
        }

def filter_parent_drugs(drugs_list: List[Dict]) -> List[Dict]:
    """Фильтрует список препаратов, оставляя по одному представителю из каждого семейства.
       Сохраняет 'Yes' в Drug Mechanism при замене дочернего с 'Yes' на родительский."""
    parent_groups = {}
    
    # 1. Группируем все препараты по семействам
    for drug in drugs_list:
        try:
            if not drug.get('Drug ChEMBL ID'):
                continue
                
            parent_info = get_parent_info(drug['Drug ChEMBL ID'])
            parent_id = parent_info['parent_chembl_id']
            
            if parent_id not in parent_groups:
                parent_groups[parent_id] = {
                    'parent_info': parent_info,
                    'drugs': [],
                    'has_mechanism': False
                }
            
            parent_groups[parent_id]['drugs'].append(drug)
            if drug.get('Drug Mechanism ChEMBL') == 'Yes':
                parent_groups[parent_id]['has_mechanism'] = True
                
        except Exception as e:
            print(f"Ошибка при группировке препаратов: {e}")
            continue
    
    filtered_drugs = []
    
    # 2. Обрабатываем каждое семейство
    for parent_id, group in parent_groups.items():
        drugs_in_group = group['drugs']
        has_mechanism = group['has_mechanism']
        
        # Если в группе только один препарат - оставляем как есть
        if len(drugs_in_group) == 1:
            filtered_drugs.append(drugs_in_group[0])
            continue
        
        # Находим родительский препарат в группе
        parent_drug = next(
            (d for d in drugs_in_group if d['Drug ChEMBL ID'] == parent_id),
            None
        )
        
        # Если есть родительский препарат
        if parent_drug:
            # Если в семействе есть препараты с механизмом, сохраняем 'Yes' для родителя
            if has_mechanism:
                parent_drug['Drug Mechanism ChEMBL'] = 'Yes'
            filtered_drugs.append(parent_drug)
        else:
            # Если нет родительского - выбираем препарат с максимальным pChEMBL
            best_drug = max(
                drugs_in_group,
                key=lambda x: float(x['pChEMBL value']) if x.get('pChEMBL value', 'N/A') != 'N/A' else -1
            )
            filtered_drugs.append(best_drug)
    
    return filtered_drugs

def get_action_type(chembl_id: str) -> str:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        action_types = set()
        for mechanism in mechanisms:
            action_type = mechanism.get("action_type")
            if action_type:
                action_types.add(action_type)
        
        return "; ".join(action_types) if action_types else "N/A"
    except Exception as e:
        print(f"Ошибка при получении типа действия для {chembl_id}: {e}")
        return "N/A"

def get_mechanism_details(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        details = []
        for mechanism in mechanisms:
            mechanism_of_action = mechanism.get("mechanism_of_action", "N/A")
            
            details.append({
                "Mechanism of Action ChEMBL": mechanism_of_action,  # Изменено здесь
            })
        
        return details if details else [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь
    except Exception as e:
        print(f"Ошибка при получении механизма действия для {chembl_id}: {e}")
        return [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь

def get_max_phase(chembl_id: str) -> str:
    try:
        client = new_client
        molecule = client.molecule.get(chembl_id)
        max_phase = molecule.get("max_phase", None)
        
        if max_phase is None:
            return ""
        
        if max_phase == "0.0":
            return "Preclinical"
        elif max_phase == "1.0":
            return "Phase 1"
        elif max_phase == "2.0":
            return "Phase 2"
        elif max_phase == "3.0":
            return "Phase 3"
        elif max_phase == "4.0":
            return "Approved"
        else:
            return f"Unknown phase ({max_phase})"
    except Exception as e:
        print(f"Ошибка при получении фазы для {chembl_id}: {e}")
        return "N/A"

def get_pchembl_value(molecule_chembl_id: str, target_chembl_id: str) -> str:
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            pchembl_value__isnull=False
        ).only("pchembl_value")
        return activities[0]["pchembl_value"] if activities else "N/A"
    except Exception as e:
        print(f"Error fetching pChEMBL value for {molecule_chembl_id}: {e}")
        return "N/A"

def get_activity_data(molecule_chembl_id: str, target_chembl_id: str) -> Dict:
    """Возвращает объединенные данные активности: значение + единицы измерения"""
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).only("standard_value", "standard_type", "standard_units")
        
        if not activities:
            return {
                "Activity value ChEMBL": "N/A",
                "Activity type ChEMBL": "N/A"
            }
        
        activity = activities[0]
        value = activity.get('standard_value')
        units = activity.get('standard_units')
        act_type = activity.get('standard_type')
        
        if act_type == "Activity":
            act_type = "N/A"
        
        if value and units and value != "N/A" and units != "N/A":
            activity_value = f"= {value} {units}"
        else:
            activity_value = "N/A"
        
        return {
            "Activity value ChEMBL": activity_value,
            "Activity type ChEMBL": act_type
        }
    except Exception as e:
        print(f"Ошибка при получении данных активности для {molecule_chembl_id}: {e}")
        return {
            "Activity value ChEMBL": "N/A",
            "Activity type ChEMBL": "N/A"
        }

def get_drugs_for_target(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        
        mechanism_drugs = []
        mechanisms = client.mechanism.filter(target_chembl_id=chembl_id)
        for mech in mechanisms:
            try:
                drug_id = mech['molecule_chembl_id']
                drug = client.molecule.get(drug_id)
                
                activity_data = get_activity_data(drug_id, chembl_id)
                mechanism_details = get_mechanism_details(drug_id)
                
                if not mechanism_details:
                    print(f"Нет данных о механизме для {drug_id}")
                    continue
                    
                mechanism_drugs.append({
                    "Drug ChEMBL ID": drug_id,
                    "Drug name": drug.get('pref_name', 'N/A'),
                    "Drug Mechanism ChEMBL": "Yes",
                    "Activity value ChEMBL": activity_data["Activity value ChEMBL"],
                    "Activity type ChEMBL": activity_data["Activity type ChEMBL"],
                    "pChEMBL value": get_pchembl_value(drug_id, chembl_id),
                    "Max phase ChEMBL": get_max_phase(drug_id),
                    "Action type ChEMBL": get_action_type(drug_id),
                    "Mechanism of Action ChEMBL": mechanism_details[0]["Mechanism of Action ChEMBL"]
                })
                time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке механизма {mech.get('molecule_chembl_id')}: {str(e)}")
                continue
        
        mechanism_ids = {drug["Drug ChEMBL ID"] for drug in mechanism_drugs}
        activity_drugs = []
        
        activities = client.activity.filter(
            target_chembl_id=chembl_id,
            pchembl_value__isnull=False,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).order_by('-pchembl_value')[:100]
        
        for activity in activities:
            try:
                if activity['molecule_chembl_id'] not in mechanism_ids:
                    value = activity.get('standard_value', 'N/A')
                    units = activity.get('standard_units', 'N/A')
                    act_type = activity.get('standard_type', 'N/A')
                    
                    if act_type == "Activity":
                        act_type = "N/A"
                    
                    activity_value = f"= {value} {units}" if value != "N/A" and units != "N/A" else "N/A"
                    
                    activity_drugs.append({
                        "Drug ChEMBL ID": activity['molecule_chembl_id'],
                        "Drug name": activity['molecule_pref_name'],
                        "Drug Mechanism ChEMBL": "No",
                        "Activity value ChEMBL": activity_value,  # Исправлено
                        "Activity type ChEMBL": act_type,          # Исправлено
                        "pChEMBL value": activity['pchembl_value'],
                        "Max phase ChEMBL": get_max_phase(activity['molecule_chembl_id']),  # Исправлено
                        "Action type ChEMBL": get_action_type(activity['molecule_chembl_id']),  # Исправлено
                        "Mechanism of Action ChEMBL": "N/A"
                    })
                    time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке активности {activity}: {e}")
                continue
        
        all_drugs = mechanism_drugs + activity_drugs
        return filter_parent_drugs(all_drugs)
    except Exception as e:
        print(f"Ошибка при получении препаратов для цели {chembl_id}: {e}")
        return []

def get_gene_drug_info(gene_names: List[str]) -> List[Dict]:
    result = []
    
    for gene_name in gene_names:
        try:
            print(f"Обрабатывается ген: {gene_name}")
            gene_info_list = search_gene_in_uniprot_filtered(gene_name)
            
            if isinstance(gene_info_list, str):
                result.append({"Gene": gene_name, "Error": gene_info_list})
                continue
            
            unique_drugs_for_gene = {}

            for gene_info in gene_info_list:
                try:
                    if isinstance(gene_info['ChEMBL_ID'], str) and gene_info['ChEMBL_ID'].startswith("No ChEMBL"):
                        continue
                        
                    drugs = get_drugs_for_target(gene_info['ChEMBL_ID'])  # Только 1 аргумент!
                    
                    for drug in drugs:
                        chembl_id = drug["Drug ChEMBL ID"]
                        if chembl_id not in unique_drugs_for_gene or unique_drugs_for_gene[chembl_id]["pChEMBL value"] < drug["pChEMBL value"]:
                            unique_drugs_for_gene[chembl_id] = drug
                except Exception as e:
                    print(f"Ошибка при обработке информации о гене {gene_name}: {e}")
                    continue
            
            if not gene_info_list or 'UniProt_ID' not in gene_info_list[0]:
                continue
                
            for drug in unique_drugs_for_gene.values():
                result.append({
                    "Gene": gene_name,
                    "UniProt ID": gene_info_list[0]['UniProt_ID'],
                    "Protein name": gene_info_list[0]['Protein_Name'],
                    "Protein ChEMBL ID": gene_info_list[0]['ChEMBL_ID'],
                    **drug
                })
                
        except Exception as e:
            print(f"Ошибка при обработке гена {gene_name}: {e}")
            result.append({"Gene": gene_name, "Error": str(e)})
            continue

    return result

if __name__ == "__main__":
    # Замените этот путь на ваш реальный путь к файлу
    input_file = r"C:\Users\rusla\OneDrive\Рабочий стол\Диплом\Гены\thresholds\gene_selection\ALL\ALL_depscore_-0.2_zscore_-1.csv"
    
    # Чтение генов из файла
    try:
        genes_df = pd.read_csv(input_file)
        gene_names = genes_df['Gene'].tolist()
        print(f"Загружено {len(gene_names)} генов из файла")
    except Exception as e:
        print(f"Ошибка при чтении файла {input_file}: {e}")
        raise
    
    # Получаем имя выходного файла (без пути)
    output_filename = os.path.basename(input_file)
    
    start_time = time.time()
    print("\nНачинаем обработку с динамической фильтрацией pChEMBL")
    
    try:
        gene_drug_info = get_gene_drug_info(gene_names)
        
        # Определяем полный список всех возможных колонок
        all_columns = [
            "Gene", "UniProt ID", "Protein name", "Protein ChEMBL ID",
            "Drug ChEMBL ID", "Drug name", "Drug Mechanism ChEMBL",
            "Activity type ChEMBL", "Activity value ChEMBL",
            "pChEMBL value", "Max phase ChEMBL", "Action type ChEMBL", 
            "Mechanism of Action ChEMBL"
        ]
        
        # Создаем DataFrame из результатов
        df = pd.DataFrame(gene_drug_info)
        
        # Добавляем отсутствующие колонки и заполняем их NA
        for col in all_columns:
            if col not in df.columns:
                df[col] = pd.NA
        
        # Упорядочиваем колонки согласно нашему списку
        df = df[all_columns]
        
        # Фильтруем ошибочные записи (где нет Drug ChEMBL ID)
        df = df[df['Drug ChEMBL ID'].notna()]
        
        # Сохраняем в текущую директорию с тем же именем файла
        df.to_csv(output_filename, index=False, encoding='utf-8')
        
        elapsed_time = time.time() - start_time
        
        # Собираем статистику
        num_drugs = len(df)
        num_mechanisms = len(df[df['Drug Mechanism ChEMBL'] == 'Yes'])
        
        print(f"Файл {output_filename} сохранён. Время выполнения: {elapsed_time:.2f} секунд")
        print(f"Статистика: {num_drugs} препаратов, из них {num_mechanisms} с известным механизмом")
        
    except Exception as e:
        print(f"Критическая ошибка при обработке: {e}")
# Out:
# Загружено 224 генов из файла
#
# Начинаем обработку с динамической фильтрацией pChEMBL
# Обрабатывается ген: ADSS2
# Обрабатывается ген: AES
# Обрабатывается ген: AGPS
# Обрабатывается ген: AHCY
# Обрабатывается ген: AHDC1
# Обрабатывается ген: AK2
# Обрабатывается ген: ALAD
# Обрабатывается ген: ALAS1
# Обрабатывается ген: ANKH
# Обрабатывается ген: ANKRD36
# Обрабатывается ген: ARHGAP19-SLIT1
# Обрабатывается ген: ARHGAP45
# Обрабатывается ген: ATIC
# Обрабатывается ген: ATP1B3
# Обрабатывается ген: ATP6V0A2
# Обрабатывается ген: BCL2
# Обрабатывается ген: BCS1L
# Обрабатывается ген: BIRC8
# Обрабатывается ген: C10orf95
# Обрабатывается ген: C14orf2
# Обрабатывается ген: C16orf52
# Обрабатывается ген: C1QTNF5&MFRP
# Обрабатывается ген: C1orf228
# Обрабатывается ген: C8orf44-SGK3
# Обрабатывается ген: CAB39
# Обрабатывается ген: CAD
# Обрабатывается ген: CARS2
# Обрабатывается ген: CBFB
# Обрабатывается ген: CCM2
# Обрабатывается ген: CCND3
# Обрабатывается ген: CCNYL2
# Обрабатывается ген: CDIN1
# Обрабатывается ген: CDK6
# Обрабатывается ген: CEND1
# Обрабатывается ген: CEP55
# Обрабатывается ген: CFL1
# Обрабатывается ген: CMIP
# Обрабатывается ген: COA5
# Обрабатывается ген: COQ4
# Обрабатывается ген: COX14
# Обрабатывается ген: COX16
# Обрабатывается ген: CPOX
# Обрабатывается ген: CTBP1
# Обрабатывается ген: CTPS1
# Обрабатывается ген: CTRB1&CTRB2
# Обрабатывается ген: DARS2
# Обрабатывается ген: DCAF15
# Обрабатывается ген: DCPS
# Обрабатывается ген: DDX3Y
# Обрабатывается ген: DHODH
# Обрабатывается ген: DNM2
# Обрабатывается ген: DNMT1
# Обрабатывается ген: DOT1L
# Обрабатывается ген: DPH6
# Обрабатывается ген: DPY30
# Обрабатывается ген: DTYMK
# Обрабатывается ген: EBF1
# Обрабатывается ген: EIF4E2
# Обрабатывается ген: ELOF1
# Обрабатывается ген: EMC3
# Обрабатывается ген: EP300
# Обрабатывается ген: ERG
# Обрабатывается ген: ESPNP
# Обрабатывается ген: FAM19A4
# Обрабатывается ген: FAM214B
# Обрабатывается ген: FAM50A
# Обрабатывается ген: FANCI
# Обрабатывается ген: FAR1
# Обрабатывается ген: FDX1
# Обрабатывается ген: FECH
# Обрабатывается ген: FER1L6-AS1
# Обрабатывается ген: FH
# Обрабатывается ген: FKBP1A
# Обрабатывается ген: FLCN
# Обрабатывается ген: FLJ42393
# Обрабатывается ген: FLT3
# Обрабатывается ген: FOXI3
# Обрабатывается ген: FPGS
# Обрабатывается ген: GALE
# Обрабатывается ген: GART
# Обрабатывается ген: GCLC
# Обрабатывается ген: GCSH
# Обрабатывается ген: GIGYF2
# Обрабатывается ген: GLRX5
# Обрабатывается ген: HIF1AN
# Обрабатывается ген: HIST1H2AC
# Обрабатывается ген: HMBS
# Обрабатывается ген: HMGB1
# Обрабатывается ген: IGLL1
# Обрабатывается ген: IKZF1
# Обрабатывается ген: IMPDH2
# Обрабатывается ген: KCNJ12
# Обрабатывается ген: KIR3DS1
# Обрабатывается ген: KLRA1P
# Обрабатывается ген: KRTAP10-11
# Обрабатывается ген: KRTAP5-1
# Обрабатывается ген: KRTAP5-10
# Обрабатывается ген: KRTAP5-3
# Обрабатывается ген: LCE1F
# Обрабатывается ген: LCE2C
# Обрабатывается ген: LEF1
# Обрабатывается ген: LINC00518
# Обрабатывается ген: LINC00523
# Обрабатывается ген: LINC01140
# Обрабатывается ген: LIPT1
# Обрабатывается ген: LIPT2
# Обрабатывается ген: LOC101929540
# Обрабатывается ген: LOC101929775
# Обрабатывается ген: LOC105369243&SULT1A4&SULT1A3
# Обрабатывается ген: LOC107984021
# Обрабатывается ген: LOC107984065
# Обрабатывается ген: LOC107987188
# Обрабатывается ген: LOC440434
# Обрабатывается ген: LOC644762
# Обрабатывается ген: LOC644936
# Обрабатывается ген: LRP8
# Обрабатывается ген: MAGEA3
# Обрабатывается ген: MAML1
# Обрабатывается ген: MBNL1
# Обрабатывается ген: MED16
# Обрабатывается ген: MED23
# Обрабатывается ген: MED24
# Обрабатывается ген: MEF2C
# Обрабатывается ген: MGAT1
# Обрабатывается ген: MICOS10
# Обрабатывается ген: MIOS
# Обрабатывается ген: MIR429
# Обрабатывается ген: MLST8
# Обрабатывается ген: MMGT1
# Обрабатывается ген: MON1A
# Обрабатывается ген: MOS
# Обрабатывается ген: MRPS24
# Обрабатывается ген: MSI2
# Обрабатывается ген: MSL3P1
# Обрабатывается ген: MTHFD1
# Обрабатывается ген: MUM1L1
# Обрабатывается ген: MXRA7
# Обрабатывается ген: MYB
# Обрабатывается ген: NAMPT
# Обрабатывается ген: NCKAP1L
# Обрабатывается ген: NCLN
# Обрабатывается ген: NMNAT1
# Обрабатывается ген: NOTUM
# Обрабатывается ген: OGDH
# Обрабатывается ген: PAICS
# Обрабатывается ген: PAX5
# Обрабатывается ген: PCYT2
# Обрабатывается ген: PDXK
# Обрабатывается ген: PEDS1
# Обрабатывается ген: PET100
# Обрабатывается ген: PEX7
# Обрабатывается ген: PFAS
# Обрабатывается ген: PGAP6
# Обрабатывается ген: PIK3CD
# Обрабатывается ген: PIM3
# Обрабатывается ген: PMS2P2
# Обрабатывается ген: PPAT
# Обрабатывается ген: PPCDC
# Обрабатывается ген: PPCS
# Обрабатывается ген: PPY
# Обрабатывается ген: PRB2
# Обрабатывается ген: PRDX6
# Обрабатывается ген: PRR22
# Обрабатывается ген: PTPRQ
# Обрабатывается ген: RFC4
# Обрабатывается ген: RHOXF2B&RHOXF2
# Обрабатывается ген: RPLP2
# Обрабатывается ген: RPS26
# Обрабатывается ген: RUNX1
# Обрабатывается ген: RYK
# Обрабатывается ген: SATB1
# Обрабатывается ген: SDHA
# Обрабатывается ген: SDHB
# Обрабатывается ген: SEMA3F
# Обрабатывается ген: SEPHS2
# Обрабатывается ген: SIRT7
# Обрабатывается ген: SLC20A1
# Обрабатывается ген: SLC25A1
# Обрабатывается ген: SLC25A19
# Обрабатывается ген: SLC25A51
# Обрабатывается ген: SLC5A3
# Обрабатывается ген: SLC8B1
# Обрабатывается ген: SMARCB1
# Обрабатывается ген: SMARCC1
# Обрабатывается ген: SMARCD1
# Обрабатывается ген: SORD2P
# Обрабатывается ген: STMN1
# Обрабатывается ген: SUCLG1
# Обрабатывается ген: SYK
# Обрабатывается ген: TAFAZZIN
# Обрабатывается ген: TBC1D3J
# Обрабатывается ген: TBL1Y
# Обрабатывается ген: TCF12
# Обрабатывается ген: TCF3
# Обрабатывается ген: TFRC
# Обрабатывается ген: THAP3
# Обрабатывается ген: TKFC
# Обрабатывается ген: TKT
# Обрабатывается ген: TMEM57
# Обрабатывается ген: TMX1
# Обрабатывается ген: TOMM20
# Обрабатывается ген: TPK1
# Обрабатывается ген: TPPP
# Обрабатывается ген: TRIM66
# Обрабатывается ген: TRMT112
# Обрабатывается ген: TYMS
# Обрабатывается ген: UBE2T
# Обрабатывается ген: UMPS
# Обрабатывается ген: UNK
# Обрабатывается ген: UQCC1
# Обрабатывается ген: UQCRB
# Обрабатывается ген: UQCRC1
# Обрабатывается ген: WDR20
# Обрабатывается ген: WDR49
# Обрабатывается ген: WDR61
# Обрабатывается ген: WDYHV1
# Обрабатывается ген: WISP3
# Обрабатывается ген: WSB1
# Обрабатывается ген: ZC3H4
# Обрабатывается ген: ZMYND8
# Обрабатывается ген: ZNF479
# Обрабатывается ген: ZNF592
# Обрабатывается ген: ZNF608
# Обрабатывается ген: ZNF629
# Файл ALL_depscore_-0.2_zscore_-1.csv сохранён. Время выполнения: 410.55 секунд
# Статистика: 2628 препаратов, из них 134 с известным механизмом

# %%
import requests
from chembl_webresource_client.new_client import new_client
import pandas as pd
import numpy as np
from typing import List, Dict, Union, Optional
from functools import lru_cache
import time
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import os
from pathlib import Path

# Настройка сессии с повторными попытками
session = requests.Session()
retries = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[500, 502, 503, 504]
)
session.mount('https://', HTTPAdapter(max_retries=retries))

# Установка таймаута по умолчанию для ChEMBL клиента
new_client.timeout = 30

def uniprot_to_chembl(uniprot_id: str) -> Optional[str]:
    """Получает ChEMBL ID из UniProt ID."""
    target = new_client.target
    try:
        res = target.filter(target_components__accession=uniprot_id)
        res_df = pd.DataFrame(res)
        
        if res_df.empty:
            return None
        return res_df['target_chembl_id'].iloc[0]
    except Exception as e:
        print(f"Ошибка при получении ChEMBL ID для UniProt {uniprot_id}: {e}")
        return None

def search_gene_in_uniprot_filtered(gene_name: str, organism: str = "Homo sapiens") -> Union[str, List[Dict]]:
    """Ищет информацию о гене в UniProt."""
    url = "https://rest.uniprot.org/uniprotkb/search"
    query = f'gene_exact:"{gene_name}" AND reviewed:true AND taxonomy_name:"{organism}"'
    
    params = {
        "query": query,
        "format": "json",
        "fields": "accession,gene_names,protein_name",
        "size": 10
    }
    
    try:
        response = session.get(url, params=params, timeout=30)
        response.raise_for_status()
        
        results = response.json().get("results", [])
        if not results:
            return f"No results found for gene '{gene_name}'"
        
        gene_info = [
            {
                "UniProt_ID": result["primaryAccession"],
                "Gene_Names": result["genes"][0]["geneName"]["value"] if result.get("genes") else "N/A",
                "Protein_Name": result["proteinDescription"]["recommendedName"]["fullName"]["value"],
            }
            for result in results
        ]
        
        for gene in gene_info:
            uniprot_id = gene["UniProt_ID"]
            chembl_id = uniprot_to_chembl(uniprot_id)
            gene["ChEMBL_ID"] = chembl_id if chembl_id else f"No ChEMBL ID found for {uniprot_id}"
            time.sleep(0.1)  # Задержка между запросами
        
        return gene_info
    except Exception as e:
        print(f"Ошибка при поиске гена {gene_name}: {e}")
        return f"Error searching gene {gene_name}: {str(e)}"

@lru_cache(maxsize=1000)
def get_parent_info(chembl_id: str) -> dict:
    """Получает информацию о родительском соединении для данного ChEMBL ID."""
    molecule = new_client.molecule
    molecule_form = new_client.molecule_form
    
    try:
        # Проверяем, есть ли родительское соединение
        parent_data = list(molecule_form.filter(molecule_chembl_id=chembl_id).only('parent_chembl_id'))
        
        if parent_data and 'parent_chembl_id' in parent_data[0]:
            parent_id = parent_data[0]['parent_chembl_id']
        else:
            # Если нет родителя, считаем текущий ID родительским
            parent_id = chembl_id
        
        # Получаем информацию о родительском соединении
        mol_data = list(molecule.filter(molecule_chembl_id=parent_id).only('pref_name', 'molecule_chembl_id'))
        pref_name = mol_data[0].get('pref_name', 'Unknown') if mol_data else 'Unknown'
        
        return {
            'parent_chembl_id': parent_id,
            'parent_pref_name': pref_name,
            'is_parent': parent_id == chembl_id
        }
    except Exception as e:
        print(f"Error getting parent info for {chembl_id}: {e}")
        return {
            'parent_chembl_id': chembl_id,
            'parent_pref_name': 'Unknown',
            'is_parent': True
        }

def filter_parent_drugs(drugs_list: List[Dict]) -> List[Dict]:
    """Фильтрует список препаратов, оставляя по одному представителю из каждого семейства.
       Сохраняет 'Yes' в Drug Mechanism при замене дочернего с 'Yes' на родительский."""
    parent_groups = {}
    
    # 1. Группируем все препараты по семействам
    for drug in drugs_list:
        try:
            if not drug.get('Drug ChEMBL ID'):
                continue
                
            parent_info = get_parent_info(drug['Drug ChEMBL ID'])
            parent_id = parent_info['parent_chembl_id']
            
            if parent_id not in parent_groups:
                parent_groups[parent_id] = {
                    'parent_info': parent_info,
                    'drugs': [],
                    'has_mechanism': False
                }
            
            parent_groups[parent_id]['drugs'].append(drug)
            if drug.get('Drug Mechanism ChEMBL') == 'Yes':
                parent_groups[parent_id]['has_mechanism'] = True
                
        except Exception as e:
            print(f"Ошибка при группировке препаратов: {e}")
            continue
    
    filtered_drugs = []
    
    # 2. Обрабатываем каждое семейство
    for parent_id, group in parent_groups.items():
        drugs_in_group = group['drugs']
        has_mechanism = group['has_mechanism']
        
        # Если в группе только один препарат - оставляем как есть
        if len(drugs_in_group) == 1:
            filtered_drugs.append(drugs_in_group[0])
            continue
        
        # Находим родительский препарат в группе
        parent_drug = next(
            (d for d in drugs_in_group if d['Drug ChEMBL ID'] == parent_id),
            None
        )
        
        # Если есть родительский препарат
        if parent_drug:
            # Если в семействе есть препараты с механизмом, сохраняем 'Yes' для родителя
            if has_mechanism:
                parent_drug['Drug Mechanism ChEMBL'] = 'Yes'
            filtered_drugs.append(parent_drug)
        else:
            # Если нет родительского - выбираем препарат с максимальным pChEMBL
            best_drug = max(
                drugs_in_group,
                key=lambda x: float(x['pChEMBL value']) if x.get('pChEMBL value', 'N/A') != 'N/A' else -1
            )
            filtered_drugs.append(best_drug)
    
    return filtered_drugs

def get_action_type(chembl_id: str) -> str:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        action_types = set()
        for mechanism in mechanisms:
            action_type = mechanism.get("action_type")
            if action_type:
                action_types.add(action_type)
        
        return "; ".join(action_types) if action_types else "N/A"
    except Exception as e:
        print(f"Ошибка при получении типа действия для {chembl_id}: {e}")
        return "N/A"

def get_mechanism_details(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        details = []
        for mechanism in mechanisms:
            mechanism_of_action = mechanism.get("mechanism_of_action", "N/A")
            
            details.append({
                "Mechanism of Action ChEMBL": mechanism_of_action,  # Изменено здесь
            })
        
        return details if details else [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь
    except Exception as e:
        print(f"Ошибка при получении механизма действия для {chembl_id}: {e}")
        return [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь

def get_max_phase(chembl_id: str) -> str:
    try:
        client = new_client
        molecule = client.molecule.get(chembl_id)
        max_phase = molecule.get("max_phase", None)
        
        if max_phase is None:
            return ""
        
        if max_phase == "0.0":
            return "Preclinical"
        elif max_phase == "1.0":
            return "Phase 1"
        elif max_phase == "2.0":
            return "Phase 2"
        elif max_phase == "3.0":
            return "Phase 3"
        elif max_phase == "4.0":
            return "Approved"
        else:
            return f"Unknown phase ({max_phase})"
    except Exception as e:
        print(f"Ошибка при получении фазы для {chembl_id}: {e}")
        return "N/A"

def get_pchembl_value(molecule_chembl_id: str, target_chembl_id: str) -> str:
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            pchembl_value__isnull=False
        ).only("pchembl_value")
        return activities[0]["pchembl_value"] if activities else "N/A"
    except Exception as e:
        print(f"Error fetching pChEMBL value for {molecule_chembl_id}: {e}")
        return "N/A"

def get_activity_data(molecule_chembl_id: str, target_chembl_id: str) -> Dict:
    """Возвращает объединенные данные активности: значение + единицы измерения"""
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).only("standard_value", "standard_type", "standard_units")
        
        if not activities:
            return {
                "Activity value ChEMBL": "N/A",
                "Activity type ChEMBL": "N/A"
            }
        
        activity = activities[0]
        value = activity.get('standard_value')
        units = activity.get('standard_units')
        act_type = activity.get('standard_type')
        
        if act_type == "Activity":
            act_type = "N/A"
        
        if value and units and value != "N/A" and units != "N/A":
            activity_value = f"= {value} {units}"
        else:
            activity_value = "N/A"
        
        return {
            "Activity value ChEMBL": activity_value,
            "Activity type ChEMBL": act_type
        }
    except Exception as e:
        print(f"Ошибка при получении данных активности для {molecule_chembl_id}: {e}")
        return {
            "Activity value ChEMBL": "N/A",
            "Activity type ChEMBL": "N/A"
        }

def get_drugs_for_target(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        
        mechanism_drugs = []
        mechanisms = client.mechanism.filter(target_chembl_id=chembl_id)
        for mech in mechanisms:
            try:
                drug_id = mech['molecule_chembl_id']
                drug = client.molecule.get(drug_id)
                
                activity_data = get_activity_data(drug_id, chembl_id)
                mechanism_details = get_mechanism_details(drug_id)
                
                if not mechanism_details:
                    print(f"Нет данных о механизме для {drug_id}")
                    continue
                    
                mechanism_drugs.append({
                    "Drug ChEMBL ID": drug_id,
                    "Drug name": drug.get('pref_name', 'N/A'),
                    "Drug Mechanism ChEMBL": "Yes",
                    "Activity value ChEMBL": activity_data["Activity value ChEMBL"],
                    "Activity type ChEMBL": activity_data["Activity type ChEMBL"],
                    "pChEMBL value": get_pchembl_value(drug_id, chembl_id),
                    "Max phase ChEMBL": get_max_phase(drug_id),
                    "Action type ChEMBL": get_action_type(drug_id),
                    "Mechanism of Action ChEMBL": mechanism_details[0]["Mechanism of Action ChEMBL"]
                })
                time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке механизма {mech.get('molecule_chembl_id')}: {str(e)}")
                continue
        
        mechanism_ids = {drug["Drug ChEMBL ID"] for drug in mechanism_drugs}
        activity_drugs = []
        
        activities = client.activity.filter(
            target_chembl_id=chembl_id,
            pchembl_value__isnull=False,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).order_by('-pchembl_value')[:100]
        
        for activity in activities:
            try:
                if activity['molecule_chembl_id'] not in mechanism_ids:
                    value = activity.get('standard_value', 'N/A')
                    units = activity.get('standard_units', 'N/A')
                    act_type = activity.get('standard_type', 'N/A')
                    
                    if act_type == "Activity":
                        act_type = "N/A"
                    
                    activity_value = f"= {value} {units}" if value != "N/A" and units != "N/A" else "N/A"
                    
                    activity_drugs.append({
                        "Drug ChEMBL ID": activity['molecule_chembl_id'],
                        "Drug name": activity['molecule_pref_name'],
                        "Drug Mechanism ChEMBL": "No",
                        "Activity value ChEMBL": activity_value,  # Исправлено
                        "Activity type ChEMBL": act_type,          # Исправлено
                        "pChEMBL value": activity['pchembl_value'],
                        "Max phase ChEMBL": get_max_phase(activity['molecule_chembl_id']),  # Исправлено
                        "Action type ChEMBL": get_action_type(activity['molecule_chembl_id']),  # Исправлено
                        "Mechanism of Action ChEMBL": "N/A"
                    })
                    time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке активности {activity}: {e}")
                continue
        
        all_drugs = mechanism_drugs + activity_drugs
        return filter_parent_drugs(all_drugs)
    except Exception as e:
        print(f"Ошибка при получении препаратов для цели {chembl_id}: {e}")
        return []

def get_gene_drug_info(gene_names: List[str]) -> List[Dict]:
    result = []
    
    for gene_name in gene_names:
        try:
            print(f"Обрабатывается ген: {gene_name}")
            gene_info_list = search_gene_in_uniprot_filtered(gene_name)
            
            if isinstance(gene_info_list, str):
                result.append({"Gene": gene_name, "Error": gene_info_list})
                continue
            
            unique_drugs_for_gene = {}

            for gene_info in gene_info_list:
                try:
                    if isinstance(gene_info['ChEMBL_ID'], str) and gene_info['ChEMBL_ID'].startswith("No ChEMBL"):
                        continue
                        
                    drugs = get_drugs_for_target(gene_info['ChEMBL_ID'])  # Только 1 аргумент!
                    
                    for drug in drugs:
                        chembl_id = drug["Drug ChEMBL ID"]
                        if chembl_id not in unique_drugs_for_gene or unique_drugs_for_gene[chembl_id]["pChEMBL value"] < drug["pChEMBL value"]:
                            unique_drugs_for_gene[chembl_id] = drug
                except Exception as e:
                    print(f"Ошибка при обработке информации о гене {gene_name}: {e}")
                    continue
            
            if not gene_info_list or 'UniProt_ID' not in gene_info_list[0]:
                continue
                
            for drug in unique_drugs_for_gene.values():
                result.append({
                    "Gene": gene_name,
                    "UniProt ID": gene_info_list[0]['UniProt_ID'],
                    "Protein name": gene_info_list[0]['Protein_Name'],
                    "Protein ChEMBL ID": gene_info_list[0]['ChEMBL_ID'],
                    **drug
                })
                
        except Exception as e:
            print(f"Ошибка при обработке гена {gene_name}: {e}")
            result.append({"Gene": gene_name, "Error": str(e)})
            continue

    return result

if __name__ == "__main__":
    # Замените этот путь на ваш реальный путь к файлу
    input_file = r"C:\Users\rusla\OneDrive\Рабочий стол\Диплом\Гены\thresholds\gene_selection\ALL\ALL_depscore_-0.15_zscore_-0.5.csv"
    
    # Чтение генов из файла
    try:
        genes_df = pd.read_csv(input_file)
        gene_names = genes_df['Gene'].tolist()
        print(f"Загружено {len(gene_names)} генов из файла")
    except Exception as e:
        print(f"Ошибка при чтении файла {input_file}: {e}")
        raise
    
    # Получаем имя выходного файла (без пути)
    output_filename = os.path.basename(input_file)
    
    start_time = time.time()
    print("\nНачинаем обработку с динамической фильтрацией pChEMBL")
    
    try:
        gene_drug_info = get_gene_drug_info(gene_names)
        
        # Определяем полный список всех возможных колонок
        all_columns = [
            "Gene", "UniProt ID", "Protein name", "Protein ChEMBL ID",
            "Drug ChEMBL ID", "Drug name", "Drug Mechanism ChEMBL",
            "Activity type ChEMBL", "Activity value ChEMBL",
            "pChEMBL value", "Max phase ChEMBL", "Action type ChEMBL", 
            "Mechanism of Action ChEMBL"
        ]
        
        # Создаем DataFrame из результатов
        df = pd.DataFrame(gene_drug_info)
        
        # Добавляем отсутствующие колонки и заполняем их NA
        for col in all_columns:
            if col not in df.columns:
                df[col] = pd.NA
        
        # Упорядочиваем колонки согласно нашему списку
        df = df[all_columns]
        
        # Фильтруем ошибочные записи (где нет Drug ChEMBL ID)
        df = df[df['Drug ChEMBL ID'].notna()]
        
        # Сохраняем в текущую директорию с тем же именем файла
        df.to_csv(output_filename, index=False, encoding='utf-8')
        
        elapsed_time = time.time() - start_time
        
        # Собираем статистику
        num_drugs = len(df)
        num_mechanisms = len(df[df['Drug Mechanism ChEMBL'] == 'Yes'])
        
        print(f"Файл {output_filename} сохранён. Время выполнения: {elapsed_time:.2f} секунд")
        print(f"Статистика: {num_drugs} препаратов, из них {num_mechanisms} с известным механизмом")
        
    except Exception as e:
        print(f"Критическая ошибка при обработке: {e}")
# Out:
# Загружено 1176 генов из файла
#
# Начинаем обработку с динамической фильтрацией pChEMBL
# Обрабатывается ген: ABHD11
# Обрабатывается ген: ACAP3
# Обрабатывается ген: ACIN1
# Обрабатывается ген: ACLY
# Обрабатывается ген: ACO2
# Обрабатывается ген: ACPP
# Обрабатывается ген: ACSL4
# Обрабатывается ген: ACTL6A
# Обрабатывается ген: ACTR10
# Обрабатывается ген: ADAMTS4
# Обрабатывается ген: ADGRB2
# Обрабатывается ген: ADSL
# Обрабатывается ген: ADSS2
# Обрабатывается ген: AES
# Обрабатывается ген: AFF1
# Обрабатывается ген: AGPS
# Обрабатывается ген: AGRN
# Обрабатывается ген: AHCY
# Обрабатывается ген: AHDC1
# Обрабатывается ген: AJM1
# Обрабатывается ген: AK2
# Обрабатывается ген: AKAP17A
# Обрабатывается ген: AKT2
# Обрабатывается ген: ALAD
# Обрабатывается ген: ALAS1
# Обрабатывается ген: ALDH3B1
# Обрабатывается ген: ALDH9A1
# Обрабатывается ген: ALYREF
# Обрабатывается ген: AMY1A&AMY1B&AMY1C
# Обрабатывается ген: ANAPC7
# Обрабатывается ген: ANKH
# Обрабатывается ген: ANKRD34B
# Обрабатывается ген: ANKRD36
# Обрабатывается ген: ANKRD62P1-PARP4P3
# Обрабатывается ген: ANKUB1
# Обрабатывается ген: ANXA13
# Обрабатывается ген: AP1G1
# Обрабатывается ген: AP1M1
# Обрабатывается ген: AP1S2
# Обрабатывается ген: AP2M1
# Обрабатывается ген: AP2S1
# Обрабатывается ген: APC
# Обрабатывается ген: APOBEC3F
# Обрабатывается ген: AQR
# Обрабатывается ген: ARHGAP19-SLIT1
# Обрабатывается ген: ARHGAP45
# Обрабатывается ген: ARID1A
# Обрабатывается ген: ARL6IP4
# Обрабатывается ген: ARMH3
# Обрабатывается ген: ASAP3
# Обрабатывается ген: ASNSD1
# Обрабатывается ген: ATF7
# Обрабатывается ген: ATIC
# Обрабатывается ген: ATP1B3
# Обрабатывается ген: ATP2C1
# Обрабатывается ген: ATP5F1E
# Обрабатывается ген: ATP5MG
# Обрабатывается ген: ATP6AP1
# Обрабатывается ген: ATP6AP2
# Обрабатывается ген: ATP6V0A2
# Обрабатывается ген: ATP6V0C
# Обрабатывается ген: ATP6V1E1
# Обрабатывается ген: ATRX
# Обрабатывается ген: ATXN2
# Обрабатывается ген: ATXN2L
# Обрабатывается ген: AUH
# Обрабатывается ген: AVPR1B
# Обрабатывается ген: AZGP1
# Обрабатывается ген: BAGE
# Обрабатывается ген: BAGE5
# Обрабатывается ген: BANF1
# Обрабатывается ген: BBC3
# Обрабатывается ген: BCL2
# Обрабатывается ген: BCOR
# Обрабатывается ген: BCS1L
# Обрабатывается ген: BICDL1
# Обрабатывается ген: BICRAL
# Обрабатывается ген: BIRC8
# Обрабатывается ген: BORCS8-MEF2B
# Обрабатывается ген: BRD4
# Обрабатывается ген: BRD9
# Обрабатывается ген: BRI3
# Обрабатывается ген: BRIP1
# Обрабатывается ген: BTNL2
# Обрабатывается ген: C10orf90
# Обрабатывается ген: C10orf95
# Обрабатывается ген: C14orf2
# Обрабатывается ген: C15orf38-AP3S2
# Обрабатывается ген: C16orf52
# Обрабатывается ген: C16orf62
# Обрабатывается ген: C17orf77
# Обрабатывается ген: C17orf82
# Обрабатывается ген: C1QTNF5&MFRP
# Обрабатывается ген: C1orf109
# Обрабатывается ген: C1orf127
# Обрабатывается ген: C1orf216
# Обрабатывается ген: C1orf228
# Обрабатывается ген: C1orf27
# Обрабатывается ген: C2orf16
# Обрабатывается ген: C3orf84
# Обрабатывается ген: C4orf32
# Обрабатывается ген: C8orf44-SGK3
# Обрабатывается ген: C8orf86
# Обрабатывается ген: C9orf57
# Обрабатывается ген: CA12
# Обрабатывается ген: CAB39
# Обрабатывается ген: CAD
# Обрабатывается ген: CAMK2G
# Обрабатывается ген: CAPNS1
# Обрабатывается ген: CARM1
# Обрабатывается ген: CARS2
# Обрабатывается ген: CBFB
# Обрабатывается ген: CBLN4
# Обрабатывается ген: CBWD1
# Обрабатывается ген: CCDC106
# Обрабатывается ген: CCDC115
# Обрабатывается ген: CCDC154
# Обрабатывается ген: CCDC155
# Обрабатывается ген: CCDC168
# Обрабатывается ген: CCDC47
# Обрабатывается ген: CCDC93
# Обрабатывается ген: CCM2
# Обрабатывается ген: CCNC
# Обрабатывается ген: CCND3
# Обрабатывается ген: CCNYL2
# Обрабатывается ген: CD177
# Обрабатывается ген: CD19
# Обрабатывается ген: CD300E
# Обрабатывается ген: CD3EAP
# Обрабатывается ген: CDAN1
# Обрабатывается ген: CDC25A
# Обрабатывается ген: CDIN1
# Обрабатывается ген: CDK6
# Обрабатывается ген: CDS2
# Обрабатывается ген: CDY1B&CDY1
# Обрабатывается ген: CEND1
# Обрабатывается ген: CEP350
# Обрабатывается ген: CEP43
# Обрабатывается ген: CEP55
# Обрабатывается ген: CFC1&CFC1B
# Обрабатывается ген: CFL1
# Обрабатывается ген: CHCHD3
# Обрабатывается ген: CHD7
# Обрабатывается ген: CHD8
# Обрабатывается ген: CHFR
# Обрабатывается ген: CHM
# Обрабатывается ген: CHRNB2
# Обрабатывается ген: CHRNG
# Обрабатывается ген: CIAO1
# Обрабатывается ген: CKMT1B
# Обрабатывается ген: CLDN19
# Обрабатывается ген: CLINT1
# Обрабатывается ген: CLIP3
# Обрабатывается ген: CLSTN3
# Обрабатывается ген: CLTB
# Обрабатывается ген: CLTC
# Обрабатывается ген: CMIP
# Обрабатывается ген: CMTM4
# Обрабатывается ген: COA5
# Обрабатывается ген: COA6
# Обрабатывается ген: COA7
# Обрабатывается ген: COL18A1
# Обрабатывается ген: COL6A5
# Обрабатывается ген: COMT
# Обрабатывается ген: COQ2
# Обрабатывается ген: COQ3
# Обрабатывается ген: COQ4
# Обрабатывается ген: COQ5
# Обрабатывается ген: COQ6
# Обрабатывается ген: COQ7
# Обрабатывается ген: COX14
# Обрабатывается ген: COX16
# Обрабатывается ген: COX17
# Обрабатывается ген: COX5B
# Обрабатывается ген: COX6A1
# Обрабатывается ген: COX6B1
# Обрабатывается ген: COX6C
# Обрабатывается ген: COX7A2
# Обрабатывается ген: COX7B
# Обрабатывается ген: CPOX
# Обрабатывается ген: CRACDL
# Обрабатывается ген: CRACR2B
# Обрабатывается ген: CROCC
# Обрабатывается ген: CSH1
# Обрабатывается ген: CSK
# Обрабатывается ген: CSPG4
# Обрабатывается ген: CSPG5
# Обрабатывается ген: CTBP1
# Обрабатывается ген: CTBP2
# Обрабатывается ген: CTGF
# Обрабатывается ген: CTPS1
# Обрабатывается ген: CTRB1&CTRB2
# Обрабатывается ген: CUEDC1
# Обрабатывается ген: CXCL1
# Обрабатывается ген: CXorf40B
# Обрабатывается ген: CYC1
# Обрабатывается ген: CYP11A1
# Обрабатывается ген: DAP3
# Обрабатывается ген: DARS2
# Обрабатывается ген: DCAF10
# Обрабатывается ген: DCAF15
# Обрабатывается ген: DCAF7
# Обрабатывается ген: DCPS
# Обрабатывается ген: DCTD
# Обрабатывается ген: DDX39A
# Обрабатывается ген: DDX3Y
# Обрабатывается ген: DEC1
# Обрабатывается ген: DENND4A
# Обрабатывается ген: DHFR
# Обрабатывается ген: DHODH
# Обрабатывается ген: DHX29
# Обрабатывается ген: DIXDC1
# Обрабатывается ген: DKC1
# Обрабатывается ген: DLD
# Обрабатывается ген: DLGAP1-AS1
# Обрабатывается ген: DLST
# Обрабатывается ген: DLSTP1
# Обрабатывается ген: DMRTB1
# Обрабатывается ген: DMXL1
# Обрабатывается ген: DNAH5
# Обрабатывается ген: DNAJB11
# Обрабатывается ген: DNAJC9
# Обрабатывается ген: DND1
# Обрабатывается ген: DNLZ
# Обрабатывается ген: DNM2
# Обрабатывается ген: DNMT1
# Обрабатывается ген: DOLK
# Обрабатывается ген: DOPEY2
# Обрабатывается ген: DOT1L
# Обрабатывается ген: DPCD
# Обрабатывается ген: DPF2
# Обрабатывается ген: DPH1
# Обрабатывается ген: DPH3
# Обрабатывается ген: DPH6
# Обрабатывается ген: DPH7
# Обрабатывается ген: DPY30
# Обрабатывается ген: DROSHA
# Обрабатывается ген: DSP
# Обрабатывается ген: DTYMK
# Обрабатывается ген: DUOX2
# Обрабатывается ген: DUSP11
# Обрабатывается ген: DUSP22
# Обрабатывается ген: DUSP29
# Обрабатывается ген: DUSP3
# Обрабатывается ген: DYNC1LI1
# Обрабатывается ген: EBF1
# Обрабатывается ген: EEF1D
# Обрабатывается ген: EEF1G
# Обрабатывается ген: EEF2
# Обрабатывается ген: EEFSEC
# Обрабатывается ген: EFHD2
# Обрабатывается ген: EIF3B
# Обрабатывается ген: EIF3K
# Обрабатывается ген: EIF4E2
# Обрабатывается ген: EIF4G1
# Обрабатывается ген: EIF5A
# Обрабатывается ген: ELOB
# Обрабатывается ген: ELOF1
# Обрабатывается ген: EMC1
# Обрабатывается ген: EMC2
# Обрабатывается ген: EMC3
# Обрабатывается ген: EMC4
# Обрабатывается ген: EMC6
# Обрабатывается ген: EMC7
# Обрабатывается ген: EMC8
# Обрабатывается ген: EML3
# Обрабатывается ген: EML6
# Обрабатывается ген: ENDOV
# Обрабатывается ген: ENTPD8
# Обрабатывается ген: EP300
# Обрабатывается ген: EP400
# Обрабатывается ген: EPHA10
# Обрабатывается ген: EPHA2
# Обрабатывается ген: EPSTI1
# Обрабатывается ген: ERCC1
# Обрабатывается ген: ERCC8
# Обрабатывается ген: ERG
# Обрабатывается ген: ESPNP
# Обрабатывается ген: ESYT1
# Обрабатывается ген: EVPL
# Обрабатывается ген: EXOC3L1
# Обрабатывается ген: EXOC6
# Обрабатывается ген: EXTL1
# Обрабатывается ген: EZH2
# Обрабатывается ген: FAAP100
# Обрабатывается ген: FAM104B
# Обрабатывается ген: FAM157A
# Обрабатывается ген: FAM193B
# Обрабатывается ген: FAM19A4
# Обрабатывается ген: FAM19A5
# Обрабатывается ген: FAM200A
# Обрабатывается ген: FAM214B
# Обрабатывается ген: FAM26E
# Обрабатывается ген: FAM45BP
# Обрабатывается ген: FAM46C
# Обрабатывается ген: FAM50A
# Обрабатывается ген: FAM74A6
# Обрабатывается ген: FAM83C
# Обрабатывается ген: FANCA
# Обрабатывается ген: FANCC
# Обрабатывается ген: FANCD2
# Обрабатывается ген: FANCI
# Обрабатывается ген: FANCL
# Обрабатывается ген: FAR1
# Обрабатывается ген: FARS2
# Обрабатывается ген: FASTKD5
# Обрабатывается ген: FCGR1B
# Обрабатывается ген: FCHO1
# Обрабатывается ген: FDPS
# Обрабатывается ген: FDX1
# Обрабатывается ген: FDXR
# Обрабатывается ген: FECH
# Обрабатывается ген: FEM1A
# Обрабатывается ген: FEN1
# Обрабатывается ген: FER1L6-AS1
# Обрабатывается ген: FGD5
# Обрабатывается ген: FGD6
# Обрабатывается ген: FGF16
# Обрабатывается ген: FH
# Обрабатывается ген: FKBP1A
# Обрабатывается ген: FLCN
# Обрабатывается ген: FLJ40194
# Обрабатывается ген: FLJ42393
# Обрабатывается ген: FLOT2
# Обрабатывается ген: FLT3
# Обрабатывается ген: FNDC10
# Обрабатывается ген: FOXI3
# Обрабатывается ген: FOXK2
# Обрабатывается ген: FOXL2NB
# Обрабатывается ген: FOXN4
# Обрабатывается ген: FOXO1
# Обрабатывается ген: FPGS
# Обрабатывается ген: FREM3
# Обрабатывается ген: FRG2B
# Обрабатывается ген: FTCD
# Обрабатывается ген: FUK
# Обрабатывается ген: FUT4
# Обрабатывается ген: G6PD
# Обрабатывается ген: GABARAP
# Обрабатывается ген: GABARAPL3
# Обрабатывается ген: GABPA
# Обрабатывается ген: GABPB1
# Обрабатывается ген: GALE
# Обрабатывается ген: GAPDH
# Обрабатывается ген: GAREM2
# Обрабатывается ген: GART
# Обрабатывается ген: GATA3
# Обрабатывается ген: GATB
# Обрабатывается ген: GCLC
# Обрабатывается ген: GCSH
# Обрабатывается ген: GFI1
# Обрабатывается ген: GFM1
# Обрабатывается ген: GFPT1
# Обрабатывается ген: GFUS
# Обрабатывается ген: GIGYF2
# Обрабатывается ген: GIP
# Обрабатывается ген: GJB4
# Обрабатывается ген: GJC3
# Обрабатывается ген: GLB1L
# Обрабатывается ген: GLRX5
# Обрабатывается ген: GMEB1
# Обрабатывается ген: GMPPB
# Обрабатывается ген: GNB3
# Обрабатывается ген: GNE
# Обрабатывается ген: GOLGA8S
# Обрабатывается ген: GOT2
# Обрабатывается ген: GPA33
# Обрабатывается ген: GPATCH3
# Обрабатывается ген: GPR132
# Обрабатывается ген: GPR137
# Обрабатывается ген: GPR62
# Обрабатывается ген: GPX4
# Обрабатывается ген: GRINA
# Обрабатывается ген: GRM2
# Обрабатывается ген: GS1-124K5.11
# Обрабатывается ген: GSE1
# Обрабатывается ген: GTF2H2
# Обрабатывается ген: GTF2H3
# Обрабатывается ген: GTF2H5
# Обрабатывается ген: GTF2IRD2B
# Обрабатывается ген: GTPBP3
# Обрабатывается ген: GTPBP8
# Обрабатывается ген: GUCY1B2
# Обрабатывается ген: GUCY2EP
# Обрабатывается ген: GUSBP1
# Обрабатывается ген: H2AC16
# Обрабатывается ген: H2AC6
# Обрабатывается ген: H2AFY
# Обрабатывается ген: H2AJ
# Обрабатывается ген: H2AZ1
# Обрабатывается ген: H2BC10
# Обрабатывается ген: H2BC11
# Обрабатывается ген: H2BC13
# Обрабатывается ген: H2BC14
# Обрабатывается ген: H2BC3
# Обрабатывается ген: H2BC4
# Обрабатывается ген: H2BC5
# Обрабатывается ген: H2BC6
# Обрабатывается ген: H2BC7
# Обрабатывается ген: H2BC8
# Обрабатывается ген: H3-3A
# Обрабатывается ген: H3C2
# Обрабатывается ген: H3C3
# Обрабатывается ген: H3C4
# Обрабатывается ген: H3C7
# Обрабатывается ген: HBS1L
# Обрабатывается ген: HCCS
# Обрабатывается ген: HCFC1
# Обрабатывается ген: HDAC1
# Обрабатывается ген: HEATR5B
# Обрабатывается ген: HEATR6
# Обрабатывается ген: HES3
# Обрабатывается ген: HEXD
# Обрабатывается ген: HFE2
# Обрабатывается ген: HGS
# Обрабатывается ген: HID1
# Обрабатывается ген: HIF1AN
# Обрабатывается ген: HIST1H2AC
# Обрабатывается ген: HIST1H2AK
# Обрабатывается ген: HIST1H2BH
# Обрабатывается ген: HIST1H2BO
# Обрабатывается ген: HIST1H4C
# Обрабатывается ген: HIST2H4B&HIST2H4A
# Обрабатывается ген: HJURP
# Обрабатывается ген: HLA-DRB4
# Обрабатывается ген: HLA-DRB6
# Обрабатывается ген: HMBS
# Обрабатывается ген: HMGB1
# Обрабатывается ген: HMX3
# Обрабатывается ген: HNRNPA1
# Обрабатывается ген: HOXC13
# Обрабатывается ген: HRK
# Обрабатывается ген: HSD17B10
# Обрабатывается ген: HSFY2&HSFY1
# Обрабатывается ген: HSH2D
# Обрабатывается ген: HSP90AA1
# Обрабатывается ген: HSPA5
# Обрабатывается ген: HSPA7
# Обрабатывается ген: HSPA8
# Обрабатывается ген: HSPB7
# Обрабатывается ген: IBA57
# Обрабатывается ген: ID3
# Обрабатывается ген: IFITM2
# Обрабатывается ген: IFNA13
# Обрабатывается ген: IFNL2&IFNL3
# Обрабатывается ген: IFNLR1
# Обрабатывается ген: IGFALS
# Обрабатывается ген: IGLL1
# Обрабатывается ген: IGSF3
# Обрабатывается ген: IKZF1
# Обрабатывается ген: IL36RN
# Обрабатывается ген: IMPDH1
# Обрабатывается ген: IMPDH2
# Обрабатывается ген: INAFM1
# Обрабатывается ген: INO80
# Обрабатывается ген: IPPK
# Обрабатывается ген: IRF4
# Обрабатывается ген: ISCA1
# Обрабатывается ген: ISG20
# Обрабатывается ген: ITGB7
# Обрабатывается ген: IWS1
# Обрабатывается ген: JADE3
# Обрабатывается ген: KAT2A
# Обрабатывается ген: KCNJ12
# Обрабатывается ген: KCTD5
# Обрабатывается ген: KCTD9
# Обрабатывается ген: KDM2B
# Обрабатывается ген: KDM5C
# Обрабатывается ген: KDM5D
# Обрабатывается ген: KEAP1
# Обрабатывается ген: KIF1A
# Обрабатывается ген: KIF26A
# Обрабатывается ген: KIR2DL5B&KIR2DL5A
# Обрабатывается ген: KIR2DS4
# Обрабатывается ген: KIR3DS1
# Обрабатывается ген: KIRREL3-AS3
# Обрабатывается ген: KLHDC7B
# Обрабатывается ген: KLHDC8A
# Обрабатывается ген: KLRA1P
# Обрабатывается ген: KMT5A
# Обрабатывается ген: KRT6A
# Обрабатывается ген: KRTAP10-11
# Обрабатывается ген: KRTAP10-9
# Обрабатывается ген: KRTAP5-1
# Обрабатывается ген: KRTAP5-10
# Обрабатывается ген: KRTAP5-3
# Обрабатывается ген: L3MBTL1
# Обрабатывается ген: LAGE3
# Обрабатывается ген: LARS2
# Обрабатывается ген: LCE1F
# Обрабатывается ген: LCE2C
# Обрабатывается ген: LCE3D
# Обрабатывается ген: LCMT2
# Обрабатывается ген: LCN10
# Обрабатывается ген: LDB1
# Обрабатывается ген: LEF1
# Обрабатывается ген: LEMD3
# Обрабатывается ген: LEXM
# Обрабатывается ген: LGI1
# Обрабатывается ген: LHX4
# Обрабатывается ген: LIAS
# Обрабатывается ген: LIG1
# Обрабатывается ген: LINC00518
# Обрабатывается ген: LINC00523
# Обрабатывается ген: LINC01140
# Обрабатывается ген: LINC01446
# Обрабатывается ген: LINC02210-CRHR1&CRHR1
# Обрабатывается ген: LIPT1
# Обрабатывается ген: LIPT2
# Обрабатывается ген: LOC101060521&POLR3E
# Обрабатывается ген: LOC101929540
# Обрабатывается ген: LOC101929775
# Обрабатывается ген: LOC101929970
# Обрабатывается ген: LOC102723414&LOC102723608&LOC102723819&LOC102723933&LOC105371747&LOC105379635
# Обрабатывается ген: LOC102723623&GOLGA6L1&GOLGA6L22&LOC645202
# Обрабатывается ген: LOC102724488&SYT15
# Обрабатывается ген: LOC102724770&DGCR6
# Обрабатывается ген: LOC102724985&PDXDC1
# Обрабатывается ген: LOC102725117
# Обрабатывается ген: LOC105369243&SULT1A4&SULT1A3
# Обрабатывается ген: LOC107984021
# Обрабатывается ген: LOC107984065
# Обрабатывается ген: LOC107984838
# Обрабатывается ген: LOC107986988
# Обрабатывается ген: LOC107987188
# Обрабатывается ген: LOC341056
# Обрабатывается ген: LOC400710
# Обрабатывается ген: LOC440434
# Обрабатывается ген: LOC554223
# Обрабатывается ген: LOC606724
# Обрабатывается ген: LOC641367
# Обрабатывается ген: LOC644762
# Обрабатывается ген: LOC644936
# Обрабатывается ген: LOC645752
# Обрабатывается ген: LOC652276
# Обрабатывается ген: LPAR5
# Обрабатывается ген: LRP5
# Обрабатывается ген: LRP8
# Обрабатывается ген: LRRC57
# Обрабатывается ген: LRWD1
# Обрабатывается ген: LTV1
# Обрабатывается ген: LYNX1
# Обрабатывается ген: MAD1L1
# Обрабатывается ген: MAFK
# Обрабатывается ген: MAGEA2B&MAGEA2
# Обрабатывается ген: MAGEA3
# Обрабатывается ген: MAGOH
# Обрабатывается ген: MAML1
# Обрабатывается ген: MAN1C1
# Обрабатывается ген: MANF
# Обрабатывается ген: MAP3K20
# Обрабатывается ген: MAPK14
# Обрабатывается ген: MAPK6
# Обрабатывается ген: MAST2
# Обрабатывается ген: MAU2
# Обрабатывается ген: MBNL1
# Обрабатывается ген: MCAT
# Обрабатывается ген: MDH2
# Обрабатывается ген: MEAF6
# Обрабатывается ген: MECR
# Обрабатывается ген: MED10
# Обрабатывается ген: MED12
# Обрабатывается ген: MED13L
# Обрабатывается ген: MED15
# Обрабатывается ген: MED16
# Обрабатывается ген: MED19
# Обрабатывается ген: MED23
# Обрабатывается ген: MED24
# Обрабатывается ген: MEF2C
# Обрабатывается ген: MEF2D
# Обрабатывается ген: MEIS3
# Обрабатывается ген: MEN1
# Обрабатывается ген: METTL1
# Обрабатывается ген: METTL13
# Обрабатывается ген: METTL16
# Обрабатывается ген: MFSD3
# Обрабатывается ген: MGAT1
# Обрабатывается ген: MGEA5
# Обрабатывается ген: MIB2
# Обрабатывается ген: MICOS10
# Обрабатывается ген: MIF
# Обрабатывается ген: MINDY2
# Обрабатывается ген: MINOS1-NBL1&NBL1
# Обрабатывается ген: MIOS
# Обрабатывается ген: MIR429
# Обрабатывается ген: MLLT1
# Обрабатывается ген: MLST8
# Обрабатывается ген: MLXIP
# Обрабатывается ген: MMEL1
# Обрабатывается ген: MMGT1
# Обрабатывается ген: MMP23B
# Обрабатывается ген: MMS22L
# Обрабатывается ген: MON1A
# Обрабатывается ген: MORF4L1
# Обрабатывается ген: MORN1
# Обрабатывается ген: MOS
# Обрабатывается ген: MPP6
# Обрабатывается ген: MPV17
# Обрабатывается ген: MRE11
# Обрабатывается ген: MRGBP
# Обрабатывается ген: MRPL11
# Обрабатывается ген: MRPL12
# Обрабатывается ген: MRPL18
# Обрабатывается ген: MRPL20
# Обрабатывается ген: MRPL21
# Обрабатывается ген: MRPL22
# Обрабатывается ген: MRPL24
# Обрабатывается ген: MRPL34
# Обрабатывается ген: MRPL41
# Обрабатывается ген: MRPL43
# Обрабатывается ген: MRPL47
# Обрабатывается ген: MRPL48
# Обрабатывается ген: MRPL52
# Обрабатывается ген: MRPL55
# Обрабатывается ген: MRPS14
# Обрабатывается ген: MRPS16
# Обрабатывается ген: MRPS17
# Обрабатывается ген: MRPS2
# Обрабатывается ген: MRPS22
# Обрабатывается ген: MRPS23
# Обрабатывается ген: MRPS24
# Обрабатывается ген: MRPS25
# Обрабатывается ген: MRPS26
# Обрабатывается ген: MRPS30
# Обрабатывается ген: MRPS33
# Обрабатывается ген: MRPS36
# Обрабатывается ген: MSANTD3-TMEFF1
# Обрабатывается ген: MSI2
# Обрабатывается ген: MSL3P1
# Обрабатывается ген: MT1A
# Обрабатывается ген: MT1B
# Обрабатывается ген: MT2A
# Обрабатывается ген: MTBP
# Обрабатывается ген: MTF1
# Обрабатывается ген: MTG1
# Обрабатывается ген: MTG2
# Обрабатывается ген: MTHFD1
# Обрабатывается ген: MTHFD2
# Обрабатывается ген: MTO1
# Обрабатывается ген: MUM1L1
# Обрабатывается ген: MVD
# Обрабатывается ген: MXRA7
# Обрабатывается ген: MYB
# Обрабатывается ген: MYBL2
# Обрабатывается ген: MYC
# Обрабатывается ген: MYO15A
# Обрабатывается ген: MYO5C
# Обрабатывается ген: MZF1
# Обрабатывается ген: N6AMT1
# Обрабатывается ген: NAA10
# Обрабатывается ген: NAMPT
# Обрабатывается ген: NAPRT
# Обрабатывается ген: NARS2
# Обрабатывается ген: NBPF10&NBPF26&NBPF15
# Обрабатывается ген: NCKAP1L
# Обрабатывается ген: NCLN
# Обрабатывается ген: NCSTN
# Обрабатывается ген: NDUFA4
# Обрабатывается ген: NELFB
# Обрабатывается ген: NELFE
# Обрабатывается ген: NEUROD2
# Обрабатывается ген: NFATC3
# Обрабатывается ген: NGRN
# Обрабатывается ген: NIPBL
# Обрабатывается ген: NME1
# Обрабатывается ген: NMNAT1
# Обрабатывается ген: NOL3
# Обрабатывается ген: NOL6
# Обрабатывается ген: NOTCH1
# Обрабатывается ген: NOTCH4
# Обрабатывается ген: NOTUM
# Обрабатывается ген: NR2E3
# Обрабатывается ген: NRBP1
# Обрабатывается ген: NSA2
# Обрабатывается ген: NSL1
# Обрабатывается ген: NUDT18
# Обрабатывается ген: NUFIP2
# Обрабатывается ген: NUP37
# Обрабатывается ген: OAS3
# Обрабатывается ген: OGDH
# Обрабатывается ген: OR10G9
# Обрабатывается ген: OR10H2
# Обрабатывается ген: OR12D2
# Обрабатывается ген: OR13H1
# Обрабатывается ген: OR1D4
# Обрабатывается ген: OR1I1
# Обрабатывается ген: OR1J1
# Обрабатывается ген: OR2A14
# Обрабатывается ген: OR2A5
# Обрабатывается ген: OR2F1
# Обрабатывается ген: OR2L8
# Обрабатывается ген: OR2M7
# Обрабатывается ген: OR2T12
# Обрабатывается ген: OR2T34&OR2T3
# Обрабатывается ген: OR2T8
# Обрабатывается ген: OR8B12
# Обрабатывается ген: OR8D2
# Обрабатывается ген: OSBPL2
# Обрабатывается ген: OTUD7A
# Обрабатывается ген: OXSM
# Обрабатывается ген: P3H4
# Обрабатывается ген: PABPN1
# Обрабатывается ген: PACS1
# Обрабатывается ген: PACS2
# Обрабатывается ген: PAICS
# Обрабатывается ген: PAPLN
# Обрабатывается ген: PAPOLB
# Обрабатывается ген: PARD6G
# Обрабатывается ген: PARGP1
# Обрабатывается ген: PARS2
# Обрабатывается ген: PAX5
# Обрабатывается ген: PAXIP1
# Обрабатывается ген: PCYT2
# Обрабатывается ген: PDAP1
# Обрабатывается ген: PDCD6
# Обрабатывается ген: PDPK1
# Обрабатывается ген: PDRG1
# Обрабатывается ген: PDSS1
# Обрабатывается ген: PDSS2
# Обрабатывается ген: PDXK
# Обрабатывается ген: PEDS1
# Обрабатывается ген: PELO
# Обрабатывается ген: PER2
# Обрабатывается ген: PERP
# Обрабатывается ген: PET100
# Обрабатывается ген: PET117
# Обрабатывается ген: PEX10
# Обрабатывается ген: PEX19
# Обрабатывается ген: PEX7
# Обрабатывается ген: PFAS
# Обрабатывается ген: PGAM5
# Обрабатывается ген: PGAP3
# Обрабатывается ген: PGAP6
# Обрабатывается ген: PI4KB
# Обрабатывается ген: PIK3CD
# Обрабатывается ген: PIM2
# Обрабатывается ген: PIM3
# Обрабатывается ген: PIMREG
# Обрабатывается ген: PISD
# Обрабатывается ген: PKD1L2
# Обрабатывается ген: PLA2G6
# Обрабатывается ген: PLAGL2
# Обрабатывается ген: PLEKHN1
# Обрабатывается ген: PLK4
# Обрабатывается ген: PLRG1
# Обрабатывается ген: PLXNA2
# Обрабатывается ген: PMM2
# Обрабатывается ген: PMS2P2
# Обрабатывается ген: PMVK
# Обрабатывается ген: PNMA1
# Обрабатывается ген: PNPT1
# Обрабатывается ген: POLR1B
# Обрабатывается ген: POLR2L
# Обрабатывается ген: POLR3K
# Обрабатывается ген: POT1
# Обрабатывается ген: POTEF
# Обрабатывается ген: POU2AF1
# Обрабатывается ген: PPA2
# Обрабатывается ген: PPAN-P2RY11
# Обрабатывается ген: PPAT
# Обрабатывается ген: PPCDC
# Обрабатывается ген: PPCS
# Обрабатывается ген: PPEF2
# Обрабатывается ген: PPIAP30
# Обрабатывается ген: PPIL1
# Обрабатывается ген: PPOX
# Обрабатывается ген: PPP2CA
# Обрабатывается ген: PPP2R3C
# Обрабатывается ген: PPP3R1
# Обрабатывается ген: PPP4C
# Обрабатывается ген: PPY
# Обрабатывается ген: PQBP1
# Обрабатывается ген: PQLC1
# Обрабатывается ген: PRAMEF12
# Обрабатывается ген: PRAMEF18
# Обрабатывается ген: PRAMEF20
# Обрабатывается ген: PRAMEF6
# Обрабатывается ген: PRB2
# Обрабатывается ген: PRC1
# Обрабатывается ген: PRCC
# Обрабатывается ген: PRDX3
# Обрабатывается ген: PRDX6
# Обрабатывается ген: PRELID1
# Обрабатывается ген: PRH2
# Обрабатывается ген: PRIM1
# Обрабатывается ген: PRKAA2
# Обрабатывается ген: PRKAB2
# Обрабатывается ген: PRKAR1A
# Обрабатывается ген: PRMT5
# Обрабатывается ген: PRPF6
# Обрабатывается ген: PRR12
# Обрабатывается ген: PRR22
# Обрабатывается ген: PRR30
# Обрабатывается ген: PSENEN
# Обрабатывается ген: PSMD2
# Обрабатывается ген: PSME4
# Обрабатывается ген: PSTK
# Обрабатывается ген: PTCD1
# Обрабатывается ген: PTCH2
# Обрабатывается ген: PTMA
# Обрабатывается ген: PTP4A2
# Обрабатывается ген: PTPN23
# Обрабатывается ген: PTPRQ
# Обрабатывается ген: PTPRU
# Обрабатывается ген: PTRH1
# Обрабатывается ген: PUS1
# Обрабатывается ген: PUS3
# Обрабатывается ген: PUSL1
# Обрабатывается ген: PYM1
# Обрабатывается ген: RAB13
# Обрабатывается ген: RAB3A
# Обрабатывается ген: RAB5IF
# Обрабатывается ген: RAB6C-AS1
# Обрабатывается ген: RABIF
# Обрабатывается ген: RACK1
# Обрабатывается ген: RAD21
# Обрабатывается ген: RAD50
# Обрабатывается ген: RAD54L2
# Обрабатывается ген: RADIL
# Обрабатывается ген: RARS
# Обрабатывается ген: RASAL1
# Обрабатывается ген: RASL10A
# Обрабатывается ген: RBFA
# Обрабатывается ген: RBMS2
# Обрабатывается ген: RBSN
# Обрабатывается ген: RCCD1
# Обрабатывается ген: RER1
# Обрабатывается ген: RERE
# Обрабатывается ген: RFC4
# Обрабатывается ген: RFC5
# Обрабатывается ген: RFK
# Обрабатывается ген: RFWD2
# Обрабатывается ген: RFWD3
# Обрабатывается ген: RFX2
# Обрабатывается ген: RGPD3
# Обрабатывается ген: RHBDF1
# Обрабатывается ген: RHOA
# Обрабатывается ген: RHOXF2B&RHOXF2
# Обрабатывается ген: RICTOR
# Обрабатывается ген: RILP
# Обрабатывается ген: RIMKLB
# Обрабатывается ген: RNASEH1
# Обрабатывается ген: RNASEH2A
# Обрабатывается ген: RNASEH2B
# Обрабатывается ген: RNASEH2C
# Обрабатывается ген: RND1
# Обрабатывается ген: RNF11
# Обрабатывается ген: RNF114
# Обрабатывается ген: RNF219
# Обрабатывается ген: RNF223
# Обрабатывается ген: RNF224
# Обрабатывается ген: RNF39
# Обрабатывается ген: RNPEPL1
# Обрабатывается ген: RPE
# Обрабатывается ген: RPF2
# Обрабатывается ген: RPIA
# Обрабатывается ген: RPL10A
# Обрабатывается ген: RPL13AP20
# Обрабатывается ген: RPL18
# Обрабатывается ген: RPL26
# Обрабатывается ген: RPL27A
# Обрабатывается ген: RPL30
# Обрабатывается ген: RPL37A
# Обрабатывается ген: RPL38
# Обрабатывается ген: RPL4
# Обрабатывается ген: RPL5
# Обрабатывается ген: RPL7
# Обрабатывается ген: RPL7A
# Обрабатывается ген: RPL8
# Обрабатывается ген: RPLP1
# Обрабатывается ген: RPLP2
# Обрабатывается ген: RPP25L
# Обрабатывается ген: RPS10-NUDT3
# Обрабатывается ген: RPS16
# Обрабатывается ген: RPS18
# Обрабатывается ген: RPS21
# Обрабатывается ген: RPS24
# Обрабатывается ген: RPS26
# Обрабатывается ген: RPS27A
# Обрабатывается ген: RPS6KA2
# Обрабатывается ген: RPS6KL1
# Обрабатывается ген: RPSAP9
# Обрабатывается ген: RPUSD3
# Обрабатывается ген: RRN3P3&LOC101060405
# Обрабатывается ген: RSF1
# Обрабатывается ген: RSL24D1
# Обрабатывается ген: RTEL1
# Обрабатывается ген: RUFY4
# Обрабатывается ген: RUNX1
# Обрабатывается ген: RUVBL1
# Обрабатывается ген: RYK
# Обрабатывается ген: SARS2
# Обрабатывается ген: SATB1
# Обрабатывается ген: SCAF8
# Обрабатывается ген: SCARB1
# Обрабатывается ген: SCARF1
# Обрабатывается ген: SCN8A
# Обрабатывается ген: SCO1
# Обрабатывается ген: SCO2
# Обрабатывается ген: SDHA
# Обрабатывается ген: SDHAF2
# Обрабатывается ген: SDHB
# Обрабатывается ген: SDHC
# Обрабатывается ген: SDHD
# Обрабатывается ген: SDR9C7
# Обрабатывается ген: SEC24A
# Обрабатывается ген: SECISBP2
# Обрабатывается ген: SEH1L
# Обрабатывается ген: SEL1L
# Обрабатывается ген: SEMA3F
# Обрабатывается ген: SEPHS2
# Обрабатывается ген: SEPSECS
# Обрабатывается ген: SEPT7
# Обрабатывается ген: SETD1B
# Обрабатывается ген: SF3B4
# Обрабатывается ген: SFT2D3
# Обрабатывается ген: SFTA3
# Обрабатывается ген: SGF29
# Обрабатывается ген: SH2D6
# Обрабатывается ген: SH3GL1
# Обрабатывается ген: SHB
# Обрабатывается ген: SHE
# Обрабатывается ген: SIK3
# Обрабатывается ген: SIRT7
# Обрабатывается ген: SKIC2
# Обрабатывается ген: SLC16A1
# Обрабатывается ген: SLC16A5
# Обрабатывается ген: SLC19A1
# Обрабатывается ген: SLC20A1
# Обрабатывается ген: SLC22A13
# Обрабатывается ген: SLC22A18AS
# Обрабатывается ген: SLC25A1
# Обрабатывается ген: SLC25A19
# Обрабатывается ген: SLC25A22
# Обрабатывается ген: SLC25A26
# Обрабатывается ген: SLC25A51
# Обрабатывается ген: SLC35G6
# Обрабатывается ген: SLC4A7
# Обрабатывается ген: SLC5A3
# Обрабатывается ген: SLC8B1
# Обрабатывается ген: SLC9A3
# Обрабатывается ген: SLX4
# Обрабатывается ген: SMARCA4
# Обрабатывается ген: SMARCA5
# Обрабатывается ген: SMARCB1
# Обрабатывается ген: SMARCC1
# Обрабатывается ген: SMARCD1
# Обрабатывается ген: SMARCD2
# Обрабатывается ген: SMARCE1
# Обрабатывается ген: SMPD5
# Обрабатывается ген: SMR3B
# Обрабатывается ген: SNAI3
# Обрабатывается ген: SNAPC5
# Обрабатывается ген: SNRPB
# Обрабатывается ген: SNRPE
# Обрабатывается ген: SOD2
# Обрабатывается ген: SORD2P
# Обрабатывается ген: SOX4
# Обрабатывается ген: SPATA33
# Обрабатывается ген: SPDYE4
# Обрабатывается ген: SPRYD4
# Обрабатывается ген: SRM
# Обрабатывается ген: SRSF6
# Обрабатывается ген: SSBP1
# Обрабатывается ген: SSH1
# Обрабатывается ген: SSH2
# Обрабатывается ген: SSRP1
# Обрабатывается ген: SSX8
# Обрабатывается ген: STAG2
# Обрабатывается ген: STEAP3
# Обрабатывается ген: STK11
# Обрабатывается ген: STMN1
# Обрабатывается ген: STRIP1
# Обрабатывается ген: SUB1
# Обрабатывается ген: SUCLA2
# Обрабатывается ген: SUCLG1
# Обрабатывается ген: SUOX
# Обрабатывается ген: SUPT20H
# Обрабатывается ген: SUPT4H1
# Обрабатывается ген: SUPT7L
# Обрабатывается ген: SUSD2
# Обрабатывается ген: SYK
# Обрабатывается ген: SYVN1
# Обрабатывается ген: TADA1
# Обрабатывается ген: TADA2B
# Обрабатывается ген: TAF10
# Обрабатывается ген: TAF11
# Обрабатывается ген: TAF13
# Обрабатывается ген: TAF1A
# Обрабатывается ген: TAF2
# Обрабатывается ген: TAF5L
# Обрабатывается ген: TAF6L
# Обрабатывается ген: TAFAZZIN
# Обрабатывается ген: TALDO1
# Обрабатывается ген: TAMM41
# Обрабатывается ген: TARDBP
# Обрабатывается ген: TBC1D17
# Обрабатывается ген: TBC1D3G
# Обрабатывается ген: TBC1D3J
# Обрабатывается ген: TBCD
# Обрабатывается ген: TBL1Y
# Обрабатывается ген: TBL2
# Обрабатывается ген: TBX4
# Обрабатывается ген: TCF12
# Обрабатывается ген: TCF3
# Обрабатывается ген: TCTN2
# Обрабатывается ген: TEDC1
# Обрабатывается ген: TEFM
# Обрабатывается ген: TEN1
# Обрабатывается ген: TEN1-CDK3&CDK3
# Обрабатывается ген: TEX44
# Обрабатывается ген: TFB2M
# Обрабатывается ген: TFEB
# Обрабатывается ген: TFRC
# Обрабатывается ген: TGFBRAP1
# Обрабатывается ген: TGIF2
# Обрабатывается ген: TGM1
# Обрабатывается ген: THAP11
# Обрабатывается ген: THAP3
# Обрабатывается ген: THG1L
# Обрабатывается ген: THOC3
# Обрабатывается ген: THOC5
# Обрабатывается ген: TIE1
# Обрабатывается ген: TIMM13
# Обрабатывается ген: TK1
# Обрабатывается ген: TKFC
# Обрабатывается ген: TKT
# Обрабатывается ген: TLE3
# Обрабатывается ген: TM4SF19-TCTEX1D2
# Обрабатывается ген: TMEM147
# Обрабатывается ген: TMEM185A
# Обрабатывается ген: TMEM189
# Обрабатывается ген: TMEM208
# Обрабатывается ген: TMEM30A
# Обрабатывается ген: TMEM41B
# Обрабатывается ген: TMEM57
# Обрабатывается ген: TMPRSS11BNL
# Обрабатывается ген: TMX1
# Обрабатывается ген: TMX2
# Обрабатывается ген: TNF
# Обрабатывается ген: TNKS1BP1
# Обрабатывается ген: TNNT2
# Обрабатывается ген: TNRC6C
# Обрабатывается ген: TNS2
# Обрабатывается ген: TOMM20
# Обрабатывается ген: TOMM22
# Обрабатывается ген: TOMM5
# Обрабатывается ген: TP53BP1
# Обрабатывается ген: TP53I3
# Обрабатывается ген: TPI1
# Обрабатывается ген: TPK1
# Обрабатывается ген: TPPP
# Обрабатывается ген: TPT1
# Обрабатывается ген: TPTE
# Обрабатывается ген: TRAF2
# Обрабатывается ген: TRAIP
# Обрабатывается ген: TREML2
# Обрабатывается ген: TRIM25
# Обрабатывается ген: TRIM28
# Обрабатывается ген: TRIM33
# Обрабатывается ген: TRIM49D2
# Обрабатывается ген: TRIM66
# Обрабатывается ген: TRIM8
# Обрабатывается ген: TRIP6
# Обрабатывается ген: TRMT112
# Обрабатывается ген: TRNAU1AP
# Обрабатывается ген: TRPM1
# Обрабатывается ген: TRPM7
# Обрабатывается ген: TRRAP
# Обрабатывается ген: TRUB2
# Обрабатывается ген: TSC1
# Обрабатывается ген: TSC2
# Обрабатывается ген: TTC14
# Обрабатывается ген: TTC22
# Обрабатывается ген: TTC27
# Обрабатывается ген: TTC39A
# Обрабатывается ген: TUBA1B
# Обрабатывается ген: TUBB
# Обрабатывается ген: TUBB8
# Обрабатывается ген: TUSC5
# Обрабатывается ген: TXN
# Обрабатывается ген: TYMS
# Обрабатывается ген: TYW1B
# Обрабатывается ген: UBA3
# Обрабатывается ген: UBALD2
# Обрабатывается ген: UBE2DNL
# Обрабатывается ген: UBE2G2
# Обрабатывается ген: UBE2T
# Обрабатывается ген: UBR1
# Обрабатывается ген: UBXN1
# Обрабатывается ген: UCN
# Обрабатывается ген: UCN2
# Обрабатывается ген: UGT2B10
# Обрабатывается ген: UMPS
# Обрабатывается ген: UNC13D
# Обрабатывается ген: UNC5B
# Обрабатывается ген: UNK
# Обрабатывается ген: UPK3BL2
# Обрабатывается ген: UQCC1
# Обрабатывается ген: UQCC2
# Обрабатывается ген: UQCR10
# Обрабатывается ген: UQCRB
# Обрабатывается ген: UQCRC1
# Обрабатывается ген: UQCRC2
# Обрабатывается ген: URM1
# Обрабатывается ген: UROD
# Обрабатывается ген: UROS
# Обрабатывается ген: USH1G
# Обрабатывается ген: USP17L3
# Обрабатывается ген: USP21
# Обрабатывается ген: USP34
# Обрабатывается ген: VARS2
# Обрабатывается ген: VMA21
# Обрабатывается ген: VPS18
# Обрабатывается ген: VPS33A
# Обрабатывается ген: VPS35
# Обрабатывается ген: VPS37C
# Обрабатывается ген: VPS45
# Обрабатывается ген: VPS72
# Обрабатывается ген: VPS8
# Обрабатывается ген: VSTM2B
# Обрабатывается ген: WASHC3
# Обрабатывается ген: WASHC4
# Обрабатывается ген: WASHC5
# Обрабатывается ген: WDR20
# Обрабатывается ген: WDR24
# Обрабатывается ген: WDR4
# Обрабатывается ген: WDR49
# Обрабатывается ген: WDR5
# Обрабатывается ген: WDR59
# Обрабатывается ген: WDR61
# Обрабатывается ген: WDR77
# Обрабатывается ген: WDR82
# Обрабатывается ген: WDR86
# Обрабатывается ген: WDYHV1
# Обрабатывается ген: WISP3
# Обрабатывается ген: WNK1
# Обрабатывается ген: WNT1
# Обрабатывается ген: WSB1
# Обрабатывается ген: XIAP
# Обрабатывается ген: XRN1
# Обрабатывается ген: YARS2
# Обрабатывается ген: YBX1
# Обрабатывается ген: YBX3
# Обрабатывается ген: YRDC
# Обрабатывается ген: YWHAE
# Обрабатывается ген: YY1P2
# Обрабатывается ген: ZAP70
# Обрабатывается ген: ZBED1
# Обрабатывается ген: ZBED4
# Обрабатывается ген: ZBTB8OS
# Обрабатывается ген: ZC3H18
# Обрабатывается ген: ZC3H4
# Обрабатывается ген: ZCRB1
# Обрабатывается ген: ZDHHC7
# Обрабатывается ген: ZEB2
# Обрабатывается ген: ZFAT
# Обрабатывается ген: ZFC3H1
# Обрабатывается ген: ZFP57
# Обрабатывается ген: ZFP91-CNTF
# Обрабатывается ген: ZMYND8
# Обрабатывается ген: ZNF143
# Обрабатывается ген: ZNF217
# Обрабатывается ген: ZNF281
# Обрабатывается ген: ZNF366
# Обрабатывается ген: ZNF479
# Обрабатывается ген: ZNF492
# Обрабатывается ген: ZNF559-ZNF177&ZNF177
# Обрабатывается ген: ZNF592
# Обрабатывается ген: ZNF608
# Обрабатывается ген: ZNF629
# Обрабатывается ген: ZNF644
# Обрабатывается ген: ZNF668
# Обрабатывается ген: ZNF98
# Обрабатывается ген: ZNHIT6
# Обрабатывается ген: ZP1
# Файл ALL_depscore_-0.15_zscore_-0.5.csv сохранён. Время выполнения: 4706.43 секунд
# Статистика: 10187 препаратов, из них 515 с известным механизмом

# %%
import requests
from chembl_webresource_client.new_client import new_client
import pandas as pd
import numpy as np
from typing import List, Dict, Union, Optional
from functools import lru_cache
import time
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import os
from pathlib import Path

# Настройка сессии с повторными попытками
session = requests.Session()
retries = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[500, 502, 503, 504]
)
session.mount('https://', HTTPAdapter(max_retries=retries))

# Установка таймаута по умолчанию для ChEMBL клиента
new_client.timeout = 30

def uniprot_to_chembl(uniprot_id: str) -> Optional[str]:
    """Получает ChEMBL ID из UniProt ID."""
    target = new_client.target
    try:
        res = target.filter(target_components__accession=uniprot_id)
        res_df = pd.DataFrame(res)
        
        if res_df.empty:
            return None
        return res_df['target_chembl_id'].iloc[0]
    except Exception as e:
        print(f"Ошибка при получении ChEMBL ID для UniProt {uniprot_id}: {e}")
        return None

def search_gene_in_uniprot_filtered(gene_name: str, organism: str = "Homo sapiens") -> Union[str, List[Dict]]:
    """Ищет информацию о гене в UniProt."""
    url = "https://rest.uniprot.org/uniprotkb/search"
    query = f'gene_exact:"{gene_name}" AND reviewed:true AND taxonomy_name:"{organism}"'
    
    params = {
        "query": query,
        "format": "json",
        "fields": "accession,gene_names,protein_name",
        "size": 10
    }
    
    try:
        response = session.get(url, params=params, timeout=30)
        response.raise_for_status()
        
        results = response.json().get("results", [])
        if not results:
            return f"No results found for gene '{gene_name}'"
        
        gene_info = [
            {
                "UniProt_ID": result["primaryAccession"],
                "Gene_Names": result["genes"][0]["geneName"]["value"] if result.get("genes") else "N/A",
                "Protein_Name": result["proteinDescription"]["recommendedName"]["fullName"]["value"],
            }
            for result in results
        ]
        
        for gene in gene_info:
            uniprot_id = gene["UniProt_ID"]
            chembl_id = uniprot_to_chembl(uniprot_id)
            gene["ChEMBL_ID"] = chembl_id if chembl_id else f"No ChEMBL ID found for {uniprot_id}"
            time.sleep(0.1)  # Задержка между запросами
        
        return gene_info
    except Exception as e:
        print(f"Ошибка при поиске гена {gene_name}: {e}")
        return f"Error searching gene {gene_name}: {str(e)}"

@lru_cache(maxsize=1000)
def get_parent_info(chembl_id: str) -> dict:
    """Получает информацию о родительском соединении для данного ChEMBL ID."""
    molecule = new_client.molecule
    molecule_form = new_client.molecule_form
    
    try:
        # Проверяем, есть ли родительское соединение
        parent_data = list(molecule_form.filter(molecule_chembl_id=chembl_id).only('parent_chembl_id'))
        
        if parent_data and 'parent_chembl_id' in parent_data[0]:
            parent_id = parent_data[0]['parent_chembl_id']
        else:
            # Если нет родителя, считаем текущий ID родительским
            parent_id = chembl_id
        
        # Получаем информацию о родительском соединении
        mol_data = list(molecule.filter(molecule_chembl_id=parent_id).only('pref_name', 'molecule_chembl_id'))
        pref_name = mol_data[0].get('pref_name', 'Unknown') if mol_data else 'Unknown'
        
        return {
            'parent_chembl_id': parent_id,
            'parent_pref_name': pref_name,
            'is_parent': parent_id == chembl_id
        }
    except Exception as e:
        print(f"Error getting parent info for {chembl_id}: {e}")
        return {
            'parent_chembl_id': chembl_id,
            'parent_pref_name': 'Unknown',
            'is_parent': True
        }

def filter_parent_drugs(drugs_list: List[Dict]) -> List[Dict]:
    """Фильтрует список препаратов, оставляя по одному представителю из каждого семейства.
       Сохраняет 'Yes' в Drug Mechanism при замене дочернего с 'Yes' на родительский."""
    parent_groups = {}
    
    # 1. Группируем все препараты по семействам
    for drug in drugs_list:
        try:
            if not drug.get('Drug ChEMBL ID'):
                continue
                
            parent_info = get_parent_info(drug['Drug ChEMBL ID'])
            parent_id = parent_info['parent_chembl_id']
            
            if parent_id not in parent_groups:
                parent_groups[parent_id] = {
                    'parent_info': parent_info,
                    'drugs': [],
                    'has_mechanism': False
                }
            
            parent_groups[parent_id]['drugs'].append(drug)
            if drug.get('Drug Mechanism ChEMBL') == 'Yes':
                parent_groups[parent_id]['has_mechanism'] = True
                
        except Exception as e:
            print(f"Ошибка при группировке препаратов: {e}")
            continue
    
    filtered_drugs = []
    
    # 2. Обрабатываем каждое семейство
    for parent_id, group in parent_groups.items():
        drugs_in_group = group['drugs']
        has_mechanism = group['has_mechanism']
        
        # Если в группе только один препарат - оставляем как есть
        if len(drugs_in_group) == 1:
            filtered_drugs.append(drugs_in_group[0])
            continue
        
        # Находим родительский препарат в группе
        parent_drug = next(
            (d for d in drugs_in_group if d['Drug ChEMBL ID'] == parent_id),
            None
        )
        
        # Если есть родительский препарат
        if parent_drug:
            # Если в семействе есть препараты с механизмом, сохраняем 'Yes' для родителя
            if has_mechanism:
                parent_drug['Drug Mechanism ChEMBL'] = 'Yes'
            filtered_drugs.append(parent_drug)
        else:
            # Если нет родительского - выбираем препарат с максимальным pChEMBL
            best_drug = max(
                drugs_in_group,
                key=lambda x: float(x['pChEMBL value']) if x.get('pChEMBL value', 'N/A') != 'N/A' else -1
            )
            filtered_drugs.append(best_drug)
    
    return filtered_drugs

def get_action_type(chembl_id: str) -> str:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        action_types = set()
        for mechanism in mechanisms:
            action_type = mechanism.get("action_type")
            if action_type:
                action_types.add(action_type)
        
        return "; ".join(action_types) if action_types else "N/A"
    except Exception as e:
        print(f"Ошибка при получении типа действия для {chembl_id}: {e}")
        return "N/A"

def get_mechanism_details(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        details = []
        for mechanism in mechanisms:
            mechanism_of_action = mechanism.get("mechanism_of_action", "N/A")
            
            details.append({
                "Mechanism of Action ChEMBL": mechanism_of_action,  # Изменено здесь
            })
        
        return details if details else [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь
    except Exception as e:
        print(f"Ошибка при получении механизма действия для {chembl_id}: {e}")
        return [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь

def get_max_phase(chembl_id: str) -> str:
    try:
        client = new_client
        molecule = client.molecule.get(chembl_id)
        max_phase = molecule.get("max_phase", None)
        
        if max_phase is None:
            return ""
        
        if max_phase == "0.0":
            return "Preclinical"
        elif max_phase == "1.0":
            return "Phase 1"
        elif max_phase == "2.0":
            return "Phase 2"
        elif max_phase == "3.0":
            return "Phase 3"
        elif max_phase == "4.0":
            return "Approved"
        else:
            return f"Unknown phase ({max_phase})"
    except Exception as e:
        print(f"Ошибка при получении фазы для {chembl_id}: {e}")
        return "N/A"

def get_pchembl_value(molecule_chembl_id: str, target_chembl_id: str) -> str:
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            pchembl_value__isnull=False
        ).only("pchembl_value")
        return activities[0]["pchembl_value"] if activities else "N/A"
    except Exception as e:
        print(f"Error fetching pChEMBL value for {molecule_chembl_id}: {e}")
        return "N/A"

def get_activity_data(molecule_chembl_id: str, target_chembl_id: str) -> Dict:
    """Возвращает объединенные данные активности: значение + единицы измерения"""
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).only("standard_value", "standard_type", "standard_units")
        
        if not activities:
            return {
                "Activity value ChEMBL": "N/A",
                "Activity type ChEMBL": "N/A"
            }
        
        activity = activities[0]
        value = activity.get('standard_value')
        units = activity.get('standard_units')
        act_type = activity.get('standard_type')
        
        if act_type == "Activity":
            act_type = "N/A"
        
        if value and units and value != "N/A" and units != "N/A":
            activity_value = f"= {value} {units}"
        else:
            activity_value = "N/A"
        
        return {
            "Activity value ChEMBL": activity_value,
            "Activity type ChEMBL": act_type
        }
    except Exception as e:
        print(f"Ошибка при получении данных активности для {molecule_chembl_id}: {e}")
        return {
            "Activity value ChEMBL": "N/A",
            "Activity type ChEMBL": "N/A"
        }

def get_drugs_for_target(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        
        mechanism_drugs = []
        mechanisms = client.mechanism.filter(target_chembl_id=chembl_id)
        for mech in mechanisms:
            try:
                drug_id = mech['molecule_chembl_id']
                drug = client.molecule.get(drug_id)
                
                activity_data = get_activity_data(drug_id, chembl_id)
                mechanism_details = get_mechanism_details(drug_id)
                
                if not mechanism_details:
                    print(f"Нет данных о механизме для {drug_id}")
                    continue
                    
                mechanism_drugs.append({
                    "Drug ChEMBL ID": drug_id,
                    "Drug name": drug.get('pref_name', 'N/A'),
                    "Drug Mechanism ChEMBL": "Yes",
                    "Activity value ChEMBL": activity_data["Activity value ChEMBL"],
                    "Activity type ChEMBL": activity_data["Activity type ChEMBL"],
                    "pChEMBL value": get_pchembl_value(drug_id, chembl_id),
                    "Max phase ChEMBL": get_max_phase(drug_id),
                    "Action type ChEMBL": get_action_type(drug_id),
                    "Mechanism of Action ChEMBL": mechanism_details[0]["Mechanism of Action ChEMBL"]
                })
                time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке механизма {mech.get('molecule_chembl_id')}: {str(e)}")
                continue
        
        mechanism_ids = {drug["Drug ChEMBL ID"] for drug in mechanism_drugs}
        activity_drugs = []
        
        activities = client.activity.filter(
            target_chembl_id=chembl_id,
            pchembl_value__isnull=False,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).order_by('-pchembl_value')[:100]
        
        for activity in activities:
            try:
                if activity['molecule_chembl_id'] not in mechanism_ids:
                    value = activity.get('standard_value', 'N/A')
                    units = activity.get('standard_units', 'N/A')
                    act_type = activity.get('standard_type', 'N/A')
                    
                    if act_type == "Activity":
                        act_type = "N/A"
                    
                    activity_value = f"= {value} {units}" if value != "N/A" and units != "N/A" else "N/A"
                    
                    activity_drugs.append({
                        "Drug ChEMBL ID": activity['molecule_chembl_id'],
                        "Drug name": activity['molecule_pref_name'],
                        "Drug Mechanism ChEMBL": "No",
                        "Activity value ChEMBL": activity_value,  # Исправлено
                        "Activity type ChEMBL": act_type,          # Исправлено
                        "pChEMBL value": activity['pchembl_value'],
                        "Max phase ChEMBL": get_max_phase(activity['molecule_chembl_id']),  # Исправлено
                        "Action type ChEMBL": get_action_type(activity['molecule_chembl_id']),  # Исправлено
                        "Mechanism of Action ChEMBL": "N/A"
                    })
                    time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке активности {activity}: {e}")
                continue
        
        all_drugs = mechanism_drugs + activity_drugs
        return filter_parent_drugs(all_drugs)
    except Exception as e:
        print(f"Ошибка при получении препаратов для цели {chembl_id}: {e}")
        return []

def get_gene_drug_info(gene_names: List[str]) -> List[Dict]:
    result = []
    
    for gene_name in gene_names:
        try:
            print(f"Обрабатывается ген: {gene_name}")
            gene_info_list = search_gene_in_uniprot_filtered(gene_name)
            
            if isinstance(gene_info_list, str):
                result.append({"Gene": gene_name, "Error": gene_info_list})
                continue
            
            unique_drugs_for_gene = {}

            for gene_info in gene_info_list:
                try:
                    if isinstance(gene_info['ChEMBL_ID'], str) and gene_info['ChEMBL_ID'].startswith("No ChEMBL"):
                        continue
                        
                    drugs = get_drugs_for_target(gene_info['ChEMBL_ID'])  # Только 1 аргумент!
                    
                    for drug in drugs:
                        chembl_id = drug["Drug ChEMBL ID"]
                        if chembl_id not in unique_drugs_for_gene or unique_drugs_for_gene[chembl_id]["pChEMBL value"] < drug["pChEMBL value"]:
                            unique_drugs_for_gene[chembl_id] = drug
                except Exception as e:
                    print(f"Ошибка при обработке информации о гене {gene_name}: {e}")
                    continue
            
            if not gene_info_list or 'UniProt_ID' not in gene_info_list[0]:
                continue
                
            for drug in unique_drugs_for_gene.values():
                result.append({
                    "Gene": gene_name,
                    "UniProt ID": gene_info_list[0]['UniProt_ID'],
                    "Protein name": gene_info_list[0]['Protein_Name'],
                    "Protein ChEMBL ID": gene_info_list[0]['ChEMBL_ID'],
                    **drug
                })
                
        except Exception as e:
            print(f"Ошибка при обработке гена {gene_name}: {e}")
            result.append({"Gene": gene_name, "Error": str(e)})
            continue

    return result

if __name__ == "__main__":
    # Замените этот путь на ваш реальный путь к файлу
    input_file = r"C:\Users\rusla\OneDrive\Рабочий стол\Диплом\Гены\thresholds\gene_selection\ALL\ALL_depscore_-0.15_zscore_-1.5.csv"
    
    # Чтение генов из файла
    try:
        genes_df = pd.read_csv(input_file)
        gene_names = genes_df['Gene'].tolist()
        print(f"Загружено {len(gene_names)} генов из файла")
    except Exception as e:
        print(f"Ошибка при чтении файла {input_file}: {e}")
        raise
    
    # Получаем имя выходного файла (без пути)
    output_filename = os.path.basename(input_file)
    
    start_time = time.time()
    print("\nНачинаем обработку с динамической фильтрацией pChEMBL")
    
    try:
        gene_drug_info = get_gene_drug_info(gene_names)
        
        # Определяем полный список всех возможных колонок
        all_columns = [
            "Gene", "UniProt ID", "Protein name", "Protein ChEMBL ID",
            "Drug ChEMBL ID", "Drug name", "Drug Mechanism ChEMBL",
            "Activity type ChEMBL", "Activity value ChEMBL",
            "pChEMBL value", "Max phase ChEMBL", "Action type ChEMBL", 
            "Mechanism of Action ChEMBL"
        ]
        
        # Создаем DataFrame из результатов
        df = pd.DataFrame(gene_drug_info)
        
        # Добавляем отсутствующие колонки и заполняем их NA
        for col in all_columns:
            if col not in df.columns:
                df[col] = pd.NA
        
        # Упорядочиваем колонки согласно нашему списку
        df = df[all_columns]
        
        # Фильтруем ошибочные записи (где нет Drug ChEMBL ID)
        df = df[df['Drug ChEMBL ID'].notna()]
        
        # Сохраняем в текущую директорию с тем же именем файла
        df.to_csv(output_filename, index=False, encoding='utf-8')
        
        elapsed_time = time.time() - start_time
        
        # Собираем статистику
        num_drugs = len(df)
        num_mechanisms = len(df[df['Drug Mechanism ChEMBL'] == 'Yes'])
        
        print(f"Файл {output_filename} сохранён. Время выполнения: {elapsed_time:.2f} секунд")
        print(f"Статистика: {num_drugs} препаратов, из них {num_mechanisms} с известным механизмом")
        
    except Exception as e:
        print(f"Критическая ошибка при обработке: {e}")
# Out:
# Загружено 49 генов из файла
#
# Начинаем обработку с динамической фильтрацией pChEMBL
# Обрабатывается ген: ARHGAP45
# Обрабатывается ген: ATP1B3
# Обрабатывается ген: ATP6V0A2
# Обрабатывается ген: BCL2
# Обрабатывается ген: C10orf95
# Обрабатывается ген: C16orf52
# Обрабатывается ген: C8orf86
# Обрабатывается ген: CARS2
# Обрабатывается ген: CBFB
# Обрабатывается ген: CCND3
# Обрабатывается ген: COQ4
# Обрабатывается ген: DHODH
# Обрабатывается ген: EBF1
# Обрабатывается ген: ERG
# Обрабатывается ген: FAM19A4
# Обрабатывается ген: FAM214B
# Обрабатывается ген: FAR1
# Обрабатывается ген: FLJ42393
# Обрабатывается ген: GCLC
# Обрабатывается ген: IKZF1
# Обрабатывается ген: LCE1F
# Обрабатывается ген: LEF1
# Обрабатывается ген: LOC107984065
# Обрабатывается ген: LOC107987188
# Обрабатывается ген: LOC440434
# Обрабатывается ген: MAGEA3
# Обрабатывается ген: MBNL1
# Обрабатывается ген: MEF2C
# Обрабатывается ген: MIR429
# Обрабатывается ген: MON1A
# Обрабатывается ген: MSL3P1
# Обрабатывается ген: MYB
# Обрабатывается ген: NMNAT1
# Обрабатывается ген: PAICS
# Обрабатывается ген: PAX5
# Обрабатывается ген: PIK3CD
# Обрабатывается ген: PPCDC
# Обрабатывается ген: PPCS
# Обрабатывается ген: RUNX1
# Обрабатывается ген: SFTA3
# Обрабатывается ген: SLC19A1
# Обрабатывается ген: SLC25A19
# Обрабатывается ген: SMARCC1
# Обрабатывается ген: STMN1
# Обрабатывается ген: TCF3
# Обрабатывается ген: TRIM66
# Обрабатывается ген: UMPS
# Обрабатывается ген: WDR61
# Обрабатывается ген: WDYHV1
# Файл ALL_depscore_-0.15_zscore_-1.5.csv сохранён. Время выполнения: 108.55 секунд
# Статистика: 677 препаратов, из них 44 с известным механизмом

# %%
import requests
from chembl_webresource_client.new_client import new_client
import pandas as pd
import numpy as np
from typing import List, Dict, Union, Optional
from functools import lru_cache
import time
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import os
from pathlib import Path

# Настройка сессии с повторными попытками
session = requests.Session()
retries = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[500, 502, 503, 504]
)
session.mount('https://', HTTPAdapter(max_retries=retries))

# Установка таймаута по умолчанию для ChEMBL клиента
new_client.timeout = 30

def uniprot_to_chembl(uniprot_id: str) -> Optional[str]:
    """Получает ChEMBL ID из UniProt ID."""
    target = new_client.target
    try:
        res = target.filter(target_components__accession=uniprot_id)
        res_df = pd.DataFrame(res)
        
        if res_df.empty:
            return None
        return res_df['target_chembl_id'].iloc[0]
    except Exception as e:
        print(f"Ошибка при получении ChEMBL ID для UniProt {uniprot_id}: {e}")
        return None

def search_gene_in_uniprot_filtered(gene_name: str, organism: str = "Homo sapiens") -> Union[str, List[Dict]]:
    """Ищет информацию о гене в UniProt."""
    url = "https://rest.uniprot.org/uniprotkb/search"
    query = f'gene_exact:"{gene_name}" AND reviewed:true AND taxonomy_name:"{organism}"'
    
    params = {
        "query": query,
        "format": "json",
        "fields": "accession,gene_names,protein_name",
        "size": 10
    }
    
    try:
        response = session.get(url, params=params, timeout=30)
        response.raise_for_status()
        
        results = response.json().get("results", [])
        if not results:
            return f"No results found for gene '{gene_name}'"
        
        gene_info = [
            {
                "UniProt_ID": result["primaryAccession"],
                "Gene_Names": result["genes"][0]["geneName"]["value"] if result.get("genes") else "N/A",
                "Protein_Name": result["proteinDescription"]["recommendedName"]["fullName"]["value"],
            }
            for result in results
        ]
        
        for gene in gene_info:
            uniprot_id = gene["UniProt_ID"]
            chembl_id = uniprot_to_chembl(uniprot_id)
            gene["ChEMBL_ID"] = chembl_id if chembl_id else f"No ChEMBL ID found for {uniprot_id}"
            time.sleep(0.1)  # Задержка между запросами
        
        return gene_info
    except Exception as e:
        print(f"Ошибка при поиске гена {gene_name}: {e}")
        return f"Error searching gene {gene_name}: {str(e)}"

@lru_cache(maxsize=1000)
def get_parent_info(chembl_id: str) -> dict:
    """Получает информацию о родительском соединении для данного ChEMBL ID."""
    molecule = new_client.molecule
    molecule_form = new_client.molecule_form
    
    try:
        # Проверяем, есть ли родительское соединение
        parent_data = list(molecule_form.filter(molecule_chembl_id=chembl_id).only('parent_chembl_id'))
        
        if parent_data and 'parent_chembl_id' in parent_data[0]:
            parent_id = parent_data[0]['parent_chembl_id']
        else:
            # Если нет родителя, считаем текущий ID родительским
            parent_id = chembl_id
        
        # Получаем информацию о родительском соединении
        mol_data = list(molecule.filter(molecule_chembl_id=parent_id).only('pref_name', 'molecule_chembl_id'))
        pref_name = mol_data[0].get('pref_name', 'Unknown') if mol_data else 'Unknown'
        
        return {
            'parent_chembl_id': parent_id,
            'parent_pref_name': pref_name,
            'is_parent': parent_id == chembl_id
        }
    except Exception as e:
        print(f"Error getting parent info for {chembl_id}: {e}")
        return {
            'parent_chembl_id': chembl_id,
            'parent_pref_name': 'Unknown',
            'is_parent': True
        }

def filter_parent_drugs(drugs_list: List[Dict]) -> List[Dict]:
    """Фильтрует список препаратов, оставляя по одному представителю из каждого семейства.
       Сохраняет 'Yes' в Drug Mechanism при замене дочернего с 'Yes' на родительский."""
    parent_groups = {}
    
    # 1. Группируем все препараты по семействам
    for drug in drugs_list:
        try:
            if not drug.get('Drug ChEMBL ID'):
                continue
                
            parent_info = get_parent_info(drug['Drug ChEMBL ID'])
            parent_id = parent_info['parent_chembl_id']
            
            if parent_id not in parent_groups:
                parent_groups[parent_id] = {
                    'parent_info': parent_info,
                    'drugs': [],
                    'has_mechanism': False
                }
            
            parent_groups[parent_id]['drugs'].append(drug)
            if drug.get('Drug Mechanism ChEMBL') == 'Yes':
                parent_groups[parent_id]['has_mechanism'] = True
                
        except Exception as e:
            print(f"Ошибка при группировке препаратов: {e}")
            continue
    
    filtered_drugs = []
    
    # 2. Обрабатываем каждое семейство
    for parent_id, group in parent_groups.items():
        drugs_in_group = group['drugs']
        has_mechanism = group['has_mechanism']
        
        # Если в группе только один препарат - оставляем как есть
        if len(drugs_in_group) == 1:
            filtered_drugs.append(drugs_in_group[0])
            continue
        
        # Находим родительский препарат в группе
        parent_drug = next(
            (d for d in drugs_in_group if d['Drug ChEMBL ID'] == parent_id),
            None
        )
        
        # Если есть родительский препарат
        if parent_drug:
            # Если в семействе есть препараты с механизмом, сохраняем 'Yes' для родителя
            if has_mechanism:
                parent_drug['Drug Mechanism ChEMBL'] = 'Yes'
            filtered_drugs.append(parent_drug)
        else:
            # Если нет родительского - выбираем препарат с максимальным pChEMBL
            best_drug = max(
                drugs_in_group,
                key=lambda x: float(x['pChEMBL value']) if x.get('pChEMBL value', 'N/A') != 'N/A' else -1
            )
            filtered_drugs.append(best_drug)
    
    return filtered_drugs

def get_action_type(chembl_id: str) -> str:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        action_types = set()
        for mechanism in mechanisms:
            action_type = mechanism.get("action_type")
            if action_type:
                action_types.add(action_type)
        
        return "; ".join(action_types) if action_types else "N/A"
    except Exception as e:
        print(f"Ошибка при получении типа действия для {chembl_id}: {e}")
        return "N/A"

def get_mechanism_details(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        mechanisms = client.mechanism.filter(molecule_chembl_id=chembl_id)
        
        details = []
        for mechanism in mechanisms:
            mechanism_of_action = mechanism.get("mechanism_of_action", "N/A")
            
            details.append({
                "Mechanism of Action ChEMBL": mechanism_of_action,  # Изменено здесь
            })
        
        return details if details else [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь
    except Exception as e:
        print(f"Ошибка при получении механизма действия для {chembl_id}: {e}")
        return [{"Mechanism of Action ChEMBL": "N/A"}]  # И здесь

def get_max_phase(chembl_id: str) -> str:
    try:
        client = new_client
        molecule = client.molecule.get(chembl_id)
        max_phase = molecule.get("max_phase", None)
        
        if max_phase is None:
            return ""
        
        if max_phase == "0.0":
            return "Preclinical"
        elif max_phase == "1.0":
            return "Phase 1"
        elif max_phase == "2.0":
            return "Phase 2"
        elif max_phase == "3.0":
            return "Phase 3"
        elif max_phase == "4.0":
            return "Approved"
        else:
            return f"Unknown phase ({max_phase})"
    except Exception as e:
        print(f"Ошибка при получении фазы для {chembl_id}: {e}")
        return "N/A"

def get_pchembl_value(molecule_chembl_id: str, target_chembl_id: str) -> str:
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            pchembl_value__isnull=False
        ).only("pchembl_value")
        return activities[0]["pchembl_value"] if activities else "N/A"
    except Exception as e:
        print(f"Error fetching pChEMBL value for {molecule_chembl_id}: {e}")
        return "N/A"

def get_activity_data(molecule_chembl_id: str, target_chembl_id: str) -> Dict:
    """Возвращает объединенные данные активности: значение + единицы измерения"""
    try:
        activities = new_client.activity.filter(
            molecule_chembl_id=molecule_chembl_id,
            target_chembl_id=target_chembl_id,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).only("standard_value", "standard_type", "standard_units")
        
        if not activities:
            return {
                "Activity value ChEMBL": "N/A",
                "Activity type ChEMBL": "N/A"
            }
        
        activity = activities[0]
        value = activity.get('standard_value')
        units = activity.get('standard_units')
        act_type = activity.get('standard_type')
        
        if act_type == "Activity":
            act_type = "N/A"
        
        if value and units and value != "N/A" and units != "N/A":
            activity_value = f"= {value} {units}"
        else:
            activity_value = "N/A"
        
        return {
            "Activity value ChEMBL": activity_value,
            "Activity type ChEMBL": act_type
        }
    except Exception as e:
        print(f"Ошибка при получении данных активности для {molecule_chembl_id}: {e}")
        return {
            "Activity value ChEMBL": "N/A",
            "Activity type ChEMBL": "N/A"
        }

def get_drugs_for_target(chembl_id: str) -> List[Dict]:
    try:
        client = new_client
        
        mechanism_drugs = []
        mechanisms = client.mechanism.filter(target_chembl_id=chembl_id)
        for mech in mechanisms:
            try:
                drug_id = mech['molecule_chembl_id']
                drug = client.molecule.get(drug_id)
                
                activity_data = get_activity_data(drug_id, chembl_id)
                mechanism_details = get_mechanism_details(drug_id)
                
                if not mechanism_details:
                    print(f"Нет данных о механизме для {drug_id}")
                    continue
                    
                mechanism_drugs.append({
                    "Drug ChEMBL ID": drug_id,
                    "Drug name": drug.get('pref_name', 'N/A'),
                    "Drug Mechanism ChEMBL": "Yes",
                    "Activity value ChEMBL": activity_data["Activity value ChEMBL"],
                    "Activity type ChEMBL": activity_data["Activity type ChEMBL"],
                    "pChEMBL value": get_pchembl_value(drug_id, chembl_id),
                    "Max phase ChEMBL": get_max_phase(drug_id),
                    "Action type ChEMBL": get_action_type(drug_id),
                    "Mechanism of Action ChEMBL": mechanism_details[0]["Mechanism of Action ChEMBL"]
                })
                time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке механизма {mech.get('molecule_chembl_id')}: {str(e)}")
                continue
        
        mechanism_ids = {drug["Drug ChEMBL ID"] for drug in mechanism_drugs}
        activity_drugs = []
        
        activities = client.activity.filter(
            target_chembl_id=chembl_id,
            pchembl_value__isnull=False,
            standard_type__in=["IC50", "Kd", "Ki", "EC50"]
        ).order_by('-pchembl_value')[:100]
        
        for activity in activities:
            try:
                if activity['molecule_chembl_id'] not in mechanism_ids:
                    value = activity.get('standard_value', 'N/A')
                    units = activity.get('standard_units', 'N/A')
                    act_type = activity.get('standard_type', 'N/A')
                    
                    if act_type == "Activity":
                        act_type = "N/A"
                    
                    activity_value = f"= {value} {units}" if value != "N/A" and units != "N/A" else "N/A"
                    
                    activity_drugs.append({
                        "Drug ChEMBL ID": activity['molecule_chembl_id'],
                        "Drug name": activity['molecule_pref_name'],
                        "Drug Mechanism ChEMBL": "No",
                        "Activity value ChEMBL": activity_value,  # Исправлено
                        "Activity type ChEMBL": act_type,          # Исправлено
                        "pChEMBL value": activity['pchembl_value'],
                        "Max phase ChEMBL": get_max_phase(activity['molecule_chembl_id']),  # Исправлено
                        "Action type ChEMBL": get_action_type(activity['molecule_chembl_id']),  # Исправлено
                        "Mechanism of Action ChEMBL": "N/A"
                    })
                    time.sleep(0.1)
            except Exception as e:
                print(f"Ошибка при обработке активности {activity}: {e}")
                continue
        
        all_drugs = mechanism_drugs + activity_drugs
        return filter_parent_drugs(all_drugs)
    except Exception as e:
        print(f"Ошибка при получении препаратов для цели {chembl_id}: {e}")
        return []

def get_gene_drug_info(gene_names: List[str]) -> List[Dict]:
    result = []
    
    for gene_name in gene_names:
        try:
            print(f"Обрабатывается ген: {gene_name}")
            gene_info_list = search_gene_in_uniprot_filtered(gene_name)
            
            if isinstance(gene_info_list, str):
                result.append({"Gene": gene_name, "Error": gene_info_list})
                continue
            
            unique_drugs_for_gene = {}

            for gene_info in gene_info_list:
                try:
                    if isinstance(gene_info['ChEMBL_ID'], str) and gene_info['ChEMBL_ID'].startswith("No ChEMBL"):
                        continue
                        
                    drugs = get_drugs_for_target(gene_info['ChEMBL_ID'])  # Только 1 аргумент!
                    
                    for drug in drugs:
                        chembl_id = drug["Drug ChEMBL ID"]
                        if chembl_id not in unique_drugs_for_gene or unique_drugs_for_gene[chembl_id]["pChEMBL value"] < drug["pChEMBL value"]:
                            unique_drugs_for_gene[chembl_id] = drug
                except Exception as e:
                    print(f"Ошибка при обработке информации о гене {gene_name}: {e}")
                    continue
            
            if not gene_info_list or 'UniProt_ID' not in gene_info_list[0]:
                continue
                
            for drug in unique_drugs_for_gene.values():
                result.append({
                    "Gene": gene_name,
                    "UniProt ID": gene_info_list[0]['UniProt_ID'],
                    "Protein name": gene_info_list[0]['Protein_Name'],
                    "Protein ChEMBL ID": gene_info_list[0]['ChEMBL_ID'],
                    **drug
                })
                
        except Exception as e:
            print(f"Ошибка при обработке гена {gene_name}: {e}")
            result.append({"Gene": gene_name, "Error": str(e)})
            continue

    return result

if __name__ == "__main__":
    # Замените этот путь на ваш реальный путь к файлу
    input_file = r"C:\Users\rusla\OneDrive\Рабочий стол\Диплом\Гены\thresholds\gene_selection\ALL\ALL_depscore_-0.15_zscore_-1.csv"
    
    # Чтение генов из файла
    try:
        genes_df = pd.read_csv(input_file)
        gene_names = genes_df['Gene'].tolist()
        print(f"Загружено {len(gene_names)} генов из файла")
    except Exception as e:
        print(f"Ошибка при чтении файла {input_file}: {e}")
        raise
    
    # Получаем имя выходного файла (без пути)
    output_filename = os.path.basename(input_file)
    
    start_time = time.time()
    print("\nНачинаем обработку с динамической фильтрацией pChEMBL")
    
    try:
        gene_drug_info = get_gene_drug_info(gene_names)
        
        # Определяем полный список всех возможных колонок
        all_columns = [
            "Gene", "UniProt ID", "Protein name", "Protein ChEMBL ID",
            "Drug ChEMBL ID", "Drug name", "Drug Mechanism ChEMBL",
            "Activity type ChEMBL", "Activity value ChEMBL",
            "pChEMBL value", "Max phase ChEMBL", "Action type ChEMBL", 
            "Mechanism of Action ChEMBL"
        ]
        
        # Создаем DataFrame из результатов
        df = pd.DataFrame(gene_drug_info)
        
        # Добавляем отсутствующие колонки и заполняем их NA
        for col in all_columns:
            if col not in df.columns:
                df[col] = pd.NA
        
        # Упорядочиваем колонки согласно нашему списку
        df = df[all_columns]
        
        # Фильтруем ошибочные записи (где нет Drug ChEMBL ID)
        df = df[df['Drug ChEMBL ID'].notna()]
        
        # Сохраняем в текущую директорию с тем же именем файла
        df.to_csv(output_filename, index=False, encoding='utf-8')
        
        elapsed_time = time.time() - start_time
        
        # Собираем статистику
        num_drugs = len(df)
        num_mechanisms = len(df[df['Drug Mechanism ChEMBL'] == 'Yes'])
        
        print(f"Файл {output_filename} сохранён. Время выполнения: {elapsed_time:.2f} секунд")
        print(f"Статистика: {num_drugs} препаратов, из них {num_mechanisms} с известным механизмом")
        
    except Exception as e:
        print(f"Критическая ошибка при обработке: {e}")
# Out:
# Загружено 263 генов из файла
#
# Начинаем обработку с динамической фильтрацией pChEMBL
# Обрабатывается ген: ADSS2
# Обрабатывается ген: AES
# Обрабатывается ген: AFF1
# Обрабатывается ген: AGPS
# Обрабатывается ген: AHCY
# Обрабатывается ген: AHDC1
# Обрабатывается ген: AK2
# Обрабатывается ген: ALAD
# Обрабатывается ген: ALAS1
# Обрабатывается ген: AMY1A&AMY1B&AMY1C
# Обрабатывается ген: ANKH
# Обрабатывается ген: ANKRD36
# Обрабатывается ген: ARHGAP19-SLIT1
# Обрабатывается ген: ARHGAP45
# Обрабатывается ген: ATIC
# Обрабатывается ген: ATP1B3
# Обрабатывается ген: ATP6V0A2
# Обрабатывается ген: AUH
# Обрабатывается ген: BCL2
# Обрабатывается ген: BCS1L
# Обрабатывается ген: BIRC8
# Обрабатывается ген: BRD9
# Обрабатывается ген: C10orf95
# Обрабатывается ген: C14orf2
# Обрабатывается ген: C16orf52
# Обрабатывается ген: C1QTNF5&MFRP
# Обрабатывается ген: C1orf228
# Обрабатывается ген: C2orf16
# Обрабатывается ген: C8orf44-SGK3
# Обрабатывается ген: C8orf86
# Обрабатывается ген: CAB39
# Обрабатывается ген: CAD
# Обрабатывается ген: CARS2
# Обрабатывается ген: CBFB
# Обрабатывается ген: CCM2
# Обрабатывается ген: CCND3
# Обрабатывается ген: CCNYL2
# Обрабатывается ген: CDIN1
# Обрабатывается ген: CDK6
# Обрабатывается ген: CDY1B&CDY1
# Обрабатывается ген: CEND1
# Обрабатывается ген: CEP55
# Обрабатывается ген: CFL1
# Обрабатывается ген: CLSTN3
# Обрабатывается ген: CMIP
# Обрабатывается ген: COA5
# Обрабатывается ген: COL18A1
# Обрабатывается ген: COQ4
# Обрабатывается ген: COX14
# Обрабатывается ген: COX16
# Обрабатывается ген: CPOX
# Обрабатывается ген: CTBP1
# Обрабатывается ген: CTPS1
# Обрабатывается ген: CTRB1&CTRB2
# Обрабатывается ген: CUEDC1
# Обрабатывается ген: DARS2
# Обрабатывается ген: DCAF15
# Обрабатывается ген: DCPS
# Обрабатывается ген: DCTD
# Обрабатывается ген: DDX3Y
# Обрабатывается ген: DHODH
# Обрабатывается ген: DIXDC1
# Обрабатывается ген: DLSTP1
# Обрабатывается ген: DNM2
# Обрабатывается ген: DNMT1
# Обрабатывается ген: DOT1L
# Обрабатывается ген: DPH6
# Обрабатывается ген: DPY30
# Обрабатывается ген: DTYMK
# Обрабатывается ген: EBF1
# Обрабатывается ген: EIF4E2
# Обрабатывается ген: ELOF1
# Обрабатывается ген: EMC3
# Обрабатывается ген: EP300
# Обрабатывается ген: ERCC8
# Обрабатывается ген: ERG
# Обрабатывается ген: ESPNP
# Обрабатывается ген: EXOC6
# Обрабатывается ген: FAM19A4
# Обрабатывается ген: FAM214B
# Обрабатывается ген: FAM50A
# Обрабатывается ген: FANCI
# Обрабатывается ген: FAR1
# Обрабатывается ген: FDX1
# Обрабатывается ген: FECH
# Обрабатывается ген: FER1L6-AS1
# Обрабатывается ген: FH
# Обрабатывается ген: FKBP1A
# Обрабатывается ген: FLCN
# Обрабатывается ген: FLJ42393
# Обрабатывается ген: FLT3
# Обрабатывается ген: FOXI3
# Обрабатывается ген: FPGS
# Обрабатывается ген: GALE
# Обрабатывается ген: GART
# Обрабатывается ген: GCLC
# Обрабатывается ген: GCSH
# Обрабатывается ген: GFI1
# Обрабатывается ген: GIGYF2
# Обрабатывается ген: GLRX5
# Обрабатывается ген: GUSBP1
# Обрабатывается ген: H2BC7
# Обрабатывается ген: HIF1AN
# Обрабатывается ген: HIST1H2AC
# Обрабатывается ген: HMBS
# Обрабатывается ген: HMGB1
# Обрабатывается ген: IGLL1
# Обрабатывается ген: IKZF1
# Обрабатывается ген: IMPDH2
# Обрабатывается ген: KCNJ12
# Обрабатывается ген: KIF26A
# Обрабатывается ген: KIR3DS1
# Обрабатывается ген: KLHDC7B
# Обрабатывается ген: KLRA1P
# Обрабатывается ген: KRTAP10-11
# Обрабатывается ген: KRTAP5-1
# Обрабатывается ген: KRTAP5-10
# Обрабатывается ген: KRTAP5-3
# Обрабатывается ген: LCE1F
# Обрабатывается ген: LCE2C
# Обрабатывается ген: LEF1
# Обрабатывается ген: LINC00518
# Обрабатывается ген: LINC00523
# Обрабатывается ген: LINC01140
# Обрабатывается ген: LINC02210-CRHR1&CRHR1
# Обрабатывается ген: LIPT1
# Обрабатывается ген: LIPT2
# Обрабатывается ген: LOC101929540
# Обрабатывается ген: LOC101929775
# Обрабатывается ген: LOC101929970
# Обрабатывается ген: LOC102723414&LOC102723608&LOC102723819&LOC102723933&LOC105371747&LOC105379635
# Обрабатывается ген: LOC105369243&SULT1A4&SULT1A3
# Обрабатывается ген: LOC107984021
# Обрабатывается ген: LOC107984065
# Обрабатывается ген: LOC107987188
# Обрабатывается ген: LOC440434
# Обрабатывается ген: LOC644762
# Обрабатывается ген: LOC644936
# Обрабатывается ген: LOC652276
# Обрабатывается ген: LPAR5
# Обрабатывается ген: LRP8
# Обрабатывается ген: LRWD1
# Обрабатывается ген: MAGEA3
# Обрабатывается ген: MAML1
# Обрабатывается ген: MBNL1
# Обрабатывается ген: MED16
# Обрабатывается ген: MED23
# Обрабатывается ген: MED24
# Обрабатывается ген: MEF2C
# Обрабатывается ген: MGAT1
# Обрабатывается ген: MICOS10
# Обрабатывается ген: MIOS
# Обрабатывается ген: MIR429
# Обрабатывается ген: MLLT1
# Обрабатывается ген: MLST8
# Обрабатывается ген: MMGT1
# Обрабатывается ген: MON1A
# Обрабатывается ген: MOS
# Обрабатывается ген: MRPS24
# Обрабатывается ген: MSI2
# Обрабатывается ген: MSL3P1
# Обрабатывается ген: MTHFD1
# Обрабатывается ген: MUM1L1
# Обрабатывается ген: MXRA7
# Обрабатывается ген: MYB
# Обрабатывается ген: NAMPT
# Обрабатывается ген: NCKAP1L
# Обрабатывается ген: NCLN
# Обрабатывается ген: NMNAT1
# Обрабатывается ген: NOTCH1
# Обрабатывается ген: NOTUM
# Обрабатывается ген: OGDH
# Обрабатывается ген: OR2L8
# Обрабатывается ген: OR2T34&OR2T3
# Обрабатывается ген: PAICS
# Обрабатывается ген: PARGP1
# Обрабатывается ген: PAX5
# Обрабатывается ген: PCYT2
# Обрабатывается ген: PDXK
# Обрабатывается ген: PEDS1
# Обрабатывается ген: PET100
# Обрабатывается ген: PEX7
# Обрабатывается ген: PFAS
# Обрабатывается ген: PGAP6
# Обрабатывается ген: PIK3CD
# Обрабатывается ген: PIM3
# Обрабатывается ген: PMS2P2
# Обрабатывается ген: PPAT
# Обрабатывается ген: PPCDC
# Обрабатывается ген: PPCS
# Обрабатывается ген: PPY
# Обрабатывается ген: PRB2
# Обрабатывается ген: PRDX6
# Обрабатывается ген: PRR22
# Обрабатывается ген: PTPRQ
# Обрабатывается ген: RADIL
# Обрабатывается ген: RFC4
# Обрабатывается ген: RHOXF2B&RHOXF2
# Обрабатывается ген: RPLP2
# Обрабатывается ген: RPS26
# Обрабатывается ген: RUNX1
# Обрабатывается ген: RYK
# Обрабатывается ген: SATB1
# Обрабатывается ген: SDHA
# Обрабатывается ген: SDHB
# Обрабатывается ген: SEMA3F
# Обрабатывается ген: SEPHS2
# Обрабатывается ген: SFTA3
# Обрабатывается ген: SIK3
# Обрабатывается ген: SIRT7
# Обрабатывается ген: SLC19A1
# Обрабатывается ген: SLC20A1
# Обрабатывается ген: SLC25A1
# Обрабатывается ген: SLC25A19
# Обрабатывается ген: SLC25A51
# Обрабатывается ген: SLC5A3
# Обрабатывается ген: SLC8B1
# Обрабатывается ген: SMARCB1
# Обрабатывается ген: SMARCC1
# Обрабатывается ген: SMARCD1
# Обрабатывается ген: SORD2P
# Обрабатывается ген: SPDYE4
# Обрабатывается ген: STMN1
# Обрабатывается ген: SUCLG1
# Обрабатывается ген: SYK
# Обрабатывается ген: TAFAZZIN
# Обрабатывается ген: TBC1D3J
# Обрабатывается ген: TBL1Y
# Обрабатывается ген: TCF12
# Обрабатывается ген: TCF3
# Обрабатывается ген: TEN1-CDK3&CDK3
# Обрабатывается ген: TFRC
# Обрабатывается ген: THAP3
# Обрабатывается ген: TKFC
# Обрабатывается ген: TKT
# Обрабатывается ген: TMEM57
# Обрабатывается ген: TMX1
# Обрабатывается ген: TOMM20
# Обрабатывается ген: TPK1
# Обрабатывается ген: TPPP
# Обрабатывается ген: TRIM66
# Обрабатывается ген: TRMT112
# Обрабатывается ген: TYMS
# Обрабатывается ген: UBE2T
# Обрабатывается ген: UMPS
# Обрабатывается ген: UNK
# Обрабатывается ген: UQCC1
# Обрабатывается ген: UQCRB
# Обрабатывается ген: UQCRC1
# Обрабатывается ген: WDR20
# Обрабатывается ген: WDR49
# Обрабатывается ген: WDR61
# Обрабатывается ген: WDYHV1
# Обрабатывается ген: WISP3
# Обрабатывается ген: WSB1
# Обрабатывается ген: ZC3H4
# Обрабатывается ген: ZFP91-CNTF
# Обрабатывается ген: ZMYND8
# Обрабатывается ген: ZNF366
# Обрабатывается ген: ZNF479
# Обрабатывается ген: ZNF592
# Обрабатывается ген: ZNF608
# Обрабатывается ген: ZNF629
# Файл ALL_depscore_-0.15_zscore_-1.csv сохранён. Время выполнения: 472.33 секунд
# Статистика: 3040 препаратов, из них 137 с известным механизмом
